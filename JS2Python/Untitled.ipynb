# %%
import pandas as pd

# %%
df=pd.read_csv("activity_log.csv")

# %%
df.head()
# Out:
#                                      id asset_type  \
# 0  40aa91ea-4ed6-463b-841e-8a9a524c1c74    dataset
# 1  807a1013-8235-490d-a491-76ddb8996480    dataset
# 2  b0a64b6f-ad2c-419a-a582-5ac7225fcd71    dataset
# 3  d71eab6f-7f27-4108-ba1e-c19cc52e7903    dataset
# 4  7c815179-07e9-4540-b7c8-0e8fa570a920    dataset
#
#                                   affected_item             acting_user_name  \
# 0                              DWR Active Calls  Division of Water Resources
# 1  Current Surface Water Conditions in Colorado  Division of Water Resources
# 2  Current Surface Water Conditions in Colorado  Division of Water Resources
# 3                              DWR Active Calls  Division of Water Resources
# 4                              DWR Active Calls  Division of Water Resources
#
#                activity_type                created_at
# 0  DataUpdate.Upsert.Success  2025-01-28T19:46:12.438Z
# 1  DataUpdate.Upsert.Success  2025-01-28T19:45:57.014Z
# ...

# %%
df["activity_type"].value_counts()
# Out:
# activity_type
# DataUpdate.Upsert.Success                   499436
# AssetMetadataChanged                         22038
# DraftPublished                               15295
# DataUpdate.Replace.Success                   11226
# DraftCreated                                 11054
# AssetDeleted                                  6965
# AssetOwnerChanged                             2098
# AssetCreated                                  1946
# AssetPermissionsChanged                       1666
# ScheduleSucceeded                             1366
# DraftDeleted                                  1189
# DataUpdate.Upsert.SuccessWithDataErrors        539
# DataUpdate.Import.Failure                      326
# DataUpdate.Upsert.Failure                      323
# ScheduleFailed                                 317
# CollaboratorAdded                              295
# DataUpdate.Replace.Failure                     103
# DataUpdate.Import.Success                       83
# ...

# %%
df2=pd.read_csv("https://data.colorado.gov/resource/xejc-64sn.csv?$limit=1000000")
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 df2=pd.read_csv("https://data.colorado.gov/resource/xejc-64sn.csv?$limit=1000000")
#
# File ~/anaconda3/envs/fire/lib/python3.11/site-packages/pandas/io/parsers/readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
import requests

# URL of the page that handles the file download
download_url = 'https://download.bls.gov/pub/time.series/sm/sm.data.6.Colorado'

# Data required to initiate the download (e.g., form data)
data = {
    'download_token': 'ab056afb9e654f45a800b1be770d7094'
}

# Headers (if required)
headers = {
    'Authorization': 'ab056afb9e654f45a800b1be770d7094'
}

# Send a POST request to the download URL
response = requests.post(download_url, data=data, headers=headers)
response.raise_for_status()  # Check for request errors

# Save the file to the local disk
with open('downloaded_file.zip', 'wb') as file:
    file.write(response.content)

print("File downloaded successfully.")
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[1], line 18
#      16 # Send a POST request to the download URL
#      17 response = requests.post(download_url, data=data, headers=headers)
# ---> 18 response.raise_for_status()  # Check for request errors
#      20 # Save the file to the local disk
#      21 with open('downloaded_file.zip', 'wb') as file:
#
# File ~/anaconda3/envs/fire/lib/python3.11/site-packages/requests/models.py:1024, in Response.raise_for_status(self)
#    1019     http_error_msg = (
#    1020         f"{self.status_code} Server Error: {reason} for url: {self.url}"
#    1021     )
#    1023 if http_error_msg:
# -> 1024     raise HTTPError(http_error_msg, response=self)
#
# HTTPError: 403 Client Error: Forbidden for url: https://download.bls.gov/pub/time.series/sm/sm.data.6.Colorado

# %%
import requests

# URL of the API endpoint that provides the file
api_url = 'https://download.bls.gov/'

# Headers required for authentication
headers = {
    'Authorization': 'ab056afb9e654f45a800b1be770d7094'
}

# Parameters required by the API (if any)
params = {
    'file_id': 'pub/time.series/sm/sm.data.6.Colorado'
}

# Send a GET request to the API endpoint with headers and parameters
response = requests.get(api_url, headers=headers,params=params)
response.raise_for_status()  # Check for request errors

# Save the file to the local disk
with open('downloaded_file.zip', 'wb') as file:
    file.write(response.content)

print("File downloaded successfully.")
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[5], line 18
#      16 # Send a GET request to the API endpoint with headers and parameters
#      17 response = requests.get(api_url, headers=headers,params=params)
# ---> 18 response.raise_for_status()  # Check for request errors
#      20 # Save the file to the local disk
#      21 with open('downloaded_file.zip', 'wb') as file:
#
# File ~/anaconda3/envs/fire/lib/python3.11/site-packages/requests/models.py:1024, in Response.raise_for_status(self)
#    1019     http_error_msg = (
#    1020         f"{self.status_code} Server Error: {reason} for url: {self.url}"
#    1021     )
#    1023 if http_error_msg:
# -> 1024     raise HTTPError(http_error_msg, response=self)
#
# HTTPError: 403 Client Error: Forbidden for url: https://download.bls.gov/?file_id=pub%2Ftime.series%2Fsm%2Fsm.data.6.Colorado

# %%
import requests

# URL of the file to download (example)
url = "https://download.bls.gov/pub/time.series/cu/cu.data.0.Current"

# Set headers to mimic a real browser
headers = {
    "Accept": "text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.7",
    "Accept-Encoding": "gzip, deflate, br, zstd",
    "Accept-Language": "en-US,en;q=0.9",
    "Connection": "keep-alive",
    "Sec-Fetch-Mode": "navigate",
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/132.0.0.0 Safari/537.36"
}

# Make the request
response = requests.get(url, headers=headers)

# Check response
if response.status_code == 200:
    print("Download successful!")
    # Save the file
    with open("bls_data.txt", "wb") as file:
        file.write(response.content)
else:
    print(f"Failed to download. HTTP Status Code: {response.status_code}")
# Out:
# Download successful!

# %%
"Accept": "text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.7",
"Accept-Encoding": "gzip, deflate, br, zstd",
"Accept-Language": "en-US,en;q=0.9",
"Cache-Control": "max-age=0",
"Connection": "keep-alive",
"Cookie": "_ga=GA1.1.584521977.1736535855; nmstat=bc4c43da-b99f-0406-a551-88dbf3de08f4; __gsas=ID=1e076771c88f393d:T=1738763649:RT=1738763649:S=ALNI_Mav7rDepcoYm-DwXBGCzNrGRxE3yA; _ga_CSLL4ZEK4L=GS1.1.1738763052.5.1.1738763730.0.0.0",
"Host": "download.bls.gov",
"Sec-Fetch-Dest": "document",
"Sec-Fetch-Mode": "navigate",
"Sec-Fetch-Site": none,
"Sec-Fetch-User": "?1",
"Upgrade-Insecure-Requests": 1,
"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/132.0.0.0 Safari/537.36",
"sec-ch-ua: "Not A(Brand";v="8", "Chromium";v="132", "Google Chrome";v="132",
"sec-ch-ua-mobile": "?0",
"sec-ch-ua-platform": "Windows"
