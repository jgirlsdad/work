# %%
from funcs import *
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from funcs import *
#
# File \\wsl.localhost\Ubuntu-24.04\home\joe\work\funcs.py:14
#       1 """
#       2 This module contains functions to interact with the Colorado Information Marketplace (CIM) and Google Sheets.
#       3   ### df = getActivityLog((bic_etl_home: str) -> 'pd.DataFrame')
#    (...)     11
#      12 """
#      13 import json,requests, pandas as pd, os
# ---> 14 from google.oauth2 import service_account
#      15 from googleapiclient.discovery import build
#      16 import requests
#
# ModuleNotFoundError: No module named 'google.oauth2'
