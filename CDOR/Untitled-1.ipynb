# %%
import pandas as pd

# %%
files = ['Recently_Expired_and_Surrendered _Liquor_Licenses_4.04.2023.xlsx',  
'Recently_Expired_and_Surrendered _Liquor_Licenses_5.09.2023.xlsx',   
'Recently_Expired_and_Surrendered _Liquor_Licenses_6.05.2023.xlsx',  
'Recently_Expired_and_Surrendered _Liquor_Licenses_7.13.2023.xlsx',   
'Recently_Expired_and_Surrendered _Liquor_Licenses_8.2.2023.xlsx',    
'Recently_Expired_and_Surrendered _Liquor_Licenses_9.7.2023.xlsx'    
]

files2 = ["Recently_Approved_Liquor_Licenses_4.04.2023.xlsx",
 "Recently_Approved_Liquor_Licenses_5.09.2023.xlsx",
 "Recently_Approved_Liquor_Licenses_6.05.2023.xlsx",
 "Recently_Approved_Liquor_Licenses_7.13.2023.xlsx",
 "Recently_Approved_Liquor_Licenses_8.2.2023.xlsx",
 "Recently_Approved_Liquor_Licenses_9.7.2023.xlsx"
    
]

files3 = ["All_State_Liquor_Licenses_4.04.2023.xlsx",
 "All_State_Liquor_Licenses_5.09.2023.xlsx",
 "All_State_Liquor_Licenses_6.05.2023.xlsx",
 "All_State_Liquor_Licenses_7.13.2023.xlsx",
 "All_State_Liquor_Licenses_8.2.2023.xlsx",
 "All_State_Liquor_Licenses_9.7.2023.xlsx"
    
]

# %%
columns = []
for file in files3:
    df = pd.read_excel(f"~/bic_etl/cdor/regulations_liquor/data_source/{file}",engine="openpyxl")
    columns.append(sorted(list(df.columns)))

# %%
columns
# Out:
# [['CITY',
#   'DOING BUSINESS AS',
#   'EXPIRES',
#   'LICENSE TYPE',
#   'LICENSEE NAME',
#   'STATE',
#   'STREET ADDRESS',
#   'ZIP',
#   'license_no'],
#  ['CITY',
#   'DOING BUSINESS AS',
#   'EXPIRES',
#   'LICENSE TYPE',
#   'LICENSEE NAME',
#   'STATE',
#   'STREET ADDRESS',
#   'ZIP',
#   'license_no'],
#  ['CITY',
#   'DOING BUSINESS AS',
#   'EXPIRES',
#   'LICENSE TYPE',
#   'LICENSEE NAME',
#   'STATE',
#   'STREET ADDRESS',
#   'ZIP',
#   'license_no'],
#  ['CITY',
#   'DOING BUSINESS AS',
#   'EXPIRES',
#   'LICENSE TYPE',
#   'LICENSEE NAME',
#   'STATE',
#   'STREET ADDRESS',
#   'ZIP',
#   'license_no'],
#  ['CITY',
#   'DOING BUSINESS AS',
#   'EXPIRES',
#   'LICENSE TYPE',
#   'LICENSEE NAME',
#   'STATE',
#   'STREET ADDRESS',
#   'ZIP',
#   'license_no'],
#  ['CITY',
#   'DOING BUSINESS AS',
#   'EXPIRES',
#   'LICENSE TYPE',
#   'LICENSEE NAME',
#   'STATE',
#   'STREET ADDRESS',
#   'ZIP',
#   'license_no']]

# %%
for nn in range(len(columns[0])):
   for mm in range(len(columns)):
     print(f"{columns[mm][nn]:>20s} : ",end="")
   print(" ")
# Out:
#                 CITY :                 CITY :                 CITY :                 CITY :                 CITY :                 CITY :
#    DOING BUSINESS AS :    DOING BUSINESS AS :    DOING BUSINESS AS :    DOING BUSINESS AS :    DOING BUSINESS AS :    DOING BUSINESS AS :
#           ISSUE DATE :           ISSUE DATE :           ISSUE DATE :           ISSUE DATE :           ISSUE DATE :           ISSUE DATE :
#            LICENSE # :            LICENSE # :            LICENSE # :            LICENSE # :            LICENSE # :            LICENSE # :
#         LICENSE TYPE :         LICENSE TYPE :         LICENSE TYPE :         LICENSE TYPE :         LICENSE TYPE :         LICENSE TYPE :
#        LICENSEE NAME :        LICENSEE NAME :        LICENSEE NAME :        LICENSEE NAME :        LICENSEE NAME :        LICENSEE NAME :
#                STATE :                STATE :                STATE :                STATE :                STATE :                STATE :
# ...

# %%
columns[-2:]
# Out:
# [['CITY',
#   'DOING BUSINESS AS',
#   'ISSUE DATE',
#   'LICENSE #',
#   'LICENSE TYPE',
#   'LICENSEE NAME',
#   'STATE',
#   'STREET ADDRESS',
#   'ZIP'],
#  ['City',
#   'Company Name',
#   'DBA',
#   'License #',
#   'License Status',
#   'License Type',
#   'State',
#   'Street',
#   'Zip',
#   'expiration_date']]
