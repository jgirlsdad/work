# %%
import pandas as pd

# %%
df= pd.read_csv("/home/joe/bic_etl/cdor/revenue_marijuana/data_source/State Retail Marijuana Sales Tax Revenue by County in Colorado County Report.csv",header=2)

# %%
df.head()
# Out:
#   Revenue Month  Revenue Year     County Medical Marijuana \nState Sales Tax  \
# 0             4        2025.0      Total                           $230,638
# 1             4        2025.0      Adams                             $4,995
# 2             4        2025.0    Alamosa                                  NR
# 3             4        2025.0   Arapahoe                             $8,447
# 4             4        2025.0  Archuleta                                 NaN
#
#   Retail Marijuana \nState Sales Tax ²  \
# 0                                  NaN
# 1                                  NaN
# 2                                  NaN
# 3                                  NaN
# 4                                  NaN
#
#   State Share of Retail Marijuana Sales Tax ³
# 0                                $15,119,875
# 1                                 $1,465,678
# 2                                         NaN
# 3                                 $1,964,953
# ...

# %%
df.columns
# Out:
# Index(['Revenue Month', 'Revenue Year', 'County',
#        'Medical Marijuana \nState Sales Tax',
#        'Retail Marijuana \nState Sales Tax ²',
#        'State Share of Retail Marijuana Sales Tax ³'],
#       dtype='object')

# %%
df.columns = df.columns.str.replace(' ', '_')

# %%
df.columns=df.columns.str.replace('\n', '')

# %%
df.columns
# Out:
# Index(['Revenue Month', 'Revenue Year', 'County',
#        'Medical Marijuana State Sales Tax',
#        'Retail Marijuana State Sales Tax ²',
#        'State Share of Retail Marijuana Sales Tax ³'],
#       dtype='object')

# %%
df.replace(
    '

# %%
dfCim=pd.read_csv("https://data.colorado.gov/resource/v9m8-x8dh.csv?$limit=1000000")

# %%
dfCim.shape
# Out:
# (5599, 9)

# %%
dfCim.head()
# Out:
#    month  year    county  med_sales_tax med_code  retail_sales_tax  \
# 0      5  2023      Bent            NaN       NR               NaN
# 1      5  2023      Mesa            NaN       NR               NaN
# 2      5  2023     Adams        10424.0      NaN               NaN
# 3      5  2023    Pitkin            NaN       NR               NaN
# 4      5  2023  Huerfano            NaN      NaN               NaN
#
#   retail_code  state_share_retail_tax state_share_blank_code
# 0         NaN                 41784.0                    NaN
# 1         NaN                355473.0                    NaN
# 2         NaN               1413261.0                    NaN
# 3         NaN                103985.0                    NaN
# 4         NaN                 58264.0                    NaN

# %%
dfCim.columns
# Out:
# Index(['month', 'year', 'county', 'med_sales_tax', 'med_code',
#        'retail_sales_tax', 'retail_code', 'state_share_retail_tax',
#        'state_share_blank_code'],
#       dtype='object')
