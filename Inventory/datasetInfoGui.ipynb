# %% [markdown]
# # datasetInfoGui

# %% [markdown]
# ## Libraries

# %%
To create a new Jupyter Notebook, follow these steps:

1. **Install Jupyter Notebook (if not already installed):**
    Ensure you have Jupyter Notebook installed. You can install it using pip:
    ```bash
    pip install notebook
    ```

2. **Launch Jupyter Notebook:**
    Open a terminal or command prompt and run:
    ```bash
    jupyter notebook
    ```
    This will open the Jupyter Notebook interface in your default web browser.

3. **Create a New Notebook:**
    - In the Jupyter Notebook interface, navigate to the directory where you want to create the notebook.
    - Click the **"New"** button on the right-hand side of the page.
    - Select **"Python 3"** (or any other kernel you want to use) from the dropdown menu.
    - A new notebook will open in a new tab.

4. **Save the Notebook:**
    - Click on the notebook's title (e.g., "Untitled") at the top of the page to rename it.
    - Save your work using **File > Save and Checkpoint** or by pressing `Ctrl+S`.

That's it! You now have a new Jupyter Notebook ready for use.

# %%
from sodapy import Socrata
import pandas as pd
import json,csv
import os,inspect,sys
from chlorophyll import CodeView
from tkinter import Tk
import tkinter as tk
from tkinter import ttk,Button,Label
from datetime  import datetime
import PySimpleGUI as sg
from difflib import SequenceMatcher
import pygments.lexers
import pytz
import glob
from croniter import croniter
from cron_descriptor import get_description, ExpressionDescriptor
os.environ["BROWSER"] = "google-chrome"
import webbrowser
browsers = webbrowser._tryorder
print("Browsers detected:", browsers)
today = datetime.today()
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', None)
cim_url_query = 'data.colorado.gov'
datasets = None
tody = datetime.today()
#today=f"{tody.year}-{tody.month:02d}-{tody.day:02d}"    
from google.oauth2 import service_account
from googleapiclient.discovery import build
import requests
import gspread
from oauth2client.service_account import ServiceAccountCredentials
import seaborn as sns,matplotlib.pyplot as plt
import matplotlib.dates as mdates

bic_etl_home = os.getenv('bic_etl_home')
from matplotlib.backends.backend_tkagg import FigureCanvasTkAgg

from matplotlib.ticker import MaxNLocator
from matplotlib.ticker import MultipleLocator
import requests
from requests.auth import HTTPBasicAuth


cimDatasets = {}
bicHome = "/home/joe/bic_etl"
allDatasets=[]


with Socrata(cim_url_query, None) as client:
    datasets = client.datasets()
    for dataset in datasets:
        allDatasets.append(dataset)
        if dataset['owner']['display_name'] == 'Colorado Information Marketplace':
            title=dataset["resource"]["name"]
            cimDatasets[title]=dataset

print("DONE")

# %% [markdown]
# ## Functions

# %%
def find_files_recursive(directory):
    # This function finds all files recursively in a given directory
    return glob.glob(f'{directory}/**/run_etl.json', recursive=True)

def decodeExtract(extract):
    
    prog=""
    lang=""
    if 'language' in extract:
        lang=extract['language']
            
    if 'file' in extract:
        prog=extract['file']
        
    else:
        print("No Prgram",lang,title,file)
    opts={}
    if 'options' in extract:
        lang=extract['language']
        for opt in extract['options']:
            opt=opt.strip()
            indx=opt.find(" ")
            o=opt[:indx]
            opts[o]= opt[indx+1:]

    return lang,prog,opts


def processRun_etls(directory_path='/home/joe/bic_etl'): 
## Get all run_etl.json files
    files = find_files_recursive(directory_path)
    
    datasets={}
    noEx=0
    groups={}
    for file in files:
        ll=len(file)
        group=file[18:-13]
        fin=open(file)
        infos = json.load(fin)
        fin.close()
        title=""
        extract=""
        for info in infos: 
            if 'title' in info:
                title=info['title']
                datasets[title]={}
                datasets[title]['extract']={}
                datasets[title]['extract']['language']=''
                datasets[title]['extract']['program']=''
                datasets[title]['extract']['options']={}
                datasets[title]['group']=group
                if group not in groups:
                    groups[group]=[]
                groups[group].append(title)
                if 'extract' in info:
                    extract=info['extract']
                    if isinstance(extract,dict):
                       lang,prog,opts=decodeExtract(extract)
                       datasets[title]['extract']['language']=lang
                       datasets[title]['extract']['program']=prog
                       datasets[title]['extract']['options']=opts
                    elif isinstance(extract,list):
                        for infoL in extract: 
                            lang,prog,opts=decodeExtract(infoL)
                            datasets[title]['extract']['language']=lang
                            datasets[title]['extract']['program']=prog
                            datasets[title]['extract']['options']=opts
                    else:
                        print("UNK",type(info))
        
            else:
                print("No Title",file)
    return datasets,groups

def getUrlAddresses(datasets):
    hist={}
    addresses={}
    options={}
    specOpts={}
    specOpts["general/scripts/request_url.js"]={}
    specOpts["general/scripts/request_url.js"]["-u"]="-f"
    
    specOpts["general/scripts/sftp_extract.js"]={}
    specOpts["general/scripts/sftp_extract.js"]["-h"]="-f"
    specOpts["general/scripts/sftp_extract.js"]["none"]="-f"
    
    specOpts["cdos/general/scripts/sftp_extract.js"]={}
    specOpts["cdos/general/scripts/sftp_extract.js"]["none"]="-f"
    
    lookupNotFound = {
    'bea/scripts/bea_msa_api_reader.py':['https://apps.bea.gov/api/data'],
    'denver/scripts/get_data.py':['https://www.denvergov.org/content/dam/denvergov/Portals/covid19/documents/Denver-Approved-Patio-Expansion-List.xlsx'],
    'scripts/extract_liquor_files.py':'https://sbg.colorado.gov/liquor-license-lists',
    'county_sales_extract.py':['https://docs.google.com/spreadsheets/d/1br_cwfHy24d2R2bcXacb2KarOIBKGrbR/export?format=csv'],
    'scripts/county_salestax_extract.py':['https://docs.google.com/spreadsheets/d/1EhlDIrXjJdmg_ob2eMFeN5xtyvTq2jtr/export?format=csv'],
    'scripts/tax_fee_extract.py':['https://docs.google.com/spreadsheets/d/1e8hnG64Vkg9ffgkNpKQ1kzPsXNbGjG2X/export?format=csv'],
    'scripts/state_mar_sales_extract.py':['https://docs.google.com/spreadsheets/d/1wE7Z_1q2zxL7-kP0AqlUvL731U3Aui1l/export?format=csv'],
    'scripts/city_extract.py':['https://docs.google.com/spreadsheets/d/1wo4WKzvlfdw47_3841jD2RUibbDwos3L/export?format=csv','https://docs.google.com/spreadsheets/d/1WI2jvRCzBqYFIPA2vsUmCjHedKCQD911/export?format=csv'],
    'scripts/county_extract.py':['https://docs.google.com/spreadsheets/d/1irLP8K7jREdDgIiamgZ2MiTbkeMX5lrM/export?format=csv'],
    'scripts/extract_scripts/citybyindustry_extract.py':['https://docs.google.com/spreadsheets/d/1ZKc0olDlChHyRiLlxL3ECxKqBYtyaUaB/export?format=csv','https://docs.google.com/spreadsheets/d/1E6VqKiPnUD3LMnrSBy1aEYSc4QsU6Y9v/export?format=csv'],
    'scripts/extract_scripts/industry_extract.py':['https://docs.google.com/spreadsheets/d/{1WANzZQFE57J73daXvo1xu4mITy-1DmuP/export?format=csv','https://docs.google.com/spreadsheets/d/1cmTJ4ZRAjBFfevT0hyCatUXDIzIG393I/export?format=csv'],
    'scripts/extract_scripts/countybyindustry_extract.py':['https://docs.google.com/spreadsheets/d/1CI66-qv0ooK93asc21VyV-tJiYSc2J3c/export?format=csv','https://docs.google.com/spreadsheets/d/1kybUGf02krqwyl8yBPHnTbn0iQT4Cnnz/export?format=csv'],
    'scripts/extract_liquor_files.py':['https://sbg.colorado.gov/liquor-license-lists']
    }
    
    
    noProg={}
    for title,dct in datasets.items():
        if 'group' in dct:
            group=dct['group']
        else:
            group=""
        if 'extract' in dct:
            if 'language' in dct['extract']:
                lang=dct['extract']['language']
                prog=dct['extract']['program']
                if lang not in hist:
                    hist[lang]={}
                if prog not in hist[lang]:
                    hist[lang][prog]=0
                hist[lang][prog]+=1
    
                if prog not in addresses:
                    addresses[prog]={}
                if 'options' in dct['extract']:
                    if prog in specOpts:
                        o=list(specOpts[prog].keys())[0]
                        fOpt=specOpts[prog][o]
                        ff = dct['extract']['options'][fOpt]  
                        if o in dct['extract']['options']:
                            a=dct['extract']['options'][o]
                        else:
                            if prog == "general/scripts/sftp_extract.js":
                              a="ftps.sos.state.co.us"
                            else:
                              a=""
                    else:
                        ff=""
                        o=""
                        a=""
                        if prog in lookupNotFound:
                            a = lookupNotFound[prog]
                        else:
                            if prog not in noProg:
                                noProg[prog]={}
                            noProg[prog]['group']=group
                        
                    if isinstance(a,str):
                        b=[]
                        b.append(a)
                    else:
                        b=a
                    for a in b: 
                        if a not in addresses[prog]:
                            addresses[prog][a]={}
                        if ff not in addresses[prog][a]:
                           addresses[prog][a][ff]={}
                        
                        if title not in addresses[prog][a][ff]:
                           addresses[prog][a][ff][title]={}
                            
                           addresses[prog][a][ff][title]['count']=0
                           addresses[prog][a][ff][title]['group']=group
                        
                        
                    addresses[prog][a][ff][title]['count']+=1
##  Create a DataFrame
    programs=[]
    address=[]
    files=[]
    counts=[]
    titles=[]
    groups=[]
    for p,dct in addresses.items():
        for o,dct2 in dct.items():   
            for f,dct3 in dct2.items():
                for t,dct4 in dct3.items():
                    
                    programs.append(p)
                    address.append(o)
                    files.append(f)
                    counts.append(dct4['count'])
                    groups.append(dct4['group'])
                    
                    titles.append(t)
    df = pd.DataFrame({
        "Title":titles,
        "Group":groups,
        "Program":programs,
        "Address":address,
        "File":files,
        "Count":counts})
    return addresses,df

## Collect CRON Info from cron File

def getCronInfo(cron_file_path):
    fin=open(cron_file_path)
    lines=fin.readlines()
    crons={}
    for line in lines:
        if line[0:1] != "#" and line[0:1] != " " and len(line) > 2:
            line=line.strip()
            spl=line.split()
            crn=' '.join(spl[:5])
            rest = ' '.join(spl[5:])
            
            crons[rest]=crn
    return crons

def decodeCron(cron_file):
    hist={}
    cronGroups={}
    crons=getCronInfo(cron_file)
    for inf,crn in crons.items():
    
        desc = get_description(crn)
        spl=inf.split()
        lang=spl[0]
        prg=spl[1]
        indxP=inf.find("-p")
        if indxP > -1:
           tmp=inf[indxP+2:].lstrip()
           end=tmp.find(" ")
           grp=tmp[:end]
        else:
            grp=""
    
        indxT=inf.find("-t")
        if indxT > -1:
           tmp=inf[indxT+2:].lstrip()
           start = tmp.find('"')
           end=tmp[start+1:].find('"')
           titl=tmp[start+1:end+1]
        else:
            titl="ALL"
        if grp not in cronGroups:
            cronGroups[grp]={}
        cronGroups[grp][titl]=desc
        print(grp,titl)     
        if lang not in hist:
            hist[lang]={}
        if prg not in hist[lang]:
            hist[lang][prg]=0
        hist[lang][prg]+=1
    return cronGroups

## Combine Dataset ETL Info and CRON Info 
def addCronInfo(row):
    title=row['Title']
    group=row['Group']
#    print(group,title)
    if group in cronGroups:
        dct=cronGroups[group]
        if title in dct:
            cron=cronGroups[group][title]
        elif "ALL" in dct:
            cron=cronGroups[group]["ALL"]
        else:
            cron="Unknown"   
            
        # for how,crn in dct.items(): 
        #     print("  ",how,crn)
        #     if title in cronGroups[group]:
        #        cron=cronGroups[group][title]
        #        break
        #     elif how == "ALL":
        #         cron=crn
        #         break
        #     else:
        #         cron="Unknown"
        #         print("    Unknown ",how,title,crn)

    else:
        cron="No Group Found"
    return cron

# %% [markdown]
# ## Activity Functions

# %%
def getActivityLog():
    flog=open(f"{bic_etl_home}/general/datasync/config.json")
    info = json.load(flog)
    username=info['username']
    password=info['password']
    api=info['appToken']
#    "$where": "created_at > '2023-01-01T00:00:00' and acting_user_name = 'Colorado Information Marketplace'"
    
    # URL of the login form
    query = {
    "$where": "created_at > '2023-01-01T00:00:00' and acting_user_name = 'Colorado Information Marketplace'"
    }
    login_url = 'https://data.colorado.gov/api/activity_log.json?$limit=6000000'
    response=requests.get(login_url,auth=(username, password),params=query)
    if response.status_code == 200:
      
#        activity_log=json.loads(response.text)
        print(type(response.text))
    else:
        print("Failed to download Activity Log")
        print(f"Error: {response.status_code}")
        print(f"Message: {response.text}")
    return pd.DataFrame(json.loads(response.text))


def createReport(summary,lastActivityDate):
    report={}
    for title,dct in summary.items():
        if "Expected Update" in dct: 
            expt = dct["Expected Update"]
            lastSuccess= dct["Activity Data Success"]
            if expt not in report:
                report[expt]={}
                report[expt]["Pass"]=0
                report[expt]["Fail"]=0
                report[expt]["Total"]=0
            
            report[expt]["Total"]=0
            
            if lastSuccess == "NA":
                report[expt]["Fail"]+=1
                what="Fail"
            else:
                lastSuccessn=int(lastSuccess)
                exptn=int(expt)
                if exptn >= lastSuccessn:
                   report[expt]["Pass"]+=1
                   what="Pass"
                else:
                   report[expt]["Fail"]+=1
                   what="Fail"
            print(f"{expt:4d} {str(lastSuccess):4s}  {what:4s}  {title}")
        else:
            print("ROH ROH ",title,dct)

    tody=datetime.today().date()
    ndf=tody-lastActivityDate

    mapped = {1:"Daily",7:"Weekly",31:"Monthly",90:"Quarterly",365:"Annual"}
    fout=open("/home/joe/reportSummary.txt","w")
    fout.write(f"Date: {datetime.today().date()}\n")
    fout.write(f"Last Date in Activity Log: {lastActivityDate}\n")
    fout.write(f"Age of  Activity Log (Days): {ndf.days}\n")
    
    
    sumr=[]
    for how,dct in report.items():
        print(f"{mapped[how]:10s}  Passed: {dct['Pass']:4d}  Fail:{dct['Fail']:4d}")
        fout.write(f"{mapped[how]:10s}  Passed: {dct['Pass']:4d}  Fail:{dct['Fail']:4d}\n")
        sumr.append([mapped[how],dct['Pass'],dct['Fail']])
        
    fout.close()
 
    layout = [
         [sg.Text(f"Summary Report for {datetime.today()}",font='Courier 25 bold ')],
         [sg.Button('Quit',font='Courier 15 bold ')],
         [sg.Text(f"Last Date in Activity Log {lastActivityDate}",font='Courier 15 bold ')],
         [sg.Text(f"Activity Log Age in Days {ndf.days}",font='Courier 15 bold ')],
         [sg.Text("Report Output to File: /home/joe/reportSummary.txt",font='Courier 15 bold ')],
         [sg.Table(values=sumr,headings=["Cadence","Pass","Fail"],font='Courier 15 bold ')]
         ]
   

   
    window2 = sg.Window('Automated Group Info', layout,margins=(25,25),finalize=True,resizable=True,background_color="#cc4400")
    return report



def convDateTime(string,format,type):
   if type == 1: # Convert Date Time string to Date Time Object
        dateTime=datetime.strptime(string,format)
        # Convert Zulu Time to Mountain Time
        if format.find("Z") > -1:
            utc_timezone = pytz.utc
            zulu_time = utc_timezone.localize(dateTime)
            
            # Define the local timezone (e.g., US/Eastern)
            local_timezone = pytz.timezone("US/Mountain")
            
            # Convert the Zulu time (UTC) to local time
            dateTime = zulu_time.astimezone(local_timezone)
            # Convert the offset-aware datetime to offset-naive by removing the timezone info
            dateTime=dateTime.replace(tzinfo=None)
        return dateTime
       

def getCimInfo(df):
    notFound=[]
    mapped = {
    "Manual - annual":365,       
    "Automated - monthly":31,    
    "Automated - daily":1,      
    "Automated - weekly":7,      
    "Manual - quarterly":90,                          
    "Manual - monthly":31}        
    
    tody = datetime.today()
    hist={}
    for indx,row in df.iterrows():
        title=row["Dataset Title"]
        expctdUpdt = row["Update Type"]
        nexpctdUpdt=mapped[expctdUpdt]
        if title  in cimDatasets:    
            cimUpdtMeta = cimDatasets[title]["resource"]["updatedAt"]
            cimUpdtData = cimDatasets[title]["resource"]["data_updated_at"]
            
            cimUpdtMeta=convDateTime(cimUpdtMeta, "%Y-%m-%dT%H:%M:%S.%fZ",1)
            cimUpdtData=convDateTime(cimUpdtData, "%Y-%m-%dT%H:%M:%S.%fZ",1)
      
            diffMeta = tody-cimUpdtMeta
            diffData = tody-cimUpdtData
            typ=cimDatasets[title]['resource']['type']
            diffMeta=round(diffMeta.total_seconds()/(24 * 60 * 60))
            diffData=round(diffData.total_seconds()/(24 * 60 * 60))
            if title not in hist:
                hist[title]={}
            hist[title]["Meta"]=diffMeta
            hist[title]["Data"]=diffData
            hist[title]["Expected"]=nexpctdUpdt
            hist[title]["Type"]=typ
            
    
        else:
            notFound.append(title)
    return hist


def getDatasetTrackerInfo(bic_etl_home):

    scope = ['https://www.googleapis.com/auth/spreadsheets.readonly',
                 "https://www.googleapis.com/auth/drive.file",
                      "https://www.googleapis.com/auth/drive"]
    
    #creds = ServiceAccountCredentials.from_json_keyfile_name('../../scripts/client_secret.json',
    #    scope)
    creds = ServiceAccountCredentials.from_json_keyfile_name(os.path.join(bic_etl_home, 'general', 'scripts','client_secret.json'),scope)
    
    client = gspread.authorize(creds)
    tracker = client.open('BIC Dataset Tracker').worksheet(
    'PublishedData')
    dfTracker = pd.DataFrame(tracker.get_all_records(head=2))
    return dfTracker

    
def analysis(hist,dfActivity):
    data=[]
    which="Data"
    logInfo={}
    counts=[]
    fails=["DataUpdate.Import.Failure","DataUpdate.Replace.Failure","DataUpdate.Import.Failure"]
    success=["DataUpdate.Replace.Success"]
    failsSched=["ScheduleFailedFatally"]
    successSched=["ScheduleSucceeded"]
    tody=datetime.today()
    summary={}
    allAuto={}
    lastActivityDate=None
    for title,dct in sorted(hist.items(), key=lambda item: item[1][which]):
       
        if dct[which] > dct["Expected"]:
         #   data.append([title,dct["Data"]-dct["Expected"],dct["Data"],dct["Expected"],dct["Meta"]])
            tmp=dfActivity.loc[dfActivity["affected_item"] == title]
            summary[title]={}
            allAuto[title]={}
            
            if tmp.shape[0] > 0:
                for indx,row in tmp.iterrows(): 
                    activity = row["activity_type"]
                    cdate=row["created_at"]
                    cdate = convDateTime(cdate, "%Y-%m-%dT%H:%M:%S.%fZ",1)
                    ndays=round((tody-cdate).total_seconds()/(24 * 60 * 60))
                    cdate=cdate.date()
                    if not lastActivityDate:
                        lastActivityDate=cdate
                    else:
                        if cdate > lastActivityDate:
                            lastActivityDate=cdate
                    if title not in logInfo:
                        logInfo[title]={}
                    if activity not in logInfo[title]:
                       logInfo[title][activity]={}
                    # if cdate not in logInfo[title][activity] = {}
                    #     logInfo[title][activity][cdate]={}
                    logInfo[title][activity][cdate]=ndays
                       
                dataFailsMax=None
                dataSuccessMax=None
                dataSuccessSchedMax=None
                dataFailsSchedMax=None
    
                
            
                for act,dct2 in logInfo[title].items():
                    mx=max(dct2.keys())
                    mn=min(dct2.keys())
            
                    if act in fails:
                        if not dataFailsMax:
                            dataFailsMax=mx
                        else:
                            if mx > dataFailsMax:
                                dataFailsMax=mx
                    elif act in success:
                        if not dataSuccessMax:
                            dataSuccessMax=mx
                        else:
                            if mx > dataSuccessMax:
                                dataSuccessMax=mx
                    elif act in failsSched:
                        if not dataFailsSchedMax:
                            dataFailsSchedMax=mx
                        else:
                            if mx > dataFailsSchedMax:
                                dataFailsSchedMax=mx
                    elif act in successSched:
                        if not dataSuccessSchedMax:
                            dataFailsSuccessMax=mx
                        else:
                            if mx > dataSuccessSchedMax:
                                dataSuccessSchedMax=mx  
                                
                tody=datetime.today()
                if dataFailsMax:
                    dataFailsNdays=round((tody.date() - dataFailsMax).total_seconds() / (24 * 3600))
                else:
                    dataFailsNdays="NA"
        
                if dataSuccessMax:
                    dataSuccessNdays=round((tody.date() - dataSuccessMax).total_seconds() / (24 * 3600))
                else:
                    dataSuccessNdays="NA"
        
                if dataFailsSchedMax:
                    dataFailsSchedNdays=round((tody.date() - dataFailsSchedMax).total_seconds() / (24 * 3600))
                else:
                    dataFailsSchedNdays="NA"
        
                if dataSuccessSchedMax:
                    dataSuccessSchedNdays=round((tody.date() - dataSuccessSchedMax).total_seconds() / (24 * 3600))
                    
                else:
                    dataSuccessSchedNdays="NA"

                what=""
                expt=dct["Expected"]
                if dataSuccessNdays == "NA":
                    what="Fail"
                else:
                    lastSuccessn=int(dataSuccessNdays)
                    exptn=int(expt)
                    if exptn >= lastSuccessn:
                       what="Pass"
                    else:
                       what="Fail"

                summary[title]["Data-Expected"]= dct["Data"]-dct["Expected"]
                summary[title]["Data Update"]= dct["Data"]
                summary[title]["Expected Update"]= dct["Expected"]
                summary[title]["Meta Update"]= dct["Meta"]
                summary[title]["Activity Data Success"]= dataSuccessNdays
                summary[title]["Activity Data Fail"]= dataFailsNdays
                summary[title]["Activity Scheduled Success"]= dataSuccessSchedNdays
                summary[title]["Activity Scheduled Fail"]= dataFailsSchedNdays     

                allAuto[title]["Data-Expected"]= dct["Data"]-dct["Expected"]
                allAuto[title]["Data Update"]= dct["Data"]
                allAuto[title]["Expected Update"]= dct["Expected"]
                allAuto[title]["Meta Update"]= dct["Meta"]
                allAuto[title]["Activity Data Success"]= dataSuccessNdays
                allAuto[title]["Activity Data Fail"]= dataFailsNdays
                allAuto[title]["Activity Scheduled Success"]= dataSuccessSchedNdays
                allAuto[title]["Activity Scheduled Fail"]= dataFailsSchedNdays     
                allAuto[title]["Status"]= 'fail'
                allAuto[title]["Type"]= dct["Type"]
                
                
                data.append([title,dct["Data"]-dct["Expected"],dct["Data"],dct["Expected"],dct["Meta"],what,dataSuccessNdays,dataFailsNdays,dataSuccessSchedNdays,dataFailsSchedNdays])
            else:
                print("NO INFO FOR ",title)
        else:
                allAuto[title]={}
                allAuto[title]["Status"]= 'pass'
                allAuto[title]['Expected Update'] = dct["Expected"]
                allAuto[title]["Type"]= dct["Type"]
             
    return logInfo,data,summary,lastActivityDate,allAuto

    
def analyzeActivityLog(title,logInf):
    try:
        histActivity={}
        acts=[]
        durs=[]
        mins=[]
        maxs=[]
        counts=[]
        for act,dct2 in logInf.items():
            mx=max(dct2.keys())
            mn=min(dct2.keys())
            acts.append(act)
            mins.append(mn)
            maxs.append(mx)
       #     dur=(mx-mn).total_seconds() / (24 * 3600)
            dur=(mx-mn)
            counts.append(len(dct2.keys()))
            durs.append(dur)
            if act not in histActivity:
                histActivity[act]=0
            histActivity[act]+=1
                             
                                         
        dfa=pd.DataFrame({"Activity":acts,"Duration":durs,"Start":mins,"Ends":maxs,"Counts":counts})
        fig, ax = plt.subplots()
        #df['duration'] = (df['end'] - df['start']).dt.total_seconds() / (24 * 3600)
    #    fig.figure(figsize=(10, 6))
        sns.set(style="whitegrid")
        
        # Plot rectangles for each task
        for index, row in dfa.iterrows():
            plt.barh(index, row['Duration'], left=row['Start'], height=0.4, edgecolor='black')
            start=row["Start"]
            duration=row["Duration"]
            count=row["Counts"]
            ax.text(start + duration / 2, index, f"{count}", va='center', ha='center', color='white', fontsize=9)
        
        # Setting labels
        ax.set_yticks(range(len(dfa['Activity'])), dfa['Activity'])
        ax.set_xlabel('Date')
        ax.set_title(f"Activity Log for {title}")
        
        # Format the x-axis to show dates
        ax.xaxis.set_major_locator(mdates.DayLocator())
        ax.xaxis.set_major_locator(MaxNLocator(nbins=5))
        
        ax.xaxis.set_major_locator(mdates.MonthLocator())
        ax.xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m'))
    
    # Set the formatter to display the date in a readable format (Year-Month-Day)
        # Rotate and align the x labels for better readability
        plt.xticks(rotation=90, ha="right")
      #  ax.set_xticklabels(ax.get_xticks(), rotation=90)
        # Show grid lines for better readability
        ax.grid(False, linestyle='--', alpha=0.5)
        ax.set_xlim(left=None, right=tody)
        # Show the plot
        fig.tight_layout()
    
        layout = [
            [sg.Text('Actvity Log Analysis')],
            [sg.Canvas(key='-CANVAS-')],
            [sg.Button('Quit')]
        ]
        
        # Create the PySimpleGUI window
        window = sg.Window('Activity Log Analysis', layout, finalize=True)
        
        # Draw the plot on the canvas
    #    draw_figure(window['-CANVAS-'].TKCanvas, fig)
        figure_canvas_agg = FigureCanvasTkAgg(fig, window['-CANVAS-'].TKCanvas)
        figure_canvas_agg.draw()
        figure_canvas_agg.get_tk_widget().pack(side='top', fill='both', expand=1)
    except Exception as err:
        print("Error in Activity Analysis ",err) 

def activeGui():
#   dfActivity = pd.read_csv("Activity_Log_2025-02-03.csv")
   dfActivity = getActivityLog()
   dfTracker=getDatasetTrackerInfo(bic_etl_home)
   dfTrackerNotStatic = dfTracker.loc[~dfTracker["Update Type"].isin(["Static",""])]
   hist=getCimInfo(dfTrackerNotStatic)
   logInfo,data,summary,lastActivityDate,allAuto=analysis(hist,dfActivity)
   header=["Title","Data-Expected","Data Update","Expected Period","Metadata Update","Smell Test","Last Success","Last Failure",
           "Sched Success","Sched Fail"]
   data=sorted(data, key=lambda item: item[1],reverse=True)
 
   layoutS = [
         [sg.Button('Quit',font='Courier 15 bold ')],
         [sg.Text(f"Last Date in Activity Log: {lastActivityDate}",font='Courier 15 bold ')],
         [sg.Text(f"Today: {datetime.today().date()}",font='Courier 15 bold ')],
         [sg.Text(f"Age of Activity Log (Days): {(datetime.today().date()-lastActivityDate).days}",font='Courier 15 bold ')],
       
         [sg.Button("Create Report",key="-REPORT-")],
         [sg.Table(values=data,headings=header,col_widths=[50,15,15,15,15,15,15,15,15,15],cols_justification=["l","c","c","c","c","c","c","c","c","c"],
                   num_rows=30,row_height=40,vertical_scroll_only=False,auto_size_columns=False,
                   enable_events=True, key='-TABLE-',border_width=6,background_color = "#99ccff",
                   alternating_row_color = "#9999ff",font="CENTAUR 10 bold")]
    ]
   layout = [[ sg.Column(layoutS,scrollable=True)]]
   window3 = sg.Window('Activity GUI', layout,finalize=True,resizable=True,background_color="#cc4400")

   sourceDefFile=""  #  this is needed
   vals=[]
   return logInfo,data,summary,lastActivityDate,allAuto

# %% [markdown]
# ## GUI

# %%
def showAutomationGroupButton(group,dct,datasets):
    try:
        back="#cc66ff"
        titles=[]
        frames=[]
        if isinstance(dct,list):
            string=f"{group}\n"
            for nn,title in enumerate(dct):
                cimLink=datasets[title]['link']
                titles.append([sg.Text(f"{nn+1}) ",font='Courier 15 bold '),sg.Button(title,key=f"{cimLink}",metadata=cimLink)])
            ysize=len(titles)*100+100
            frames.append(sg.Frame(f"{group}",[titles],size=(500,ysize),expand_x=True,expand_y=True,font='Courier 20 bold '))
        elif isinstance(dct,dict):
            string=f"{group}\n"
            titles={}
          
            for subgroup,titls in dct.items():
                string+=f"  {subgroup}\n"
                titles=[]
                notFound=[]
                for nn,title in enumerate(titls):
                    if title in datasets:
                       cimLink=datasets[title]['link']
                       titles.append([sg.Text(f"{nn+1}) ",font='Courier 15 bold '),sg.Button(title,key=f"{cimLink}",metadata=cimLink)]) 
                    else:
                        print("RORORORORORORO   Not FOUND ",title)
                        notFound.append(title)
                        cimLink=""
                ysize=len(titles)*40     
                
    
                for title in notFound:
                   cimLink=""
                   titles.append([sg.Text(f"Not Found) ",font='Courier 15 bold '),sg.Text(title)]) 
                frames.append(sg.Frame(subgroup,[titles],pad=(10,10),font='Courier 15 bold '))
            
                    
                
        layoutS = [
             [sg.Text(f"Datasets for {group}",font='Courier 25 bold ')],
             [sg.Button('Quit',font='Courier 15 bold ')],
             ]
        for frame in frames:
            layoutS.append([frame])
        print(layoutS)
        layout = [[ sg.Column(layoutS,scrollable=True,expand_x=True,expand_y=True)]]
        window2 = sg.Window('Automated Group Info', layout,margins=(25,25),finalize=True,resizable=True,background_color="#cc4400")
    except Exception as err:
        print("ERROR ERROR",err)

def showAutomationGroup(group,dct):
    try:
        back="#cc66ff"
        titles=[]
        if isinstance(dct,list):
            string=f"{group}\n"
            for nn,title in enumerate(dct):
                titles.append(f"{nn+1}) {title}")
                string+=f"  {nn+1}) {title}\n"
        elif isinstance(dct,dict):
            string=f"{group}\n"
            for subgroup,titls in dct.items():
                string+=f"  {subgroup}\n"
                for nn,title in enumerate(titls):
                    string+=f"     {nn+1}) {title}\n"
                string+="\n"
                
                
        layoutS = [
             [sg.Button('Quit',font='Courier 15 bold ')],
             [sg.Multiline(string,size=(100,70),font='Courier 15 bold',background_color=back,autoscroll=True)]
             ]
        layout = [[ sg.Column(layoutS,scrollable=True)]]
        window2 = sg.Window('Automated Group Info', layout,finalize=True,resizable=True,background_color="#cc4400")
    except Exception as err:
        print("ERROR ERROR",err)

#############################################

def showInfo(title,dataset,bgc,dfEtlCron):
    try:
        print("BGC=",bgc)
        today = datetime.today()
        local_tz = pytz.timezone("America/Denver")  # Replace with your local timezone

# Convert to local time

        today = today.astimezone(local_tz)
    
        desc=dataset["resource"]["description"]
        w4x4=dataset["resource"]["id"]
        source=dataset["resource"]["attribution"]
        sourceLink=dataset["resource"]["attribution_link"]
        cimLink=dataset['link']
        
        # '2024-12-02T17:35:31.000Z'
        create=datetime.strptime(dataset['resource']['createdAt'],"%Y-%m-%dT%H:%M:%S.%fZ")
        create = create.astimezone(local_tz)
      
        
      #  print("CREATE ",create)
        
        
        if dataset['resource']['metadata_updated_at'] is not None:
          updateMeta=datetime.strptime(dataset['resource']['metadata_updated_at'],"%Y-%m-%dT%H:%M:%S.%fZ")
          # Get the local timezone
          local_tz = pytz.timezone("America/Denver")  # Replace with your local timezone
          localMeta = updateMeta.astimezone(local_tz)
          localToday = today.astimezone(local_tz)
          
          updateMeta=localMeta
          updateMetaDelta= (localToday-localMeta).days
        else:    
            updateMeta=""
            updateMetaDelta=""
            
        if dataset['resource']['data_updated_at'] is not None:         
            updateData=datetime.strptime(dataset['resource']['data_updated_at'],"%Y-%m-%dT%H:%M:%S.%fZ")  
            local_tz = pytz.timezone("America/Denver")  # Replace with your local timezone
            localData = updateData.astimezone(local_tz)
            localToday = today.astimezone(local_tz)
            updateData=localData
            updateDataDelta= (localToday-localData).days

        
        else:
            updateData=""
            updateDataDelta=""
        
        timeDelta=today-create
        timeDelta=timeDelta.days
        t=(20,1)
        back="#cc66ff"
        dates=[]
        dates.append([sg.Text("Creation Date",size=(13,1),font='Courier 15 bold',background_color=bgc),
                      sg.Text(create,size=t,font='Courier 15 bold',background_color=back),
                      sg.Text("Age",size=(13,1),font='Courier 15 bold',background_color=bgc),
                      sg.Text(timeDelta,size=t,font='Courier 15 bold',background_color=back)])
        
        dates.append([sg.Text("Update Data",size=(13,1),font='Courier 15 bold',background_color=bgc),
                      sg.Text(updateData,size=t,font='Courier 15 bold',background_color=back),
                      sg.Text("Days Since Update",size=(13,1),font='Courier 15 bold',background_color=bgc),
                      sg.Text(updateDataDelta,size=t,font='Courier 15 bold',background_color=back)])
                     
        dates.append([sg.Text("Update Meta",size=(13,1),font='Courier 15 bold',background_color=bgc),
                      sg.Text(updateMeta,size=t,font='Courier 15 bold',background_color=back),
                      sg.Text("Days Since Update",size=(13,1),font='Courier 15 bold',background_color=bgc),
                      sg.Text(updateMetaDelta,size=t,font='Courier 15 bold',background_color=back)])

        downloads = dataset['resource']['download_count']
        downloadsRate=downloads/timeDelta
        pageLW=dataset['resource']['page_views']["page_views_last_week"]
        pageLM=dataset['resource']['page_views']['page_views_last_month']
        pageTotal=dataset['resource']['page_views']['page_views_total']
        pageTotalRate=pageTotal/timeDelta
        
        views=[]
        views.append([sg.Text("Page Views - Last Week",size=(23,1),font='Courier 15 bold',background_color=bgc),
                    sg.Text(pageLW,size=(6,1),font='Courier 15 bold',background_color=back)])
    
        views.append([sg.Text("Page Views - Last Month",size=(23,1),font='Courier 15 bold',background_color=bgc),
                    sg.Text(pageLM,size=(6,1),font='Courier 15 bold',background_color=back)])
        
        views.append([sg.Text("Page Views - Total",size=(23,1),font='Courier 15 bold',background_color=bgc),
                    sg.Text(pageTotal,size=(6,1),font='Courier 15 bold',background_color=back),
                    sg.Text("Daily Rate",size=(12,1),font='Courier 15 bold',background_color=bgc),
                    sg.Text(round(pageTotalRate,1),size=(6,1),font='Courier 15 bold',background_color=back)]  
                     )

        views.append([sg.Text("Downloads - Total",size=(23,1),font='Courier 15 bold',background_color=bgc),
                    sg.Text(downloads,size=(6,1),font='Courier 15 bold',background_color=back),
                    sg.Text("Daily Rate",size=(12,1),font='Courier 15 bold',background_color=bgc),
                    sg.Text(round(downloadsRate,1),size=(6,1),font='Courier 15 bold',background_color=back)]  
                     )
       
## ETL-Cron info
        etlCron=[]
        if dfEtlCron.shape[0] > 0:
                    group=list(dfEtlCron["Group"].value_counts().to_dict().keys())[0]
                    prog=list(dfEtlCron["Program"].value_counts().to_dict().keys())[0]
                    cron=list(dfEtlCron["Cron"].value_counts().to_dict().keys())[0]
                    etlCron.append([sg.Text("Automation Group",size=(23,1),font='Courier 15 bold',background_color=bgc),
                                    sg.Text(group,size=(25,1),font='Courier 15 bold',background_color=back)])
                    etlCron.append([sg.Text("Extract Program",size=(23,1),font='Courier 15 bold',background_color=bgc),
                                    sg.Text(prog,size=(55,1),font='Courier 15 bold',background_color=back)])
                    etlCron.append([sg.Text("Automation Cadence",size=(23,1),font='Courier 15 bold',background_color=bgc),
                                    sg.Text(cron,size=(70,1),font='Courier 15 bold',background_color=back)])
                    add = dfEtlCron["Address"].values.tolist()
                    file = dfEtlCron["File"].values.tolist()
                    for nn,addr in enumerate(add):
                        etlCron.append([sg.Text(f"{nn}) Address",size=(23,1),font='Courier 15 bold',background_color=bgc),
                                    sg.Text(addr,size=(70,1),font='Courier 15 bold',background_color=back),
                                    sg.Text(f"File ",size=(23,1),font='Courier 15 bold',background_color=bgc),
                                    sg.Text(file[nn],size=(70,1),font='Courier 15 bold',background_color=back)])
                 
                    
        
        layout = [
             [sg.Button('Quit',font='Courier 15 bold ')],
             [sg.Text(title,auto_size_text=True ,font='Courier 15 bold',background_color=bgc)],
             [sg.Text(desc,auto_size_text=True ,font='Courier 15 bold')],
             [sg.Button("CIM Link",key=f"{cimLink}",metadata=cimLink,enable_events=True)],
             [sg.Text("4x4",auto_size_text=True ,font='Courier 15 bold'),sg.Input(w4x4,font='Courier 15 bold')],
             [sg.Text("Source",auto_size_text=True ,font='Courier 15 bold',background_color=bgc),
              sg.Text(source,auto_size_text=True ,font='Courier 15 bold'),
              sg.Text("Link",auto_size_text=True ,font='Courier 15 bold',background_color=bgc),
              sg.Text(sourceLink,auto_size_text=True ,font='Courier 15 bold')
             ],
           
             [sg.Frame("DATES",[dates],size=(700,100),background_color=bgc )],
             [sg.Frame("VIEW",[views],size=(700,150),background_color=bgc )]
        ]
        if len(etlCron) > 0:
            layout.append([sg.Frame("Automation Info",[etlCron],size=(700,150),background_color=bgc )])
            
        window2 = sg.Window('Info', layout,finalize=True,resizable=True,background_color="#cc33ff")
    except Exception as err:
        print("ERROR ERROR",err)

######################################

def showColumns(title,ds,bgc):
    try:
        back="#cc66ff"
        columns=[]
        for nn,colName in enumerate(ds["resource"]["columns_name"]):
            apiName=ds["resource"]["columns_field_name"][nn]
            dataType=ds["resource"]["columns_datatype"][nn]
            desc=ds["resource"]["columns_description"][nn]
            form=ds["resource"]["columns_format"][nn]
            print(colName,apiName,dataType,desc,form)
            columns.append([colName,apiName,dataType,desc,form])
        
        header=["CIM Name","API Name","Data Type","Description","Format"]
        layoutS = [
             [sg.Button('Quit',font='Courier 15 bold ')],
             [sg.Text('Total Columns',size=(14,1),font='Courier 15 bold',background_color=bgc),
              sg.Text(len(columns),size=(6,1),font='Courier 15 bold',background_color=back)],
             [sg.Table(values=columns,headings=header,cols_justification=["l","l","l","l","l"],
                   num_rows=30,row_height=40,vertical_scroll_only=False,max_col_width=60,
                   enable_events=False, key='-COLUMNS-',display_row_numbers=True,border_width=6,background_color = "#99ccff",
                   alternating_row_color = "#9999ff",font="CENTAUR 13 bold",starting_row_number=1)],
        ]
        layout = [[ sg.Column(layoutS,scrollable=True)]]
        window2 = sg.Window('Column Info', layout,finalize=True,resizable=True,background_color="#cc4400")
    except Exception as err:
        print("ERROR ERROR",err)



def GUI():
    global cim4x4,values,cronGroups
    directory_path="/home/joe/bic_etl"
    datasetsEtlInfo,automationGroups = processRun_etls(directory_path=directory_path)
    newGroups={}
    for group,titles in automationGroups.items():
        spl=group.split("/")
        if len(spl) > 1:
           subGroup = '/'.join(spl[1:])
           group=spl[0]
        else:
           subGroup=""
        if group not in newGroups:
            newGroups[group]={}
        if len(subGroup) > 0:
            newGroups[group][subGroup]=titles
        else:
            newGroups[group]=titles

    print("GEt addresses")
    addresses,df = getUrlAddresses(datasetsEtlInfo) 
    cron_file = '/home/joe/bic_etl/general/cron/cron_file'    
    cronGroups=decodeCron(cron_file)
    df["Cron"] = df.apply(addCronInfo,axis=1)
    dfCronGroup = df.copy()
    frameDataset=[[sg.Text("Choose Dataset "),sg.Combo(sorted(list(cimDatasets.keys())), size=(50,10) , 
                                                 enable_events=True,key='-TITLE-',font='Courier 15 bold')],
            [sg.Checkbox("Show CIM Column Info",key="-CIMCOLUMNS-")]]
    frameGroup=[sg.Text(" Choose Group "),sg.Combo(sorted(list(newGroups.keys())), size=(20,10) , enable_events=True,key='-AUTOGROUP-',font='Courier 15 bold')]
    frameTemporalAnalysis=[sg.Button("Temporal Analysis",key="-TEMPORAL-")]
    layout = [
         [sg.Button('Close',font='Courier 15 bold ')],
         [sg.Frame("Dataset Info",[frameDataset])],
         [sg.Frame("Automation Group Info",[frameGroup])],
         [sg.Frame("Temporal Analysis",[frameTemporalAnalysis])],
        
        #     [sg.Button('Check Meta Updates',font='Courier 15 bold ')]
    ]
    window2 = sg.Window('GUI', layout,finalize=True,resizable=True,background_color="#cc4400")
    print("starting")
    sourceDefFile=""  #  this is needed
    vals=[]
    try: 
        while True:
            wid, event, values = sg.read_all_windows()
            print("EV ",event)
            print(values)
            if event == sg.WIN_CLOSED or event == 'Close':
                window2.close()
                break
            elif event == 'Quit':
                wid.close()
            elif event == "-TITLE-":
                try:
                    print(values)
                    title=values["-TITLE-"]
                    tmp=df.loc[df["Title"] == title]
    
                    print("ETL INFO ",tmp.shape,title)
                    bgc=background_color = window2.TKroot.cget("background")
                #    print(cimDatasets[title])
                    showInfo(title,cimDatasets[title],bgc,tmp)
                    if values["-CIMCOLUMNS-"]:
                        showColumns(title,cimDatasets[title],bgc)
                    
                    ds=cimDatasets[title]
                except Exception as err:
                    print("Error Showing Dataset Info",err)
            elif event == "-AUTOGROUP-":
                autog=values["-AUTOGROUP-"]
                print("AUTOG ",autog)
                showAutomationGroupButton(autog,newGroups[autog],cimDatasets)
            elif event.find("http")  < 3 and event.find("http") > -1:
                url=event
       #         url=wid['-WEBLINK-'].metadata
                print("URL URL URL ",url)
                try: 
                   webbrowser.get("/mnt/c/Program\ Files/Google/Chrome/Application/chrome.exe %s").open(url,new=2)
                except Exception as err:
                    print("ERROR ",err)
            elif event == "-TEMPORAL-": 
                logInfo,data,summary,lastActivityDate,allAuto=activeGui()
            elif event == "-TABLE-":
                bgc=background_color = window2.TKroot.cget("background")
                selected_row_index = values['-TABLE-'][0]
                selected_row_data = data[selected_row_index]
                title=data[selected_row_index][0]
                analyzeActivityLog(title,logInfo[title])
                tmp=df.loc[df["Title"] == title]
                showInfo(title,cimDatasets[title],bgc,tmp)
            elif event == "-REPORT-":
                report=createReport(summary,lastActivityDate)
                
                
            # elif event == "Check Meta Updates":
            #     checkMetaUpdates()
        return newGroups
        
    except Exception as err:
        print("ERROR ",err)
    
newGroups=GUI()
# Out:
# No Title /home/joe/bic_etl/general/example/run_etl.json
# GEt addresses
#  ALL
#
#  ALL
# bls/sm ALL
# boulder ALL
# catalog ALL
# cdos/business/nonprofit ALL
# cdos/business/nonprofit Registration of Charities, Paid Solicitors, Professional Fundraising Consultants, and for-profit Public Benefit Corporations in Colorado
# cdos/business/business Business Entities in Colorado
# cdos/business/business Business Entity Transaction History
# cdos/health ALL
# cdos/lobbyist ALL
# cdos/government ALL
# cdos/business/business Master List in Colorado
# cdos/business/business Trade Names for Businesses in Colorado
# cdos/business/business Trademarks for Businesses in Colorado
# cdos/business/ucc ALL
# cdot/transportation_road_attributes ALL
# cdot/transportation_infrastructure ALL
# cdot/natural_resources ALL
# cdot/tops ALL
# dola/boundaries ALL
# dola/special_districts ALL
# dola/demographics ALL
# cdor/revenue_marijuana ALL
# cdor/retail_reports ALL
# cdor/regulations_liquor ALL
# ceo/useia Gasoline Prices in Colorado
# ceo/useia Natural Gas Prices in Colorado
#  ALL
# starting
# EV  -AUTOGROUP-
# {'-TITLE-': '', '-CIMCOLUMNS-': False, '-AUTOGROUP-': 'cdor'}
# AUTOG  cdor
# RORORORORORORO   Not FOUND  Marijuana Sales Revenue in Colorado
# RORORORORORORO   Not FOUND  Retail Sales Tax Return History in Colorado
# [[<PySimpleGUI.PySimpleGUI.Text object at 0x7f552c060590>], [<PySimpleGUI.PySimpleGUI.Button object at 0x7f552c060690>], [<PySimpleGUI.PySimpleGUI.Frame object at 0x7f552c04f3d0>], [<PySimpleGUI.PySimpleGUI.Frame object at 0x7f552c017890>], [<PySimpleGUI.PySimpleGUI.Frame object at 0x7f552c060450>]]
# EV  Quit
# {}
# EV  Close
# {'-TITLE-': '', '-CIMCOLUMNS-': False, '-AUTOGROUP-': 'cdor'}

# %%
titles=[]
starts=[]
updated=[]
views=[]
downs=[]
for gp,dct in newGroups["cdor"].items():
    for title in dct:
   #     ['createdAt'],'download_count''page_views'
        if title in cimDatasets:
            titles.append(title)
            starts.append(cimDatasets[title]['resource']['createdAt'])
            updated.append(cimDatasets[title]['resource']['data_updated_at'])
            views.append(cimDatasets[title]['resource']['page_views']['page_views_total'])
            downs.append(cimDatasets[title]['resource']['download_count'])
        else:
            print("ROH ROH ",title)
            
df=pd.DataFrame(
    {"Title":titles,
     "Created":starts,
     "Updated":updated,
     "Views":views,
     "Downloads":downs})

df["Created"]=pd.to_datetime(df["Created"])
df["Created"]=df["Created"].dt.date

df["Updated"]=pd.to_datetime(df["Updated"])
df["Updated"]=df["Updated"].dt.date
# Out:
# ROH ROH  Marijuana Sales Revenue in Colorado
# ROH ROH  Retail Sales Tax Return History in Colorado

# %%
df.to_csv("cdor.csv",index=False)

# %%
# Out:
# 0     2019-01-24
# 1     2019-02-01
# 2     2019-02-01
# 3     2019-12-11
# 4     2019-12-11
# 5     2019-12-11
# 6     2015-04-12
# 7     2019-12-10
# 8     2018-03-29
# 9     2018-04-12
# 10    2018-03-30
# 11    2018-03-30
# 12    2018-03-30
# 13    2018-03-29
# 14    2018-03-29
# Name: Created, dtype: object

# %%
display(df.head(100))
# Out:
#                                                 Title  \
# 0               Marijuana Sales by County in Colorado
# 1   Retail Marijuana Sales Tax Revenue by County i...
# 2           Marijuana Tax and Fee Revenue in Colorado
# 3                  Retail Reports by City in Colorado
# 4                Retail Reports by County in Colorado
# 5     Retail Reports by Industry and City in Colorado
# 6   Retail Reports by Industry and County in Colorado
# 7              Retail Reports by Industry in Colorado
# 8       Liquor Permits for Special Events in Colorado
# 9      Liquor Compliance Check Statistics in Colorado
# 10                        Liquor Licenses in Colorado
# 11      Recently Approved Liquor Licenses in Colorado
# 12  Recently Expired and Surrendered Liquor Licens...
# 13                            Sales Rooms in Colorado
# 14  Manufacturer Temporary Sales Room Permits in C...
#
#                      Created                   Updated  Views  Downloads
# 0   2019-01-24T17:44:14.000Z  2025-02-15T11:13:14.000Z   2562       1251
# 1   2019-02-01T20:26:40.000Z  2025-02-15T11:13:12.000Z   1673        948
# 2   2019-02-01T19:59:06.000Z  2025-02-15T11:13:18.000Z   4875       1048
# 3   2019-12-11T19:58:31.000Z  2025-03-10T10:22:42.000Z   1434        825
# 4   2019-12-11T20:16:20.000Z  2025-03-10T10:22:31.000Z   1554        787
# 5   2019-12-11T20:32:08.000Z  2025-03-10T10:22:29.000Z   1446        719
# 6   2015-04-12T20:15:25.000Z  2025-03-10T10:22:39.000Z   3791       1144
# 7   2019-12-10T21:44:03.000Z  2025-03-10T10:22:36.000Z   1126        739
# 8   2018-03-29T19:37:19.000Z  2025-03-06T11:32:51.000Z   1255       2359
# 9   2018-04-12T15:19:37.000Z  2025-03-06T11:33:03.000Z   2007       1270
# 10  2018-03-30T19:24:22.000Z  2025-03-06T11:33:37.000Z   4047       2947
# 11  2018-03-30T21:27:42.000Z  2025-03-06T11:32:45.000Z   3252       1458
# 12  2018-03-30T21:35:59.000Z  2025-02-03T20:00:36.000Z   1212       1248
# 13  2018-03-29T16:42:42.000Z  2025-01-16T22:36:21.000Z   1894       1275
# 14  2018-03-29T18:34:07.000Z  2025-03-06T11:32:40.000Z   1077        601

# %%
views
# Out:
# [{'page_views_last_week': 9,
#   'page_views_last_month': 49,
#   'page_views_total': 2562,
#   'page_views_last_week_log': 3.3219280948873626,
#   'page_views_last_month_log': 5.643856189774724,
#   'page_views_total_log': 11.323617763291578},
#  {'page_views_last_week': 2,
#   'page_views_last_month': 31,
#   'page_views_total': 1672,
#   'page_views_last_week_log': 1.5849625007211563,
#   'page_views_last_month_log': 5.0,
#   'page_views_total_log': 10.708221730038353},
#  {'page_views_last_week': 11,
#   'page_views_last_month': 69,
#   'page_views_total': 4872,
#   'page_views_last_week_log': 3.5849625007211565,
#   'page_views_last_month_log': 6.129283016944967,
#   'page_views_total_log': 12.250594507192316},
#  {'page_views_last_week': 2,
#   'page_views_last_month': 14,
#   'page_views_total': 1434,
#   'page_views_last_week_log': 1.5849625007211563,
#   'page_views_last_month_log': 3.9068905956085187,
#   'page_views_total_log': 10.486835021563051},
#  {'page_views_last_week': 6,
#   'page_views_last_month': 17,
#   'page_views_total': 1554,
#   'page_views_last_week_log': 2.807354922057604,
#   'page_views_last_month_log': 4.169925001442312,
#   'page_views_total_log': 10.602698865017965},
#  {'page_views_last_week': 6,
#   'page_views_last_month': 35,
#   'page_views_total': 1444,
#   'page_views_last_week_log': 2.807354922057604,
#   'page_views_last_month_log': 5.169925001442312,
#   'page_views_total_log': 10.496853777388042},
#  {'page_views_last_week': 31,
#   'page_views_last_month': 107,
#   'page_views_total': 3791,
#   'page_views_last_week_log': 5.0,
#   'page_views_last_month_log': 6.754887502163469,
#   'page_views_total_log': 11.88874324889826},
#  {'page_views_last_week': 3,
#   'page_views_last_month': 15,
#   'page_views_total': 1126,
#   'page_views_last_week_log': 2.0,
#   'page_views_last_month_log': 4.0,
#   'page_views_total_log': 10.138271800172221},
#  {'page_views_last_week': 5,
#   'page_views_last_month': 15,
#   'page_views_total': 1254,
#   'page_views_last_week_log': 2.584962500721156,
#   'page_views_last_month_log': 4.0,
#   'page_views_total_log': 10.293471648838134},
#  {'page_views_last_week': 10,
#   'page_views_last_month': 275,
#   'page_views_total': 2007,
#   'page_views_last_week_log': 3.4594316186372978,
#   'page_views_last_month_log': 8.108524456778168,
#   'page_views_total_log': 10.971543553950772},
#  {'page_views_last_week': 40,
#   'page_views_last_month': 402,
#   'page_views_total': 4047,
#   'page_views_last_week_log': 5.357552004618084,
#   'page_views_last_month_log': 8.654636028527968,
#   'page_views_total_log': 11.98299357469431},
#  {'page_views_last_week': 14,
#   'page_views_last_month': 62,
#   'page_views_total': 3252,
#   'page_views_last_week_log': 3.9068905956085187,
#   'page_views_last_month_log': 5.977279923499917,
#   'page_views_total_log': 11.667555107041132},
#  {'page_views_last_week': 2,
#   'page_views_last_month': 27,
#   'page_views_total': 1212,
#   'page_views_last_week_log': 1.5849625007211563,
#   'page_views_last_month_log': 4.807354922057604,
#   'page_views_total_log': 10.244363835120511},
#  {'page_views_last_week': 10,
#   'page_views_last_month': 42,
#   'page_views_total': 1894,
#   'page_views_last_week_log': 3.4594316186372978,
#   'page_views_last_month_log': 5.426264754702098,
#   'page_views_total_log': 10.887982133058454},
#  {'page_views_last_week': 1,
#   'page_views_last_month': 10,
#   'page_views_total': 1077,
#   'page_views_last_week_log': 1.0,
#   'page_views_last_month_log': 3.4594316186372978,
#   'page_views_total_log': 10.074141462752506}]

# %%
#['createdAt']'data_updated_at','download_count''page_views'
cimDatasets['Business Entities in Colorado']['resource'].keys()
# Out:
# dict_keys(['name', 'id', 'resource_name', 'parent_fxf', 'description', 'attribution', 'attribution_link', 'contact_email', 'type', 'updatedAt', 'createdAt', 'metadata_updated_at', 'data_updated_at', 'page_views', 'columns_name', 'columns_field_name', 'columns_datatype', 'columns_description', 'columns_format', 'download_count', 'provenance', 'lens_view_type', 'lens_display_type', 'locked', 'blob_mime_type', 'hide_from_data_json', 'publication_date'])

# %%
allAuto

# %% [markdown]
# ## Extra

# %%
for gp,dct in newGroups["cdor"].items():
    for title in dct:

# %%
cimDatasets.keys()
# Out:
# dict_keys(['Business Entities in Colorado', 'Professional and Occupational Licenses in Colorado', 'Map of Counties in Colorado', 'Population Projections in Colorado', 'Map of Fire Districts in Colorado', 'Map of Municipal Boundaries in Colorado', 'Map of Water and Sanitation Districts in Colorado', 'Uniform Commercial Code (UCC) Filing Information in Colorado', 'Trade Names for Businesses in Colorado', 'Active Nursing Licenses in Colorado', 'Map of All Special Districts in Colorado', 'Restaurant Inspections in Boulder County', 'Map of Highways in Colorado', 'Registration of Charities, Paid Solicitors, Professional Fundraising Consultants, and for-profit Public Benefit Corporations in Colorado', 'Uniform Commercial Code (UCC) Debtor Information in Colorado', 'COVID-19 Colorado Cases Dashboard', 'Employee Counts by Industry in Colorado', 'Unemployment Estimates in Colorado', 'Secured Party Information in Colorado', 'Map of Major Roads in Colorado', 'Personal Income in Colorado', 'Map of Railroads in Colorado', 'Business Entity Transaction History', 'Building Permit Counts in Colorado', 'Active Business Licenses Denver', 'Map of School Districts in Colorado', 'Trademarks for Businesses in Colorado', 'Persons Associated with Charitable Organizations, Paid Solicitors, and Professional Fundraising Consultants in Colorado', 'Map of Tree Inventory Denver', 'Current Notaries in Colorado', 'Map of Library Districts in Colorado', 'Contour Lines in Colorado', 'Employment Wages in Colorado', 'Bicycle and Pedestrian Counts in Colorado', 'Map of Census Counties in Colorado 2010', 'Map of Parks and Rec Districts in Colorado', 'CDOT Expenses', 'Septic Systems in Boulder County Colorado', 'Colorado COVID-19 Landing Page', 'Map of Highway Milepoints in Colorado', 'Map of Streams in Colorado', 'Marijuana Tax and Fee Revenue in Colorado', 'Uniform Commercial Code (UCC) Collateral Information in Colorado', 'Motor Vehicle Sales in Colorado', 'Long-Term Employment Projections in Colorado', 'Degrees Awarded to Post-Secondary Graduates in Colorado', 'CDOT Revenues', 'Professional and Occupational License Types in Colorado', 'Charitable Organizations’ Offices in Colorado', 'Map of Highway Traffic Counts in Colorado 2015', 'Liquor Licenses in Colorado', 'Highway Traffic Counts in Colorado 2017', 'Map of Road Traffic Counts in Colorado 2014', 'Map of Cities in Colorado', 'Retail Reports by Industry and County in Colorado', 'Map of Census Blocks in Colorado 2010', 'Taxes by County and Industry in Colorado', 'Charity Extension Requests', 'Aquaculture Facilities in Colorado', 'Post-Secondary Financial Aid Demographics in Colorado', 'Enrollment Demographics for Post-Secondary Graduates in Colorado', 'Map of Airports in Colorado', 'Recently Approved Liquor Licenses in Colorado', 'Durable Medical Equipment Suppliers in Colorado', 'Restaurant Sales in Colorado', 'Census Datasets on Colorado Information Marketplace', 'Map of Municipal Annexations in Colorado', 'CDOT Real Time Data Feed (XML)', 'Traffic Feeds in Colorado', 'Hours Worked by Employees in Colorado', 'Paid Solicitors Disclosed on Charity Registration Forms in Colorado', 'CDOT Payroll Expenditures', 'Consumer Price Index 2014', 'Alternative Fuels and Electric Vehicle Charging Station Locations in Colorado', 'Charitable Purpose of the Charity in Colorado', 'Use Tax Rates for Districts in Colorado', 'Natural Gas Prices in Colorado', 'Effective Financing Statements Master List (Farm Products)', 'Map of Hospital Districts in Colorado', 'Paid Solicitor Solicitation Notices in Colorado', 'Map of Lakes in Colorado', 'Tree Inventory Denver', 'Colorado COVID-19 Positive Cases and Rates of Infection by County of Identification', 'Crimes in Colorado', 'Map of Crude Oil Pipelines in Colorado 2014', 'Restaurant Inspections in Tri-County Colorado 2018', 'Crime Offenses by Police District 2001-2016 in Colorado', 'Marijuana Sales by County in Colorado', 'Map of Soil Districts in Colorado', 'National Hydrography Datase ...

# %%
def generateMonthlyReport(allAuto):
    mapped = {1:"Daily",7:"Weekly",31:"Monthly",90:"Quarterly",365:"Annual"}
    hist={}
    histNew={}
    badTitles={}
    for title,dct in allAuto.items():
        stat = dct["Status"]
        expected = dct["Expected Update"]
        
        mapd=mapped[expected]
        if mapd not in hist:
            hist[mapd]={}
        if stat not in hist[mapd]:
            hist[mapd][stat]=0
        hist[mapd][stat]+=1
        if stat == "fail":
            if dct['Activity Data Success'] != 'NA'  and int(dct['Activity Data Success']) <= dct['Expected Update']:
                stat='pass'
        if stat == "fail":
            if mapd not in badTitles:
                badTitles[mapd]={}
            badTitles[mapd][title]=dct
            
        if mapd not in histNew:
            histNew[mapd]={}
        if stat not in histNew[mapd]:
            histNew[mapd][stat]=0
        histNew[mapd][stat]+=1

## Create Summary Plot
    if 'Annual' in histNew:
        del histNew["Annual"]
    if 'Quarterly' in histNew:
        del histNew['Quarterly']
    print (histNew)
    histPlot={}
    for key,dct in histNew.items():
        histPlot[key]={}
        histPlot[key]['Fail']=dct['fail']
        histPlot[key]['Pass']=dct['pass']
        if "Total" not in histPlot:
            histPlot["Total"]={}
            histPlot["Total"]["Fail"]=0
            histPlot["Total"]["Pass"]=0
            
        histPlot["Total"]["Fail"]+=dct["fail"]
        histPlot["Total"]["Pass"]+=dct["pass"]

    tdy = datetime.today().date()
    print("HIST PLOT ",histPlot)
    pd.DataFrame(histPlot)[["Daily","Weekly","Monthly","Total"]].T.plot.bar(figsize=(9,7))
    plt.title(f'Automated Datasets Meeting Update Schedule as of {tdy.strftime("%B")}, {tdy.year}')
    
    # Move the legend to outside of the plot
    plt.legend(loc='center left', bbox_to_anchor=(1, 0.85))
    plt.gca().yaxis.set_major_locator(MultipleLocator(2))
    plt.savefig("automatedStatus.png")


## Plot WHY Failing
    all=None
    
    for cron,dct in badTitles.items():
        for title,dct2 in dct.items():
     #       print("--------------\n",title)
          
            tmp=dfAssets.loc[(dfAssets["name"] == title) & (dfAssets["uid"].str.len() == 9),['uid', 'name', 'owner','creation_date','audience','publication_stage', 'last_data_updated_date']]
            tmp2 = grCronGroup.loc[grCronGroup["Title"] == title]
      
            if tmp2.shape[0] > 0:
                tmp["Group"]=tmp2["Group"].values
                tmp["Cron"]=tmp2["Cron"].values
                grp = tmp2["Group"].values.tolist()[0]
                
            else:
                tmp["Group"]=""
                tmp["Cron"]=""
                grp=""
                
            if "Data Update" in dct2 and "Expected Update" in dct2:
                tmp["Data Update CIM"]=dct2["Data Update"]
                tmp["Expected Update"]=dct2["Expected Update"]
                tmp["Diff Update"]=dct2["Data Update"]-dct2["Expected Update"]           
            else:
                tmp["Data Update CIM"]=""
                tmp["Expected Update"]=""
    
                
            if title.lower().find("denver") > -1: 
                why="Denver"
            
            elif grp == "dola/special_districts" or grp == "cdot/transportation_infrastructure" or  grp == "dola/boundaries" or  \
                 grp == "cdot/transportation_road_attributes" or grp == "cdot/natural_resources":
                 why="Map Issue"
            else:
                why="Unknown"
            tmp["Sched"]=cron
            tmp["Status"]=why
            if all is not None:
                all=pd.concat([all,tmp])
            else:
                all=tmp     

    plt.figure(figsize=(8,10))
    ax=all["Status"].value_counts().plot.bar()
    plt.title(f"Reasons for Dataset Automation Failures as of {tdy.strftime('%B')}, {tdy.year}")
    plt.gca().yaxis.set_major_locator(MultipleLocator(2))
    plt.savefig("reasons.png")
generateMonthlyReport(allAuto)

# %%
from google.oauth2 import service_account
from googleapiclient.discovery import build
from googleapiclient.http import MediaFileUpload

# Path to the service account key file
SERVICE_ACCOUNT_FILE = os.path.join(bic_etl_home, 'general', 'scripts','client_secret.json')
# creds = ServiceAccountCredentials.from_json_keyfile_name(os.path.join(bic_etl_home, 'general', 'scripts','client_secret.json'),scope)
    
# Define the required scopes
SCOPES = ['https://www.googleapis.com/auth/drive.file']

# Authenticate and build the service
credentials = service_account.Credentials.from_service_account_file(
    SERVICE_ACCOUNT_FILE, scopes=SCOPES)
service = build('drive', 'v3', credentials=credentials)

def upload_file(file_path, file_name, mime_type):
    # Create a MediaFileUpload object
    media = MediaFileUpload(file_path, mimetype=mime_type)

    # Create a file metadata dictionary
    file_metadata = {'name': file_name}

    # Upload the file
    file = service.files().create(
        body=file_metadata,
        media_body=media,
        fields='id'
    ).execute()

    print(f'File ID: {file.get("id")}')

# Example usage
upload_file('automatedStatus.png', 'automatedStatus.png', 'image/png')

# %%
 dfActivity = getActivityLog()

# %%
dfActivity.head()

# %%
dfActivity.loc[(dfActivity["dataset_name"].str.contains("Grand Junction"))].head(500)

# %%
dfActivity.dropna(subset=["dataset_name"],inplace=True)

# %%
if 'Annual' in histNew:
   del histNew["Annual"]
if 'Quarterly' in histNew:
    del histNew['Quarterly']
print (histNew)
histPlot={}
for key,dct in histNew.items():
    histPlot[key]={}
    histPlot[key]['Fail']=dct['fail']
    histPlot[key]['Pass']=dct['pass']
    if "Total" not in histPlot:
        histPlot["Total"]={}
        histPlot["Total"]["Fail"]=0
        histPlot["Total"]["Pass"]=0
        
    histPlot["Total"]["Fail"]+=dct["fail"]
    histPlot["Total"]["Pass"]+=dct["pass"]

# %%
tdy = datetime.today().date()
pd.DataFrame(histPlot)[["Daily","Weekly","Monthly","Total"]].T.plot.bar(figsize=(9,7))
plt.title(f'Automated Datasets Meeting Update Schedule as of {tdy.strftime("%B")}, {tdy.year}')

# Move the legend to outside of the plot
plt.legend(loc='center left', bbox_to_anchor=(1, 0.85))
plt.gca().yaxis.set_major_locator(MultipleLocator(2))
plt.savefig("automatedStatus.png")

# %%
all=None

for cron,dct in badTitles.items():
    for title,dct2 in dct.items():
 #       print("--------------\n",title)
      
        tmp=dfAssets.loc[(dfAssets["name"] == title) & (dfAssets["uid"].str.len() == 9),['uid', 'name', 'owner','creation_date','audience','publication_stage', 'last_data_updated_date']]
        tmp2 = grCronGroup.loc[grCronGroup["Title"] == title]
        print(tmp2.shape[0],title,tmp2['Group'].values,tmp2['Cron'].values)
        if tmp2.shape[0] > 0:
            tmp["Group"]=tmp2["Group"].values
            tmp["Cron"]=tmp2["Cron"].values
            grp = tmp2["Group"].values.tolist()[0]
            
        else:
            tmp["Group"]=""
            tmp["Cron"]=""
            grp=""
            
        if "Data Update" in dct2 and "Expected Update" in dct2:
            tmp["Data Update CIM"]=dct2["Data Update"]
            tmp["Expected Update"]=dct2["Expected Update"]
            tmp["Diff Update"]=dct2["Data Update"]-dct2["Expected Update"]           
        else:
            tmp["Data Update CIM"]=""
            tmp["Expected Update"]=""

            
        if title.lower().find("denver") > -1: 
            print("Known Issue")
            why="Denver - Socrata"
        
        elif grp == "dola/special_districts" or grp == "cdot/transportation_infrastructure" or  grp == "dola/boundaries" or  \
             grp == "cdot/transportation_road_attributes" or grp == "cdot/natural_resources":
             why="Map Issue"
        else:
            why="Unknown"
        tmp["Sched"]=cron
        tmp["Status"]=why
        if all is not None:
            all=pd.concat([all,tmp])
        else:
            all=tmp

    ax=all["Status"].value_counts().plot.bar()
    plt.title("Reasons for Dataset Automation Failures")
    plt.gca().yaxis.set_major_locator(MultipleLocator(2))
    plt.savefig("reasons.png")
  #      display(tmp2.head())
 #       display(tmp.head())

# %%
all[["name","creation_date","last_data_updated_date","Group","Sched","Diff Update","Status"]].sort_values(by="Status")

# %%
all["Group"].value_counts()

# %%
from matplotlib.ticker import MultipleLocator
ax=all["Status"].value_counts().plot.bar()
plt.title("Reasons for Dataset Automation Failures")
plt.gca().yaxis.set_major_locator(MultipleLocator(2))
plt.savefig("reasons.png")

# %%
dfActivity = pd.read_csv("activity_log.csv")
dfTracker=getDatasetTrackerInfo(bic_etl_home)
dfTrackerNotStatic = dfTracker.loc[~dfTracker["Update Type"].isin(["Static",""])]
hist=getCimInfo(dfTrackerNotStatic)
logInfo,data,summary=analysis(hist,dfActivity)

# %%
summary

# %%
report={}
for title,dct in summary.items():
    if "Expected Update" in dct: 
        expt = dct["Expected Update"]
        lastSuccess= dct["Activity Data Success"]
        if expt not in report:
            report[expt]={}
            report[expt]["Pass"]=0
            report[expt]["Fail"]=0
            report[expt]["Total"]=0
        
        report[expt]["Total"]=0
        
        if lastSuccess == "NA":
            report[expt]["Fail"]+=1
            what="Fail"
        else:
            lastSuccessn=int(lastSuccess)
            exptn=int(expt)
            if exptn >= lastSuccessn:
               report[expt]["Pass"]+=1
               what="Pass"
            else:
               report[expt]["Fail"]+=1
               what="Fail"
        print(f"{expt:4d} {str(lastSuccess):4s}  {what:4s}  {title}")
    else:
        print("ROH ROH ",title,dct)

# %%
report={}
for title,dct in summary.items():
    if "Expected Update" in dct: 
        expt = dct["Expected Update"]
        lastSuccess= dct["Activity Data Success"]
        if expt not in report:
            report[expt]={}
            report[expt]["Pass"]=0
            report[expt]["Fail"]=0
            report[expt]["Total"]=0
        
        report[expt]["Total"]=0
        
        if lastSuccess == "NA":
            report[expt]["Fail"]+=1
            what="Fail"
        else:
            lastSuccessn=int(lastSuccess)
            exptn=int(expt)
            if exptn >= lastSuccessn:
               report[expt]["Pass"]+=1
               what="Pass"
            else:
               report[expt]["Fail"]+=1
               what="Fail"
        print(f"{expt:4d} {str(lastSuccess):4s}  {what:4s}  {title}")
    else:
        print("ROH ROH ",title,dct)



mapped = {1:"Daily",7:"Weekly",31:"Monthly",90:"Quarterly",365:"Annual"}

for how,dct in report.items():
    print(f"{mapped[how]:10s}  Passed: {dct['Pass']:4d}  Fail:{dct['Fail']:4d}")

# %% [markdown]
# ## Actvity GUI

# %%
def activeGui():
   dfActivity = pd.read_csv("activity_log.csv")
   dfTracker=getDatasetTrackerInfo(bic_etl_home)
   dfTrackerNotStatic = dfTracker.loc[~dfTracker["Update Type"].isin(["Static",""])]
   hist=getCimInfo(dfTrackerNotStatic)
   logInfo,data=analysis(hist,dfActivity)
   header=["Title","Data-Expected","Data Update","Expected Period","Metadata Update"]
   data=sorted(data, key=lambda item: item[1],reverse=True)
   # buttons=[]
   # for dat in data:
   #     row = [sg.Button(dat[0],key=f"-TITLEBAD:{title}"),dat[1],dat[2],dat[3]]
   #     buttons.append(row)
       
   layoutS = [
         [sg.Button('Close',font='Courier 15 bold ')],
         [sg.Table(values=data,headings=header,cols_justification=["l","c","c","c"],
                   num_rows=30,row_height=40,vertical_scroll_only=False,max_col_width=60,
                   enable_events=True, key='-TABLE-',display_row_numbers=True,border_width=6,background_color = "#99ccff",
                   alternating_row_color = "#9999ff",font="CENTAUR 13 bold",starting_row_number=1)]
    ]
   layout = [[ sg.Column(layoutS,scrollable=True)]]
   window3 = sg.Window('Activity GUI', layout,finalize=True,resizable=True,background_color="#cc4400")

   sourceDefFile=""  #  this is needed
   vals=[]
   return logInfo,data
   # try: 
   #      while True:
   #          wid, event, values = sg.read_all_windows()
   #          print("EV ",event)
   #          print(values)
   #          if event == sg.WIN_CLOSED or event == 'Close':
   #              window2.close()
   #              break
   #          elif event == 'Quit':
   #              wid.close()
   #          elif event == "-TABLE-":
   #              selected_row_index = values['-TABLE-'][0]
   #              selected_row_data = data[selected_row_index]
   #              title=data[selected_row_index][0]
   #              analyzeActivityLog(title,logInfo[title])
                
   #      return title
   # except Exception as err:
   #     print("ERROR ERROR ERROR",err)

#logInfo=activeGui()

# %%
def analyzeActivityLog(title,logInf):
    histActivity={}
    acts=[]
    durs=[]
    mins=[]
    maxs=[]

    
    for act,dct2 in logInf.items():
        mx=max(dct2.keys())
        mn=min(dct2.keys())
        acts.append(act)
        mins.append(mn)
        maxs.append(mx)
        dur=(mx-mn).total_seconds() / (24 * 3600)
        durs.append(dur)
        if act not in histActivity:
            histActivity[act]=0
        histActivity[act]+=1
            
    
   
    dfa=pd.DataFrame({"Activity":acts,"Duration":durs,"Start":mins,"Ends":maxs})
        
    #df['duration'] = (df['end'] - df['start']).dt.total_seconds() / (24 * 3600)
    plt.figure(figsize=(10, 6))
    sns.set(style="whitegrid")
    
    # Plot rectangles for each task
    for index, row in dfa.iterrows():
        plt.barh(index, row['Duration'], left=row['Start'], height=0.4, edgecolor='black')
    
    # Setting labels
    plt.yticks(range(len(dfa['Activity'])), dfa['Activity'])
    plt.xlabel('Date')
    plt.title('Floating Bar Chart Based on Dates')
    
    # Format the x-axis to show dates
    plt.gca().xaxis.set_major_locator(mdates.DayLocator())
    plt.gca().xaxis.set_major_formatter(mdates.DateFormatter("%Y-%m-%d"))
    #plt.gca().xaxis.set_major_locator(MaxNLocator(nbins=5))
    plt.gca().xaxis.set_major_locator(mdates.MonthLocator())
    # Rotate and align the x labels for better readability
    plt.xticks(rotation=45, ha="right")
    
    # Show grid lines for better readability
    plt.grid(False, linestyle='--', alpha=0.5)
    
    # Show the plot
    plt.tight_layout()
    plt.show()
title='Scenic Byways in Colorado'
analyzeActivityLog(title,logInfo[title])

# %%
def analyzeActivityLog(title,logInf):
    histActivity={}
    acts=[]
    durs=[]
    mins=[]
    maxs=[]
    counts=[]

    tody = datetime.today()
    for act,dct2 in logInf.items():
        mx=max(dct2.keys())
        mn=min(dct2.keys())
        acts.append(act)
        mins.append(mn)
        maxs.append(mx)
        counts.append(len(dct2.keys()))
   #     dur=(mx-mn).total_seconds() / (24 * 3600)
        dur=(mx-mn)
        
        durs.append(dur)
        if act not in histActivity:
            histActivity[act]=0
        histActivity[act]+=1
            
    
    print("DURS ",maxs)
    dfa=pd.DataFrame({"Activity":acts,"Duration":durs,"Start":mins,"Ends":maxs,"Counts":counts})
    fig, ax = plt.subplots()
    #df['duration'] = (df['end'] - df['start']).dt.total_seconds() / (24 * 3600)
#    fig.figure(figsize=(10, 6))
    sns.set(style="whitegrid")
    
    # Plot rectangles for each task
    for index, row in dfa.iterrows():
        plt.barh(index, row['Duration'], left=row['Start'], height=0.4, edgecolor='black')
        start=row["Start"]
        duration=row["Duration"]
        count=row["Counts"]
        ax.text(start + duration / 2, index, f"{count}", va='center', ha='center', color='white', fontsize=9)
    
    # Setting labels
    ax.set_yticks(range(len(dfa['Activity'])), dfa['Activity'])
    ax.set_xlabel('Date')
    ax.set_title('Floating Bar Chart Based on Dates')
    
    # Format the x-axis to show dates
    ax.xaxis.set_major_locator(mdates.DayLocator())
#    ax.xaxis.set_major_formatter(mdates.DateFormatter("%Y-%m-%d"))
    ax.xaxis.set_major_locator(MaxNLocator(nbins=5))
    
    ax.xaxis.set_major_locator(mdates.MonthLocator())
    ax.xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m'))

    # ax.xaxis.set_major_locator(mdates.DayLocator())

# Set the formatter to display the date in a readable format (Year-Month-Day)
    # Rotate and align the x labels for better readability
    plt.xticks(rotation=90, ha="right")
  #  ax.set_xticklabels(ax.get_xticks(), rotation=90)
    # Show grid lines for better readability
    ax.grid(False, linestyle='--', alpha=0.5)
    ax.set_xlim(left=None, right=tody)
    # Show the plot
    fig.tight_layout()
    plt.show()

title='Tree Inventory Denver'

analyzeActivityLog(title,logInfo[title])

# %%
items

# %%
items[0]

# %%
import PySimpleGUI as sg
import matplotlib.pyplot as plt
from matplotlib.backends.backend_tkagg import FigureCanvasTkAgg

# Function to draw the plot on the canvas
def draw_figure(canvas, figure):
    figure_canvas_agg = FigureCanvasTkAgg(figure, canvas)
    figure_canvas_agg.draw()
    figure_canvas_agg.get_tk_widget().pack(side='top', fill='both', expand=1)
    return figure_canvas_agg

# Sample data for plotting
x = [1, 2, 3, 4, 5]
y = [1, 4, 9, 16, 25]

# Create the Matplotlib figure
fig, ax = plt.subplots()
ax.plot(x, y)
ax.set_title('Sample Plot')
ax.set_xlabel('X-axis')
ax.set_ylabel('Y-axis')

# Define the PySimpleGUI layout
layout = [
    [sg.Text('Matplotlib Plot in PySimpleGUI')],
    [sg.Canvas(key='-CANVAS-')],
    [sg.Button('Exit')]
]

# Create the PySimpleGUI window
window = sg.Window('PySimpleGUI with Matplotlib', layout, finalize=True)

# Draw the plot on the canvas
draw_figure(window['-CANVAS-'].TKCanvas, fig)

# Event loop to process events and get the values of the inputs
while True:
    event, values = window.read()
    if event in (sg.WIN_CLOSED, 'Exit'):
        break

window.close()

# %% [markdown]
# ## Dataset Tracker

# %% [markdown]
# # Metadata Functions

# %%
def getDatasetTracker():
    scope = ['https://www.googleapis.com/auth/spreadsheets.readonly',
             "https://www.googleapis.com/auth/drive.file",
                  "https://www.googleapis.com/auth/drive"]
    creds = ServiceAccountCredentials.from_json_keyfile_name(os.path.join(bic_etl_home, 'general', 'scripts','client_secret.json'),scope)
    
    client = gspread.authorize(creds)
    tracker = client.open('BIC Dataset Tracker').worksheet(
    'PublishedData')
    metadata_df = pd.DataFrame(tracker.get_all_records(head=2))

    tracker2 = client.open('BIC Dataset Tracker').worksheet(
    'cimAllData')
    vals=tracker2.get_all_values()
    metadata_df_cimAll = pd.DataFrame(vals[1:],columns=vals[0])
    return metadata_df,metadata_df_cimAll

def getActivityLog():
    flog=open(f"{bic_etl_home}/general/datasync/config.json")
    info = json.load(flog)
    username=info['username']
    password=info['password']
    api=info['appToken']
#    "$where": "created_at > '2023-01-01T00:00:00' and acting_user_name = 'Colorado Information Marketplace'"
    
    # URL of the login form
    query = {
    "$where": "acting_user_name = 'Colorado Information Marketplace'"
    }
    login_url = 'https://data.colorado.gov/api/activity_log.json?$limit=6000000'
    response=requests.get(login_url,auth=(username, password),params=query)
    if response.status_code == 200:
      
#        activity_log=json.loads(response.text)
        print(type(response.text))
    else:
        print("Failed to download Activity Log")
        print(f"Error: {response.status_code}")
        print(f"Message: {response.text}")
    return json.loads(response.text)


def getApiLog():
    flog=open(f"{bic_etl_home}/general/datasync/config.json")
    info = json.load(flog)
    username=info['username']
    password=info['password']
    api=info['appToken']
    
    # URL of the login form
    query = {
    "$where": "timestamp > '2023-01-01T00:00:00' "
    }
    login_url = 'https://data.colorado.gov/resource/xejc-64sn.csv?$limit=4000000'
    response=requests.get(login_url,auth=(username, password),params=query)
    if response.status_code == 200:
      
#        activity_log=json.loads(response.text)
        print(type(response.text))
    else:
        print("Failed to download Activity Log")
        print(f"Error: {response.status_code}")
        print(f"Message: {response.text}")
    return response.text


def getAssetDataset():
    flog=open(f"{bic_etl_home}/general/datasync/config.json")
    info = json.load(flog)
    username=info['username']
    password=info['password']
    api=info['appToken']
    
    # URL of the login form
    query = {
    "$where": "timestamp > '2013-01-01T00:00:00' "
    }
    login_url = 'https://data.colorado.gov/resource/pb79-5bvp.json?$limit=4000000'
    response=requests.get(login_url,auth=(username, password))
    if response.status_code == 200:
      
#        activity_log=json.loads(response.text)
        print(type(response.text))
    else:
        print("Failed to download Activity Log")
        print(f"Error: {response.status_code}")
        print(f"Message: {response.text}")
    return pd.DataFrame(json.loads(response.text))

# %%
def getDatasetTracker():
    scope = ['https://www.googleapis.com/auth/spreadsheets.readonly',
             "https://www.googleapis.com/auth/drive.file",
                  "https://www.googleapis.com/auth/drive"]
    creds = ServiceAccountCredentials.from_json_keyfile_name(os.path.join(bic_etl_home, 'general', 'scripts','client_secret.json'),scope)
    
    client = gspread.authorize(creds)
    tracker = client.open('BIC Dataset Tracker').worksheet(
    'PublishedData')
    metadata_df = pd.DataFrame(tracker.get_all_records(head=2))

    tracker2 = client.open('BIC Dataset Tracker').worksheet(
    'cimAllData')
    vals=tracker2.get_all_values()
    metadata_df_cimAll = pd.DataFrame(vals[1:],columns=vals[0])
    return metadata_df,metadata_df_cimAll

# %% [markdown]
# ## API Log

# %%
def getApiLog():
    flog=open(f"{bic_etl_home}/general/datasync/config.json")
    info = json.load(flog)
    username=info['username']
    password=info['password']
    api=info['appToken']
    
    # URL of the login form
    query = {
    "$where": "timestamp > '2023-01-01T00:00:00' "
    }
    login_url = 'https://data.colorado.gov/resource/xejc-64sn.csv?$limit=4000000'
    response=requests.get(login_url,auth=(username, password),params=query)
    if response.status_code == 200:
      
#        activity_log=json.loads(response.text)
        print(type(response.text))
    else:
        print("Failed to download Activity Log")
        print(f"Error: {response.status_code}")
        print(f"Message: {response.text}")
    return response.text
# text=getApiLog()

# %% [markdown]
# ## Asset Dataset

# %%
def getAssetDataset():
    flog=open(f"{bic_etl_home}/general/datasync/config.json")
    info = json.load(flog)
    username=info['username']
    password=info['password']
    api=info['appToken']
    
    # URL of the login form
    query = {
    "$where": "timestamp > '2013-01-01T00:00:00' "
    }
    login_url = 'https://data.colorado.gov/resource/pb79-5bvp.json?$limit=4000000'
    response=requests.get(login_url,auth=(username, password))
    if response.status_code == 200:
      
#        activity_log=json.loads(response.text)
        print(type(response.text))
    else:
        print("Failed to download Activity Log")
        print(f"Error: {response.status_code}")
        print(f"Message: {response.text}")
    return pd.DataFrame(json.loads(response.text))
#assetsDf=getAssetDataset()

# %% [markdown]
# ## Analysis

# %%
trackerDf = getDatasetTracker()
assetsDf=getAssetDataset()

# %%
trackerDf.columns

# %%
titles = trackerDf["Dataset Title"].values.tolist()
w4x4s = trackerDf["Socrata Link"].values.tolist()
maps = trackerDf["MapViz"].values.tolist()

# %%
maps

# %%
#tmp=assetsDf.loc[assetsDf["name"].isin(titles)]
tmp=assetsDf.loc[(assetsDf["uid"].isin(w4x4s)) | (assetsDf["uid"].isin(maps))]

# %%
tmp.shape

# %%
tmp2 = tmp.loc[tmp["owner"] != "Colorado Information Marketplace"]

# %%
tmp2.shape

# %%
tmp2.head(10)

# %%
tmpT=assetsDf.loc[(assetsDf["name"].isin(titles))]
tmpT2 = tmpT.loc[tmpT["owner"] != "Colorado Information Marketplace"]

# %%
titlesNot=tmpT2["name"].values.tolist()

# %%
assetsDf.loc[assetsDf["name"].isin(titlesNot)].sort_values(by="name")

# %%
assetsDf.columns

# %%
lic=trackerDf.loc[trackerDf["Socrata Link"] == "gagb-cxcb","License Type"].values

# %%
trackerDf["License Type"].value_counts()

# %%
tmp = assetsDf.loc[assetsDf["name"].str.contains("Grand Junction")]

# %%
tmp.shape

# %%
tmp[["uid","owner","name","audience"]]

# %%
times=[]
textNew=[]
for string in text:

    row=string.split(",")
    row=[col.replace('"','') for col in row]
    textNew.append(row)
#    print(row)
    # if row[2] == "v4as-sthd":
    #     print(row)

# %%
len(textNew[0])

# %%
text[:100]

# %%
textNew[0][0]

# %%
header=textNew[0]
for nn,row in enumerate(textNew[1:]):
    print(len(row),len(header))
    for mm,val in enumerate(row):
        if header[mm] == "audience":
            print(val)

# %%
def count(val,dct):
    if val not in dct:
        dct[val]=0
    dct[val]+=1
    return dct

whats={}
whos={}
titles={}
typs={}
titles={}
values={}
dates={}
headerTmp=textNew[0]
header={}
header = {val:nn for nn,val in enumerate(headerTmp)]
for row in textNew[1:]:
    if len(row) > 4:
        if row[header['id']] == "v4as-sthd":
           date=row[0]
           value=int(row[1])
           who=row[3]
           what=row[4]
           title=row[5]
           typ = row[6]
           whats=count(what,whats)
           whos=count(who,whos)
           titles=count(title,titles)
           typs=count(typ,typs)
           values=count(value,values)
           dates=count(date,dates)
            
    else:
        print(row)

# %%
whats

# %%
titles

# %%
from sodapy import Socrata

# Replace with your Socrata domain and dataset identifier
domain = "data.colorado.gov"
dataset_identifier = "your-dataset-identifier"


# Replace with your App Token, username, and password
# app_token = "YOUR_APP_TOKEN"
# username = "YOUR_USERNAME"
# password = "YOUR_PASSWORD"

flog=open(f"{bic_etl_home}/general/datasync/config.json")
info = json.load(flog)
username=info['username']
password=info['password']
app_token=info['appToken']
domain = "https://data.colorado.gov"
# Create a Socrata client
client = Socrata(domain, app_token, username=username, password=password)

# Fetch all assets
results = client.get("pb79-5bvp")

# Print the results
print(results)

# Optionally, you can convert the results to a pandas DataFrame for easier analysis
import pandas as pd
df = pd.DataFrame.from_records(results)
print(df)

# %%
trackerDf = pd.read_excel("Questionable Datasets.xlsx",engine='openpyxl')

# %%
trackerDf[["Dataset Title","Socrata Link"]].head(100)

# %%
trackerDf["Socrata Link"].head()

# %%
assetsDf.head()

# %%
good=0
tooMany=0
hist={}
audience={}
for indx,row in trackerDf.iterrows():
    w4x4=row["Socrata Link"]
    title=row["Dataset Title"]
    tmp=assetsDf.loc[assetsDf["name"] == title]
    if tmp.shape[0] == 1:
       good+=1
       owner= tmp["owner"].values.tolist()[0]
       if owner not in hist:
           hist[owner]=0
       hist[owner]+=1
       audience[title]={}
       audience[title]["audience"]=tmp["audience"].values.tolist()[0]
       audience[title]["owner"]=tmp["owner"].values.tolist()[0]
       audience[title]["xen 4x4"]=w4x4
       audience[title]["cim 4x4"]=tmp["uid"].values.tolist()[0]
        
        
        
    elif tmp.shape[0] > 1:
        print("Too Many ",tmp.shape[0],title)
        display(tmp[["uid","name","audience","owner"]].head(10)) 
        tooMany+=1
#        display(tmp.head(10))
    elif tmp.shape[0] == 0:
        print("Not Foun",title)

# %%
pd.DataFrame(audience).T.to_csv("questionable_tracker_meta.csv",index=False)

# %%
display(pd.DataFrame(audience).T)

# %%
pd.DataFrame(audience).T["audience"].value_counts()

# %%
for title,dct in sorted(audience.items()):
    print(f"{dct['audience']:7s}  xen 4x4: {dct['xen 4x4']}  cim 4x4: {dct['cim 4x4']}    {dct['owner']:40s}  {title:60s}")

# %%
good=0
tooMany=0
hist={}
audience={}
for indx,row in trackerDf.iterrows():
    w4x4=row["Socrata Link"]
    title=row["Dataset Title"]
    tmp=assetsDf.loc[assetsDf["uid"] == w4x4]
    if tmp.shape[0] == 1:
       good+=1
       owner= tmp["owner"].values.tolist()[0]
       if owner not in hist:
           hist[owner]=0
       hist[owner]+=1
       audience[title]={}
       audience[title]["audience"]=tmp["audience"].values.tolist()[0]
       audience[title]["owner"]=tmp["owner"].values.tolist()[0]
       audience[title]["xen 4x4"]=w4x4
       audience[title]["cim 4x4"]=tmp["uid"].values.tolist()[0]
        
        
        
    elif tmp.shape[0] > 1:
        print("Too Many ",tmp.shape[0],title)
        display(tmp[["uid","name","audience","owner"]].head(10)) 
        tooMany+=1
#        display(tmp.head(10))
    elif tmp.shape[0] == 0:
        print("Not Foun",title)

# %%
pd.DataFrame(audience).T.to_csv("questionable_tracker_meta.csv",index=False)

# %%
pd.DataFrame(audience).T["audience"].value_counts()

# %% [markdown]
# # Analysis

# %%
trackerDf,trackerAllDf = getDatasetTracker()
assetsDf=getAssetDataset()
assetsDf['creation_date'] = pd.to_datetime(assetsDf['creation_date']).dt.date
assetsDf['last_data_updated_date'] = pd.to_datetime(assetsDf['last_data_updated_date']).dt.date

columns2Output=['uid','name','owner','audience','creation_date','last_data_updated_date','publication_stage',"approval_status",'row_count','type','url']
titlesTracker = trackerDf['Dataset Title'].str.strip().values.tolist()
titlesTrackerAll = trackerAllDf['Title'].str.strip().values.tolist()
w4x4sTracker=trackerDf["Socrata Link"].str.strip().values.tolist()
w4x4sMapsTracker=trackerDf.loc[trackerDf["MapViz"].str.len() > 0,"MapViz"].values.tolist()

# %%
len(w4x4sMapsTracker)

# %% [markdown]
# ## Tracker Datasets Private on CIM

# %%
##  Drafts marked private (all drafts are likely private) 
tmp=assetsDf.loc[(assetsDf["audience"] == "private") & (assetsDf["owner"] == "Colorado Information Marketplace") & (assetsDf["uid"].str.len() > 9)]
tmp[columns2Output].to_csv("Output/private_drafts.tsv",index=False,sep="\t")
print(tmp.shape)

# %%
## Datasets on CIM that are marked Private... Drafts are removed
tmp=assetsDf.loc[(assetsDf["audience"] == "private") & (assetsDf["owner"] == "Colorado Information Marketplace") & (assetsDf["uid"].str.len()== 9) ]

tmp[columns2Output].to_csv("Output/private_all.tsv",index=False)
print(tmp.shape)

# %%
tmp["type"].value_counts()

# %%
# How many of the private datasets are maps for other datasets
tmp.loc[tmp["uid"].isin(w4x4sMapsTracker)].shape[0]

# %%
tmp.shape

# %%
trackerAllDf.columns

# %%
# titlesTracker = trackerDf['Dataset Title'].values.tolist()
# titlesTrackerAll = trackerAllDf['Title'].values.tolist()
# w4x4sTracker = trackerDf['Socrata Link'].values.tolist()
w4x4sTrackerAll = trackerAllDf['ID'].str.strip().values.tolist()


print(tmp.loc[tmp["name"].str.strip().isin(titlesTracker)].shape)
print(tmp.loc[tmp["name"].str.strip().isin(titlesTrackerAll)].shape)

print(tmp.loc[tmp["uid"].str.strip().isin(w4x4sTracker)].shape)
print(tmp.loc[tmp["uid"].str.strip().isin(w4x4sTrackerAll)].shape)

# %%
# CIM Private Datasets NOT in the Tracker
tmp.loc[~tmp["name"].str.strip().isin(titlesTracker),columns2Output].sort_values(by="name").to_csv("Output/privateNotTracker.tsv",index=False,sep="\t")

# %%
tmp.loc[tmp["name"].isin(titlesTracker),columns2Output].sort_values(by="name")

# %% [markdown]
# ## Tracker vs CIM

# %% [markdown]
# ### Datasets in Tracker but Not on CIM

# %%
titlesTracker = trackerDf["Dataset Title"].str.strip().values.tolist()
maps4x4Tracker = trackerDf["MapViz"].str.strip().values.tolist()
w4x4Tracker = trackerDf["Socrata Link"].str.strip().values.tolist()


titlesCim = assetsDf.loc[(assetsDf["owner"].str.strip() == "Colorado Information Marketplace"),"name"].values.tolist()
w4x4sCim = assetsDf.loc[(assetsDf["owner"].str.strip() == "Colorado Information Marketplace"),"uid"].values.tolist()

# %%
len(w4x4sCim)

# %%
## In Tracker Not on CIM
columns2OutputTracker=["Dataset Title","Socrata Link","MapViz","Date of Initial Dataset Creation"]
trackerNotCim=trackerDf.loc[~trackerDf["Dataset Title"].str.strip().isin(titlesCim)]
print("In Tracker, Not CIM ",trackerNotCim.shape)
display(trackerNotCim[columns2OutputTracker].head(20))
trackerNotCim[columns2OutputTracker].to_csv("Output/trackerNotCimByTitle.tsv",sep="\t",index=False)
trackerNotCimasTitlebut4x4=trackerNotCim.loc[trackerNotCim["Socrata Link"].str.strip().isin(w4x4sCim)]
print("In Tracker, on CIM w/ 4x4",trackerNotCimasTitlebut4x4.shape)
display(trackerNotCimasTitlebut4x4[columns2OutputTracker].head(20))
trackerNotCimasTitlebut4x4[columns2OutputTracker].to_csv("Output/trackerNotCimFoundBy4x4.tsv",index=False,sep="\t")
#trackerNotCim=trackerNotCim.loc[~trackerNotCim["Socrata Link"].isin(w4x4sCim)]

# %%
# Datasets in Tracker Found on CIM with DIfferent Title
w4=trackerNotCimasTitlebut4x4["Socrata Link"].values.tolist()
titls=assetsDf.loc[assetsDf["uid"].isin(w4)][["uid","name"]].values.tolist()
titls={lst[0]:lst[1] for lst in titls}
#print(titls)
for indx,row in trackerNotCimasTitlebut4x4.iterrows():
     t4x4 = row['Socrata Link']
     ctitl = titls[t4x4]
     print(f"{len(row['Dataset Title'])} {row['Dataset Title']}: {len(ctitl)} {ctitl}")
     print()

# %% [markdown]
# ### Dataset on CIM but Not in Tracker

# %%
# CIM Not in Tracker
assetsCimDf=assetsDf.loc[(assetsDf["owner"] == "Colorado Information Marketplace")]

cimNotTracker=assetsCimDf.loc[~assetsCimDf["name"].str.strip().isin(titlesTracker)]  # get all datasets on cim not in tracker
display("By Title: ",cimNotTracker.shape)

cimNotTracker=cimNotTracker.loc[~cimNotTracker["uid"].str.strip().isin(maps4x4Tracker)] # remove maps that are listed as a map viz for a dataset
display("By Title and Map 4x4: ",cimNotTracker.shape)

cimNotTrackerDrafts=cimNotTracker.loc[cimNotTracker["uid"].str.len() != 9] # get the Drafts
display("By Title and Map 4x4 These ARE  Drafts: ",cimNotTrackerDrafts.shape)
cimNotTrackerDrafts[columns2Output].to_csv("Output/cimNotTrackerDrafts.tsv",index=False,sep="\t")

cimNotTracker=cimNotTracker.loc[cimNotTracker["uid"].str.len() == 9] # remove all drafts
display("By Title and Map 4x4 No Drafts: ",cimNotTracker.shape)

cimNotTracker4x4=cimNotTracker.loc[cimNotTracker["uid"].isin(w4x4Tracker)] # use 4x4 to catch title mis-match
display("By Title,4x4  and Map 4x4 w/ 4x4: ",cimNotTracker4x4.shape)
cimNotTracker4x4[columns2Output].to_csv("Output/cimNotTrackerDataset4x4.tsv",index=False,sep="\t")
display(cimNotTracker4x4.head())

cimNotTracker=cimNotTracker.loc[~cimNotTracker["uid"].isin(w4x4Tracker)] # use 4x4 to catch title mis-match
display("By Title,4x4  and Map 4x4 No Drafts: ",cimNotTracker.shape)
cimNotTracker[columns2Output].to_csv("Output/cimNotTrackerFinal.tsv",index=False,sep="\t")

#display(cimNotTracker.head(100))

# %%
249-87

# %%
cimNotTracker.shape

# %%
cimNotTracker["owner"].value_counts()

# %%
display(cimNotTracker['audience'].value_counts())
print()
display(cimNotTracker['publication_stage'].value_counts())
print()
display(cimNotTracker['type'].value_counts())
print()
print('Missing Row Counts',cimNotTracker['row_count'].isna().sum())
print()
print('Missing Row Counts for Published Datasets ',cimNotTracker.loc[cimNotTracker['publication_stage'] == 'published','row_count'].isna().sum())
print('Non-Missing Row Counts for Published Datasets ',cimNotTracker.loc[cimNotTracker['publication_stage'] == 'published','row_count'].count())

#display(cimNotTracker.loc[cimNotTracker['publication_stage'] == 'published',['uid','name','row_count']].head(100))

display(cimNotTracker[['publication_stage','audience','name']].groupby(['audience','publication_stage']).count())
display(cimNotTracker[['publication_stage','audience','name']].groupby(['audience','publication_stage']).count())

tmp=cimNotTracker.loc[cimNotTracker['publication_stage','audience','name']]

# %%
def ncount(series):
    return series.count()

def count_non_na(series):
    return series.count()

# Function to count missing values
def count_na(series):
    return series.isna().sum()

# Group by 'Category' and aggregate counts of missing and non-missing values
grouped = cimNotTracker.groupby(['audience','publication_stage','type'],as_index=False).agg(all_values=('audience',ncount),
    non_missing_values=('row_count', count_non_na),
    missing_values=('row_count', count_na)
)

groupedP = cimNotTracker.groupby(['audience','publication_stage','type']).agg(all_values=('audience',ncount),
    non_missing_values=('row_count', count_non_na),
    missing_values=('row_count', count_na)
)

# %%
groupedP

# %%
grouped.to_csv("Output/cimNotTrackerFinalGroups.tsv",index=False,sep="\t")

# %%
for indx,row in grouped.iterrows():
    aud=row['audience']
    pub=row['publication_stage']
    typ=row['type']
    tmp=cimNotTracker.loc[(cimNotTracker['publication_stage'] == pub) & (cimNotTracker['audience'] == aud) & (cimNotTracker['type'] == typ)]
    print(aud,typ,pub,tmp.shape[0])
#    display(tmp[columns2Output].sort_values(by=["approval_status","name"]).head(20))
    string=f"Output/cimNotTracker-{aud}-{typ}-{pub}.tsv"
    print(string)
    tmp[columns2Output].sort_values(by=["approval_status","name"]).to_csv(string,index=False,sep="\t")

# %% [markdown]
# ### Tracker Datasets Not Owned on CIM

# %%
# Datasets in Tracker with Duplicate titles on CIM, but have different 4x4s (i.e. different datasets) and we are NOT the owner
tmp=assetsDf.loc[(assetsDf["name"].isin(titlesTracker)) & (assetsDf["owner"] != "Colorado Information Marketplace") & (~assetsDf["uid"].isin(w4x4sTracker))]

# %%
tmp.head()

# %%
tmp.groupby(["owner"])["name"].count()

# %%
tmp.shape

# %%
ncount=0
notInTracker=None
trackerNotOwnedByTitle=None
for indx,row in tmp.iterrows():
    ncount+=1
    title=row['name']
    hld=assetsDf.loc[(assetsDf["name"] == title) & (assetsDf["uid"].str.len() ==9)]
    
    if hld.shape[0] < 2:
        print(title)
        notInTracker=pd.concat([notInTracker,hld])
    else:
        trackerNotOwnedByTitle=pd.concat([trackerNotOwnedByTitle,hld])
print(trackerNotOwnedByTitle.shape)      
trackerNotOwnedByTitle[columns2Output].to_csv("Output/trackerNotOwnedOnCimByTitle.tsv",index=False,sep="\t")  
#notInTracker[columns2Output].to_csv("Output/

# %%
notInTracker[columns2Output].to_csv("Output/trackerNotOwnedOnCimByTitleNotTracker.tsv",index=False,sep="\t")

# %%
notInTracker.loc[notInTracker["name"].isin(titlesTracker)].shape

# %%
display(trackerDf.head(3))

# %%
merged=None
fout=open("Output/trackerOnCimSameTitleDiff4x4.tsv","w")
header=["Source","4x4","Title","Creation Date","Row Count","Owner"]
string= "\t".join(header)
print(string)
fout.write(f"{string}\n")
for indx,row in trackerDf.loc[trackerDf["Dataset Title"].isin(notInTracker["name"])].iterrows():
    titleT=row["Dataset Title"]
    w4x4T=row["Socrata Link"]
    dateT=row["Date Published to CIM"]
    hldC=notInTracker.loc[notInTracker["name"] == titleT,["uid","name","creation_date","row_count","owner"]]
    hldC["creation_date"] = hldC["creation_date"].astype(str)
    hldC=hldC.values.tolist()
    stringC="CIM Asset\t"
    stringC+= '\t'.join(hldC[0])
    hldT= trackerDf.loc[trackerDf["Dataset Title"]==titleT,["Socrata Link","Dataset Title","Date Published to CIM","Row Count (11/20/17)"]].values.tolist()   
    hldT=[str(val) for val in hldT[0]]
    hldT.append("Colorado Information Marketplace")
    stringT="Dataset Tracker\t"
    stringT+= '\t'.join(hldT)
    print(stringT)
    fout.write(f"{stringC}\n")
    fout.write(f"{stringT}\n")

fout.close()

# %%
notInTracker.columns

# %%
# All Datasets in Tracker that we do NOT ownn on CIM, by 4x4
trackerNotOwnedCimBy4x4=assetsDf.loc[(assetsDf["uid"].isin(w4x4sTracker)) & (assetsDf["owner"] != "Colorado Information Marketplace")]
display(trackerNotOwnedCimBy4x4.head(20))
trackerNotOwnedCimBy4x4[columns2Output].to_csv("Output/trackerNotOwnedCimBy4x4.tsv",index=False,sep="\t")

# %% [markdown]
# ## Tracker N/A in 'cimAllData Updates' Column

# %%
trackerDf.columns

# %%
trackerDf['cimAllData Updates'].value_counts()
missingUpdts = trackerDf.loc[trackerDf['cimAllData Updates'] == "#N/A"]
tmp=assetsDf.loc[assetsDf["name"].isin(missingUpdts["Dataset Title"])]
print(tmp.shape)
print(missingUpdts.shape)

# %%
display(tmp[columns2Output].head(30))

# %%
tmp["name"].value_counts()

# %%
tmp["audience"].value_counts()

# %%
tmp.groupby(["audience","owner"])["name"].count()

# %%
tmp.loc[(tmp["owner"] == "Colorado Information Marketplace")].to_csv("Output/trackerMissingCimUpateOurs.tsv",index=False,sep="\t")
tmp.loc[~(tmp["owner"] == "Colorado Information Marketplace")].to_csv("Output/trackerMissingCimUpateNotOurs.tsv",index=False,sep="\t")

# %%
tmp[['uid','name','owner','audience','creation_date','last_data_updated_date','type','url']].to_csv("privateOnCim.csv",index=False)

# %%
sorted(tmp.columns)

# %%
assetsDf.loc[assetsDf['name'] == "Festival Permits in Colorado"]

# %%
tmp[["uid","name","publication_stage"]]

# %%
trackerDf.loc[trackerDf["Dataset Title"].isin(titles)].shape

# %%
w4x4=[]
audience=[]
stage=[]
types=[]
creation=[]
name=[]

for row in notInTracker:
   
        w4x4.append(row["UID"])
        audience.append(row["Audience"])
        stage.append(row["Publication Stage"])
        types.append(row["Type"])
        creation.append(row["Creation Date (UTC)"])
        name.append(row["Name"])

sumry=pd.DataFrame({
    "Title":name,
    "Audience":audience,
    "Stage":stage,
    "Types":types,
    "4x4":w4x4,
    "Created":creation
})

# %%
sumry

# %%
lst=trackerDf["Keywords"].values.tolist()
hist={}
for val in lst:
    spl=val.split()
    for kw in spl:
        if kw not in hist:
            hist[kw]=0
        hist[kw]+=1

# %%
sorted_dict = dict(sorted(hist.items(), key=lambda item: item[1],reverse=True))

# %%
sorted_dict

# %%
sumry.to_csv("datasetsNotInTracker.csv",index=False)

# %%
notFound={}
found={}
for indx,row in track.iterrows():
    trackTitle=row["Dataset Title"]
    w4x4=row["Socrata Link"]
    
    tmp=assets.loc[(assets["Name"] == trackTitle) | (assets["UID"] == w4x4)]
    if tmp.shape[0]>0:
        print(tmp['Audience'].values[0])
        found[w4x4]=tmp
        print(row["Dataset Title"])
        
    else:
        print("Not Found",w4x4,trackTitle)
        notFound[w4x4]=row

# %%
row[0]

# %%
found.keys()

# %%
for w4x4 in found.keys():
    tmp=found[w4x4]
    display(tmp[["Owner","Audience","Creation Date (UTC)","API Endpoint","Name"]].head(100))

# %%
for key in sorted(found[w4x4].keys()):
    print(key)

# %%
["Dataset Title","Date of Initial Dataset Creation",'Date Published to CIM']

# %%
assets[0]

# %%
from ftplib import FTP

# %%
try:
    # Connect to the FTP server
    ftp = FTP('https://download.bls.gov/pub/time.series/sm/sm.data.6.Colorado')
    ftp.login()
except Exception as err:
 print("Error ",err)

# %%
import requests

def download_file(url, local_filename):
    headers = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'
    }
    # Send a HTTP GET request with custom headers
    with requests.get(url, headers=headers, stream=True) as response:
        response.raise_for_status()  # Check for HTTP errors
        # Open a local file in binary write mode
        with open(local_filename, 'wb') as file:
            # Write the content to the local file in chunks
            for chunk in response.iter_content(chunk_size=8192):
                file.write(chunk)
    print(f"Downloaded {local_filename}")

# Example usage
url = ''
local_filename = 'data.csv'
download_file('https://download.bls.gov/pub/time.series/sm/sm.data.6.Colorado', local_filename)
