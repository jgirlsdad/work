# %% [markdown]
# # Compare

# %%
import sys
import argparse
import os.path
bic_etl_home = os.getenv('bic_etl_home')
## Add the bic_etl/general/script directory to path 
sys.path.insert(0, os.path.join(bic_etl_home, 'general', 'scripts'))
import custom_log
import pandas as pd
import re
import time
import csv

# %% [markdown]
# ## Compare Datasets

# %%
fin1 = open("/home/joe/bic_etl/cdos/business/business/data_source/business_entities.tsv",encoding="latin")

linesOrg = fin1.readlines()
fin1.close()

#fin2 = open("business_entities-new.csv")
fin2 = open("/home/joe/bic_etl/cdos/business/business/data_transformed/business_entities.csv",encoding="latin")
linesTrn = fin2.readlines()
fin2.close()

ngood=0
nbad=0
nlines=0
for nline,line in enumerate(linesOrg):
    # print(len(line),len(linesTrn[nline]))
    bad=0
    nlines+=1
    if nline > 0:
        for nn,c1 in enumerate(line):
            if nline%10000 == 0 and nn%10 == 0:
                c1="D"
            if linesTrn[nline][nn:nn+1] != c1:
                # print(nline,nn,linesTrn[nline][nn:nn+1],c1)
                bad+=1
        if nbad > 0:
            print(nline,bad)
            nbad+=1
        else:
            ngood+=1

display(f"Total Lines: {nlines}")
display(f"Good  Lines: {ngood}")
display(f"Bad Lines: {nbad}")
# Out:
# 'Total Lines: 2653757'
# 'Good  Lines: 2653756'
# 'Bad Lines: 0'

# %%
fin1 = open("/home/joe/bic_etl/cdos/business/business/data_source/business_entities.tsv","rb")

linesOrg = fin1.readlines()
fin1.close()

# %%
fin1 = open("/home/joe/bic_etl/cdos/business/business/data_transformed/business_entities.tsv",encoding="latin")

linesOrg = fin1.readlines()
fin1.close()

# %%
for line in linesOrg:
    spl = line.split("\t")
    for val in spl:
        if val.count('"') > 2:
            print(line)

# %%
dfN=pd.read_csv("/home/joe/bic_etl/cdos/business/business/data_transformed/business_entities.tsv",delimiter="\t",encoding="latin")

# %%
dfO=pd.read_csv("/home/joe/bic_etl/cdos/business/business/data_source/business_entities.tsv",delimiter="\t",encoding="latin")

# %%
eid=
display(dfN.loc[dfN["entityId"] == eid,"entityName"])
display(df.loc[df["entityid"] == eid,"entityname"])

# %%
fin1 = open("/home/joe/bic_etl/cdos/business/business/data_source/business_entities.tsv","rb")

linesOrg = fin1.readlines()
fin1.close()

#fin2 = open("business_entities-new.csv")
fin2 = open("/home/joe/bic_etl/cdos/business/business/data_transformed/business_entities.tsv")
linesTrn = fin2.readlines()
fin2.close()

# %%
fin3 = open("Business_Entities_in_Colorado_20240423-CIM.csv")

linesCimC = fin3.readlines()
fin3.close()
print(len(linesCimC))

# %%
dfCimC = pd.read_csv("Business_Entities_in_Colorado_20240423-CIM.csv")
dfCimT = pd.read_csv("Business_Entities_in_Colorado_20240424-CIM.tsv",delimiter="\t")

# %%
fin4 = open("Business_Entities_in_Colorado_20240424-CIM.tsv")

linesCimT = fin4.readlines()
fin4.close()
print(len(linesCimT))

# %%
linesOrg[eid]

# %%
def getAsciiCodes():
    codesdf = pd.read_excel("/home/joe/Python/ascii-codes.xlsx",engine='openpyxl')
    asciiCodes={}
    for index,row in codesdf.iterrows():
        asciiCodes[row['DEC']] = {}
        asciiCodes[row['DEC']]['symbol'] = row['Symbol']
        asciiCodes[row['DEC']]['desc'] = row['Description']
    return asciiCodes
asciiCodes=getAsciiCodes()

# %%
eid=349840
eid=386592
spl1=linesOrg[eid].split("\t")
spl2=linesTrn[eid].split("\t")
ngood=0
for nn,val in enumerate(spl1):
    if val != spl2[nn]: 
       print(nn,val,spl2[nn]) 
    else:
        ngood+=1
        
print(ngood)

# %%
print(linesOrg[eid])
print(linesTrn[eid])

# %%
eid=386592
for nn,c in enumerate(linesOrg[eid]):
    cT=linesTrn[eid][nn:nn+1]
    print(nn,c,cT,ord(cT),c==ord(cT),asciiCodes[c]['desc'],asciiCodes[ord(cT)]['desc'])

# %%
histC={}
for line in linesCim:
    
    for c in line:
        nc=ord(c)
        if nc not in histC:
            histC[nc]=0
        histC[nc]==1

# %%
histC={}
def  analyzeString(string,hist,type=1): 
    for c in string:
        if type == 1:
            nc=ord(c)
        else:
            nc=c
        if nc not in hist:
            hist[nc]=0
        hist[nc]+=1
    return hist

for nn,line in enumerate(linesCim):
    if nn%300000 == 0:
        print(nn)
    histC=analyzeString(line,histC)

# %%
for val,count in sorted(histC.items()):
    print(val,count)

# %%
histO = {}
for nn,line in enumerate(linesOrg):
    if nn%300000 == 0:
        print(nn)
    histO=analyzeString(line,histO,2)

# %%
histT = {}
for nn,line in enumerate(linesTrn):
    if nn%300000 == 0:
        print(nn)
    histT=analyzeString(line,histT,1)

# %%
for val,count in sorted(histO.items()):
    if val in histT:
        countT=histT[val]
    else:
        countT=0
    print(val,count,countT,asciiCodes[val]['desc'])

# %%
print(len(linesOrg))
print(len(linesCim))

# %%
2647087*35

# %%
94556120-92648045

# %%
histCDelim={}
for line in linesCim:
    spl=line.split(",")
    nn=len(spl)
    if nn not in histCDelim:
        histCDelim[nn]=0
    histCDelim[nn]+=1

# %%
print(histCDelim)

# %%
histCTDelim={}
for line in linesCimT:
    spl=line.split("\t")
    nn=len(spl)
    if nn not in histCTDelim:
        histCTDelim[nn]=0
    histCTDelim[nn]+=1

# %%
print(histCTDelim)

# %%
dfCimC.head()

# %%
print(dfCimC.shape)
print(dfCimT.shape)

# %%
dfCimC.compare(dfCimT)

# %%
fin2 = open("/home/joe/bic_etl/cdos/business/business/data_source/business_entities.tsv",encoding="latin")
linesOrg = fin2.readlines()
fin2.close()

# %%
count=0
for line in linesOrg:
    spl = line.split("\t")
    for val in spl:
        if val.count('"') > 2:
            count+=1
            if count < 10:
                print(line)

# %%
count

# %%
def  analyzeString(string,hist,type=1): 
    for c in string:
        if type == 1:
            nc=ord(c)
        else:
            nc=c
        if nc not in hist:
            hist[nc]=0
        hist[nc]+=1
    return hist

# %%
fin2 = open("/home/joe/bic_etl/cdos/business/business/data_source/trademarks.tsv")
linesTM = fin2.readlines()
fin2.close()

# %%
hist={}
histNFields={}
for nline,line in enumerate(linesTM):
    hist=analyzeString(line,hist,1)
    spl=line.split("\t")
    nn=len(spl)
    if nn not in histNFields:
        histNFields[nn]=0
    histNFields[nn]+=1     
    
    for val in spl:
        if val.count('"') != 2 and val.count('"') != 0: 
            print(val.count('"'),val)

# %%
fin2 = open("Business_Entities_in_Colorado_20240424-CIM.tsv")
linesCim = fin2.readlines()
fin2.close()

# %%
histNFields

# %%
hist={}
histNFields={}
histNDoubleQuotes={}
for nline,line in enumerate(linesTrn):
    hist=analyzeString(line,hist,1)
    spl=line.split("\t")
    nn=len(spl)
    if nn not in histNFields:
        histNFields[nn]=0
    histNFields[nn]+=1     
    
    for val in spl:
        mm=val.count('"')
        if mm not in histNDoubleQuotes:
            histNDoubleQuotes[mm]=0
        histNDoubleQuotes[mm]+=1

# %%
histNFields

# %%
histNDoubleQuotes

# %%
fin2 = open("/home/joe/bic_etl/cdos/business/business/data_transformed/business_entities.csv")
linesJS = fin2.readlines()
fin2.close()

# %%
fin1 = open("/home/joe/bic_etl/cdos/business/business/data_source/business_entities.tsv",encoding='latin')

linesOrg = fin1.readlines()
fin1.close()

# %%
fin1 = open("/home/joe/bic_etl/cdos/business/business/data_source/business_entities.tsv",encoding="latin")

lines = fin1.readlines()
fin1.close()

# %%
nout=0
ngood=0
nline=0
fout = open("test.csv","w")
hist={}
for nline,line in enumerate(lines):
    spl=line.split("\t")
    
    if nline < 11:
        fout.write(line)
    for nn,val in enumerate(spl):
        mm=val.count('"')
        if mm > 2:
            fout.write(line)
            print(mm,nline)
            print(line)
            nout+=1
        if nout > 5:
            break
fout.close()

# %%
linesJS[1573]

# %%
linesCim[1573]

# %%
for line in linesCim:
    if line[:11] == '20051359945':
        print(line)
        break

# %%
for line in linesOrg:
    if line[1:12] == '20051359945':
        print(line)
        break
 #   print(line[1:11])

# %%
for line in linesTrn[1:]:
    if line[:11] == '20051359945':
        print(line)
        break

# %%
nout=0
ngood=0
nline=0
fout = open("test.csv","w")
hist={}
for nline,line in enumerate(lines):
    spl=line.split("\t")
    if nline == 0:
        header=spl
    for nn,val in enumerate(spl):
        mm=val.count('"')
        if mm != 0 and mm != 2:
            if nn not in hist:
                hist[nn]=0
            hist[nn]+=1

# %%
these= sorted(hist.keys())
for mm,cnt in hist.items():
    print(mm,header[mm],cnt)

# %% [markdown]
# ## Check Business Entities

# %%
#fin1 = open("/home/joe/bic_etl/cdos/business/business/data_source/business_entities.tsv","r",encoding="latin")
fin1 = open("/home/joe/bic_etl/cdos/business/business/data_source/business_entities.tsv","r",encoding="latin")
linesOrg = fin1.readlines()
fin1.close()

# fin2 = open("business_entities-new.csv")
# fin2 = open("/home/joe/bic_etl/cdos/business/business/data_source/business_entities-new.tsv")
# linesNew = fin2.readlines()
# fin2.close()

fin2 = open("/home/joe/bic_etl/cdos/business/business/data_transformed/business_entities.csv")
linesTrn = fin2.readlines()
fin2.close()

# %%
#fin1 = open("/home/joe/bic_etl/cdos/business/business/data_source/business_entities.tsv","r",encoding="latin")
fin1 = open("/home/joe/bic_etl/cdos/business/business/data_transformed/business_entities.tsv","r",encoding="latin")
reader = csv.DictReader(fin1,quoting=csv.QUOTE_NONE,quotechar='',delimiter='\t')
linesOrg=[]
for line in reader:
    linesOrg.append(line)
fin1.close()

# %%
fin1 = open("/home/joe/bic_etl/cdos/business/business/data_transformed/business_entities.csv","r",encoding="latin")
reader = csv.DictReader(fin1,delimiter=',')
linesTrn=[]
for line in reader:
    linesTrn.append(line)
fin1.close()

# %%
hist={}
nbad=0
total=0
for nn,rowO in enumerate(linesOrg):
   
   rowT = linesTrn[nn]
   for colO,valO in rowO.items():
       total+=1
       valT = rowT[colO]
       if colO in hist: 
         hist[colO]["Total"]+=1
       else:
        hist[colO]={}
        hist[colO]["Total"]=1
        hist[colO]["Bad"]=0
        
       if valT != valO:
          nbad+=1
          hist[colO]["Bad"]+=1
          if hist[colO]["Bad"] < 10:
             print(colO)
             print(valO)
             print(valT)
             print("---")
# Out:
# entityType
# DLLC
# Limited Liability Company
# ---
# entityFormDate
# 01/03/2001
# 2001-01-03T00:00:00.000
# ---
# entityType
# DPC
# Corporation
# ---
# entityFormDate
# 12/13/2000
# 2000-12-13T00:00:00.000
# ---
# principalCity
# DENVER
# Denver
# ---
# entityType
# DLLC
# Limited Liability Company
# ---
# entityFormDate
# 06/07/1996
# 1996-06-07T00:00:00.000
# ---
# entityType
# DPC
# Corporation
# ---
# entityFormDate
# 12/13/2000
# 2000-12-13T00:00:00.000
# ---
# entityType
# DLLC
# Limited Liability Company
# ---
# entityFormDate
# 03/22/2005
# 2005-03-22T00:00:00.000
# ---
# entityType
# DPC
# Corporation
# ---
# entityFormDate
# 06/24/1996
# 1996-06-24T00:00:00.000
# ---
# entityType
# DPC
# Corporation
# ---
# entityFormDate
# 12/13/2000
# 2000-12-13T00:00:00.000
# ---
# entityType
# DPC
# Corporation
# ---
# entityFormDate
# 05/05/1993
# 1993-05-05T00:00:00.000
# ---
# entityType
# DLLC
# Limited Liability Company
# ---
# entityFormDate
# 12/13/2000
# ...

# %%
for col,dct in hist.items():
    if hist[col]["Bad"] > 0:
        pp = hist[col]["Bad"]/hist[col]["Total"] * 100
        print(f"{col:30s}  {hist[col]['Bad']:9,d} {hist[col]['Total']:9,d} {pp:5.1f}")
# Out:
# principalAddress1                     261 2,670,455   0.0
# principalCity                     512,543 2,670,455  19.2
# mailingAddress1                         1 2,670,455   0.0
# mailingCity                       107,020 2,670,455   4.0
# entityType                      2,670,455 2,670,455 100.0
# agentMiddleName                         1 2,670,455   0.0
# agentLastName                           1 2,670,455   0.0
# agentPrincipalAddress1                  2 2,670,455   0.0
# entityFormDate                  2,670,455 2,670,455 100.0

# %%
trn2OrgXref = { 
    "entityId" :   "Entity Id",
    "entityName"             :"Entity Name",
    "principalAddress1"       :"Principal Address 1",
    "principalAddress1"       :"Principal Address 1",
    "principalAddress2"       :"Principal Address 2",
    "principalCity"           : "Principal City",
    "principalState"          :"Principal State",
    "principalZipCode"        :"Principal Zip",
    "principalCountry"        :"Principal Country",
    "mailingAddress1"         :"Mailing Address 1",
    "mailingAddress2"         :"Mailing Address 2",
    "mailingCity"             :"Mailing City",
    "mailingState"            :"Mailing State",
    "mailingZipCode"          :"Mailing Zip",
    "mailingCountry"          :"Mailing Country",
    "entityStatus"            :"Entity Status",
    "jurisdictonOfFormation"  :"Jurisdiction of Formation",
    "entityType"              : "Entity Type",
    "agentFirstName"          :"Agent First Name",
    "agentMiddleName"         :"Agent Middle Name",
    "agentLastName"           :"Agent Last Name",
    "agentSuffix"             :"Agent Suffix",
    "agentOrganizationName"   :"Agent Organization Name",
    "agentPrincipalAddress1"  :"Agent Principal Address 1",
    "agentPrincipalAddress2"  :"Agent Principal Address 2",
    "agentPrincipalCity"      :"Agent Principal City",
    "agentPrincipalState"     :"Agent Principal State",
    "agentPrincipalZipCode"   :"Agent Principal Zip",
    "agentPrincipalCountry"   :"Agent Principal Country",
    "agentMailingAddress1"    :"Agent Mailing Address 1",
    "agentMailingAddress2"    :"Agent Mailing Address 2",
    "agentMailingCity"        :"Agent Mailing City",
    "agentMailingState"       :"Agent Mailing State",
    "agentMailingZipCode"     :"Agent Mailing Zip",
    "agentMailingCountry"     :"Agent Mailing Country",
    "entityType"              :"Entity Type",
    "entityFormDate"          :"Entity Form Date" }

org2TrnXref = {val:key for key,val in trn2OrgXref.items()}

# %%
hist
# Out:
# {'entityType': 2670455,
#  'entityFormDate': 2670455,
#  'principalCity': 512543,
#  'mailingCity': 107020,
#  'principalAddress1': 261,
#  'agentPrincipalAddress1': 2,
#  'agentMiddleName': 1,
#  'agentLastName': 1,
#  'mailingAddress1': 1}

# %%
#fin1 = open("/home/joe/bic_etl/cdos/business/business/data_source/business_entities.tsv","r",encoding="latin")
fin1 = open("/home/joe/bic_etl/cdos/business/business/data_source/corpmstr-test.txt","r",encoding="latin")
linesOrg = fin1.readlines()
fin1.close()


fin2 = open("/home/joe/bic_etl/cdos/business/business/data_transformed/business_entities.csv")
linesTrn = fin2.readlines()
fin2.close()

# %%
from io import StringIO
line=linesOrg[0:60]
csv_input = csv.DictReader(StringIO(linesOrg[0:60], newline='\n'), delimiter='\t')

# %%
for row in csv_input:
    print(row)

# %%
line = linesOrg[60]
for line in linesOrg[57:62]:
    hist={}
    for c in line:
        nn=ord(c)
        if nn not in hist:
            hist[nn]=0
        hist[nn]+=1
    for mm,cnt in sorted(hist.items()):
        print(mm,cnt)
    print("----")

# %%
for nn,line in enumerate(linesOrg[:100]):
    print(nn,line[:11],linesTrn[nn][:11])

# %%
print(len(linesOrg))
print(len(linesTrn))

# %%
hist={}
for line in linesTrn:
    spl = line.split(",")
    nn = len(spl)
    if nn not in hist:
        hist[nn]=0
    hist[nn]+=1

# %%
print(len(linesDictOrg))
print(len(linesDictTrn))

# %%
for nline,rowO in enumerate(linesDictOrg):
    rowT = linesDictTrn[nline]
    
    print(nline,rowO["Entity Id"],rowT["entityId"])

# %%
def  analyzeString(string,hist,histNFields,histNDoubleQuotes,type=1,delimiter=","): 
    for c in string:
        if type == 1:
            nc=ord(c)
        else:
            nc=c
        if nc not in hist:
            hist[nc]=0
        hist[nc]+=1
    spl=line.split(delimiter)    
    nn = len(spl)
    if nn not in histNFields:
        histNFields[nn]=0
    histNFields[nn]+=1
    for mm,val in enumerate(spl):
        ndq = val.count('"')
        if ndq not in histNDoubleQuotes[mm]:
            histNDoubleQuotes[mm][ndq]=0
        histNDoubleQuotes[mm][ndq]+=1
    
    return hist,histNFields,histNDoubleQuotes

def getAsciiCodes():
    codesdf = pd.read_excel("/home/joe/Python/ascii-codes.xlsx",engine='openpyxl')
    asciiCodes={}
    for index,row in codesdf.iterrows():
        asciiCodes[row['DEC']] = {}
        asciiCodes[row['DEC']]['symbol'] = row['Symbol']
        asciiCodes[row['DEC']]['desc'] = row['Description']
    return asciiCodes
asciiCodes=getAsciiCodes()



def analyzeDataset(file,delimiter=","):
    fin1 = open(file,"r")
    lines = fin1.readlines()
    fin1.close()
    histChars={}
    histNFields={}
    histNDoubleQuotes = {}
    
    for nline,line in enumerate(lines[:100000]):
        if nline == 0:
           header=line.split("\t")
           for mm in range(len(header)):
               histNDoubleQuotes[mm]={}
        histChars,histNFields,histNDoubleQuotes=analyzeString(line,histChars,histNFields,histNDoubleQuotes,delimiter=delimiter)
    return histChars,histNFields,histNDoubleQuotes

# %%
def  analyzeString(string,hist,type=1): 
    for c in string:
        if type == 1:
            nc=ord(c)
        else:
            nc=c
        if nc not in hist:
            hist[nc]=0
        hist[nc]+=1
    return hist

def getAsciiCodes():
    codesdf = pd.read_excel("/home/joe/Python/ascii-codes.xlsx",engine='openpyxl')
    asciiCodes={}
    for index,row in codesdf.iterrows():
        asciiCodes[row['DEC']] = {}
        asciiCodes[row['DEC']]['symbol'] = row['Symbol']
        asciiCodes[row['DEC']]['desc'] = row['Description']
    return asciiCodes
asciiCodes=getAsciiCodes()

# %%
t1=time.time()

histOrgChars={}
histOrgNFields={}
histNDoubleQuotes={}
for nline,line in enumerate(linesOrg):
    histOrgChars=analyzeString(line,histOrgChars,1)
    spl=line.split("\t")
    nn=len(spl)
    if nn not in histOrgNFields:
        histOrgNFields[nn]=0
    histOrgNFields[nn]+=1
    
t2 = time.time()
print(t2-t1)

# %%
t1=time.time()
# fin2 = open("/home/joe/bic_etl/cdos/business/business/data_source/business_entities-new.tsv")
# linesNew = fin2.readlines()
# fin2.close()
histNewChars={}
histNewNFields={}
histNDoubleQuotes={}
for nline,line in enumerate(linesNew):
    histNewChars=analyzeString(line,histNewChars,1)
    spl=line.split("\t")
    nn=len(spl)
    if nn not in histNewNFields:
        histNewNFields[nn]=0
    histNewNFields[nn]+=1
    
t2 = time.time()
print(t2-t1)

# %%
t1=time.time()
# fin2 = open("/home/joe/bic_etl/cdos/business/business/data_source/business_entities-new.tsv")
# linesNew = fin2.readlines()
# fin2.close()
histTrnChars={}
histTrnNFields={}
histNDoubleQuotes={}
for nline,line in enumerate(linesTrn):
    histTrnChars=analyzeString(line,histTrnChars,1)
    spl=line.split("\t")
    nn=len(spl)
    if nn not in histTrnNFields:
        histTrnNFields[nn]=0
    histTrnNFields[nn]+=1
    
t2 = time.time()
print(t2-t1)

# %%
for val,cnt in sorted(histOrgChars.items()):
    if val in histNewChars:
        cntN=histNewChars[val]
    else:
        cntN=0
    if cnt != cntN:
        print(val,cnt,cntN,asciiCodes[val]['desc'],cnt-cntN)

# %%
for val,cnt in sorted(histOrgChars.items()):
    if val in histTrnChars:
        cntN=histTrnChars[val]
    else:
        cntN=0
    if cnt != cntN:
        print(val,cnt,cntN,asciiCodes[val]['desc'],cnt-cntN)

# %%
#fin1 = open("/home/joe/bic_etl/cdos/business/business/data_source/business_entities.tsv","r",encoding='latin')
fin1 = open("/home/joe/bic_etl/cdos/business/business/data_source/business_entities.tsv","r",encoding='latin')

reader = csv.DictReader(fin1,quoting=csv.QUOTE_NONE,quotechar='',delimiter='\t')
#reader = csv.DictReader(fin1,delimiter='\t')
linesDictOrg = []
for row in reader:
   linesDictOrg.append(row)


# print("New")
# fin1 = open("/home/joe/bic_etl/cdos/business/business/data_source/business_entities-new.tsv","r")
# reader = csv.DictReader(fin1,delimiter='\t')
# linesDictNew = []
# for row in reader:
#    linesDictNew.append(row)


print("Transformed")
fin1 = open("/home/joe/bic_etl/cdos/business/business/data_transformed/business_entities.csv","r")
#reader = csv.DictReader(fin1)
reader = csv.DictReader(fin1,quoting=csv.QUOTE_NONE,quotechar='',delimiter='\t')
linesDictTrn = []
for row in reader:
   linesDictTrn.append(row)
# Out:
# Transformed

# %%
len(linesDictOrg)

# %%
df = pd.read_csv("/home/joe/bic_etl/cdos/business/business/data_source/business_entities.tsv",encoding="latin",quoting=csv.QUOTE_NONE,skip_blank_lines=False,delimiter="\t")
# Out:
# /home/joe/anaconda3/envs/bic/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3072: DtypeWarning: Columns (29) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
for col in sorted(df.columns):
    print(col)
# Out:
# Agent First Name
# Agent Last Name
# Agent Mailing Address 1
# Agent Mailing Address 2
# Agent Mailing City
# Agent Mailing Country
# Agent Mailing State
# Agent Mailing Zip
# Agent Middle Name
# Agent Organization Name
# Agent Principal Address 1
# Agent Principal Address 2
# Agent Principal City
# Agent Principal Country
# Agent Principal State
# Agent Principal Zip
# Agent Suffix
# Entity Form Date
# Entity Id
# Entity Name
# Entity Status
# Entity Type
# Jurisdiction of Formation
# Mailing Address 1
# Mailing Address 2
# Mailing City
# Mailing Country
# Mailing State
# Mailing Zip
# Principal Address 1
# Principal Address 2
# Principal City
# Principal Country
# Principal State
# Principal Zip

# %%
dfCIM = pd.read_csv("https://data.colorado.gov/resource/4ykn-tg5h.csv?$limit=10000000")

# %%
dfCIM.shape
# Out:
# (2667732, 35)

# %%
dfCIM["entitytype"].value_counts()
# Out:
# Limited Liability Company                                     1771207
# Corporation                                                    485065
# Nonprofit Corporation                                          117480
# Foreign Corporation                                            110258
# Foreign Limited Liability Company                              104629
# Limited Partnership                                             21922
# Limited Liability Partnership                                   13029
# Limited Liability Limited Partnership                           11588
# Foreign Limited Partnership                                      8231
# Foreign Nonprofit Corporation                                    7702
# Foreign Other                                                    4800
# General Partnership                                              3676
# Corporation-Public Benefit Corporation                           2597
# ...

# %%
for col in sorted(dfCIM.columns):
    print(col)
# Out:
# agentfirstname
# agentlastname
# agentmailingaddress1
# agentmailingaddress2
# agentmailingcity
# agentmailingcountry
# agentmailingstate
# agentmailingzipcode
# agentmiddlename
# agentorganizationname
# agentprincipaladdress1
# agentprincipaladdress2
# agentprincipalcity
# agentprincipalcountry
# agentprincipalstate
# agentprincipalzipcode
# agentsuffix
# entityformdate
# entityid
# entityname
# entitystatus
# entitytype
# jurisdictonofformation
# mailingaddress1
# mailingaddress2
# mailingcity
# mailingcountry
# mailingstate
# mailingzipcode
# principaladdress1
# principaladdress2
# principalcity
# principalcountry
# principalstate
# principalzipcode

# %%
df['Entity Form Date'].value_counts()
# Out:
# 01/01/2005    1447
# 05/10/2023    1368
# 01/03/2023    1325
# 01/05/2023    1320
# 01/01/2019    1233
#               ...
# 05/16/1938       1
# 11/03/1960       1
# 06/26/1937       1
# 10/05/1894       1
# 03/21/1961       1
# Name: Entity Form Date, Length: 22292, dtype: int64

# %%
dfCIM['entityformdate'].value_counts()
# Out:
# 2005-01-01T00:00:00.000    1447
# 2023-05-10T00:00:00.000    1368
# 2023-01-03T00:00:00.000    1325
# 2023-01-05T00:00:00.000    1320
# 2019-01-01T00:00:00.000    1232
#                            ...
# 1947-07-09T00:00:00.000       1
# 1871-03-03T00:00:00.000       1
# 1948-01-12T00:00:00.000       1
# 1998-08-30T00:00:00.000       1
# 1928-07-11T00:00:00.000       1
# Name: entityformdate, Length: 22326, dtype: int64

# %%
df = pd.read_csv("/home/joe/bic_etl/cdos/business/business/data_transformed/business_entities.csv",encoding="latin",quoting=3,skip_blank_lines=False,delimiter="\t")
# Out:
# /home/joe/anaconda3/envs/bic/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3072: DtypeWarning: Columns (29) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
fin = open("/home/joe/bic_etl/cdos/business/business/data_transformed/business_entities.csv")
hist={}
for line in fin:
    spl=line.split("\t")
    nn=len(spl)
    if nn in hist:
        hist[nn]+=1
    else:
        hist[nn]=1

# %%
hist
# Out:
# {35: 2653757}

# %%
nbad=0
histBad={}
histBadTotal={}
histBadMap={}

for nline,row1 in enumerate(linesDictOrg):
    rowT=linesDictTrn[nline]
 #   rowN=linesDictNew[nline]
    
    for key in row1:
 #       if key.lower().count("tradename form")  > 0:
     #   if key != "Registrant Name":
            keyT = org2TrnXref[key]
      #      print(key,keyT)
            keyN=key
      #      if row1[key] != rowT[keyT] and len(rowT[keyT]) == 0:
            if key == "Entity Type":
               if len(rowT[keyT]) < 2:
                    print(key,rowT[keyT])
            if row1[key] != rowT[keyT] :
                    val=row1[key]
                    valT=rowT[keyT]
                    print(nline,key,row1[key])
                    print(nline,key,rowT[keyT])
                    print(row1)
                    print("-----")
                    
                    if key not in histBadMap:
                        histBadMap[key]={}
                        
                    if val not in histBadMap[key]:
                        histBadMap[key][val]={}
                        histBadMap[key][val]['count']=0
                    
                    histBadMap[key][val]['count']+=1
                    
                    histBadMap[key][val]['val']=valT
                    if key not in histBad:
                        histBad[key] = {}

                    if val not in histBad[key]:
                        histBad[key][val]=0

                    histBad[key][val]+=1

                    nbad+=1

# %%
print(nbad)
print(len(linesDictOrg))
print(len(linesDictTrn))
# Out:
# 0
# 2653756
# 2653756

# %%
for key,dct in histBad.items():
    tot=0
    for k,cnt in dct.items():
        tot+=cnt
    print(key,tot)

# %%
for k,dct in histBadMap['Entity Type'].items():
    if len(dct['val']) < 2:
        print(dct['count'],f"Old: {k}  New: {dct['val']}")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-8-cd89938bc71a> in <module>
# ----> 1 for k,dct in histBadMap['Entity Type'].items():
#       2     if len(dct['val']) < 2:
#       3         print(dct['count'],f"Old: {k}  New: {dct['val']}")
#
# KeyError: 'Entity Type'

# %%
nrec=58
rowO = linesDictOrg[nrec]
rowT = linesDictTrn[nrec]

for keyO in rowO:
    keyT = org2TrnXref[keyO]
    print(keyO,keyT)
    print(f"Org: {rowO[keyO]}")    
    print(f"New: {rowT[keyT]}")    
    print("----")

# %%
for key,dct in histBadMap.items():
    print(key)
    for k,dct2 in dct.items():
     #   if len(dct2['val']) < 2: 
          print(key,dct2['count'],f"Org: {k} New:{dct2['val']}")

# %%
fin = open("/home/joe/bic_etl/cdos/business/business/data_transformed/business_entities.tsv")
hist={}
for line in fin:
    spl = line.split("\t")
    nn=len(spl)
    if nn in hist:
        hist[nn]+=1
    else:
        hist[nn]=1

# %%
hist
# Out:
# {35: 2653757}

# %%
fin2 = open("Business_Entities_in_Colorado_20240427-CIM.tsv")
linesCimT = fin2.readlines()
fin2.close()

fin2 = open("Business_Entities_in_Colorado_20240427-CIM.csv")
linesCimC = fin2.readlines()
fin2.close()

# %%
dfCimC = pd.read_csv("Business_Entities_in_Colorado_20240427-CIM.csv")

# %%
dfCimT = pd.read_csv("Business_Entities_in_Colorado_20240427-CIM.tsv",delimiter="\t")

# %%
histTrnChars={}
histTrnNFields={}
histNDoubleQuotes={}
for nline,line in enumerate(linesTrn):
    histTrnChars=analyzeString(line,histTrnChars,1)
    spl=line.split("\t")
    nn=len(spl)
    if nn not in histTrnNFields:
        histTrnNFields[nn]=0
    histTrnNFields[nn]+=1

# %%
histCimChars={}
histCimNFields={}
histNDoubleQuotes={}
for nline,line in enumerate(linesCim):
    histCimChars=analyzeString(line,histCimChars,1)
    spl=line.split("\t")
    nn=len(spl)
    if nn not in histCimNFields:
        histCimNFields[nn]=0
    histCimNFields[nn]+=1

# %%
for val,cnt in sorted(histOrgChars.items()):
    if val in histTrnChars:
        cntN=histTrnChars[val]
    else:
        cntN=0
    if cnt != cntN:
        print(val,cnt,cntN,asciiCodes[val]['desc'])

# %%
print(len(linesOrg))
print(len(linesCim))

# %%
nout=0
histNewChars={}
for nline,line in enumerate(linesOrg):
    histNewChars=analyzeString(line,histNewChars,1)
    spl=line.split("\t")
    nn=len(spl)
    for nn,val in enumerate(spl):
        mm = val.count('"')
        if mm > 2:
            print(nline,nn,mm,val)
            print(line)
            nout+=1
    if nout > 10:
        break

# %%
nout=0
histNewChars={}
for nline,line in enumerate(linesNew):
    histNewChars=analyzeString(line,histNewChars,1)
    spl=line.split("\t")
    nn=len(spl)
    for nn,val in enumerate(spl):
        mm = val.count('"')
        if mm > 2:
            print(nline,nn,mm,val)
            
            nout+=1
    if nout > 10:
        break

# %%
nout=0
histNewChars={}
for nline,line in enumerate(linesCim):
    histNewChars=analyzeString(line,histNewChars,1)
    spl=line.split("\t")
    nn=len(spl)
    for nn,val in enumerate(spl):
        mm = val.count('"')
        if mm > 2:
            print(nline,nn,mm,val)
            print(line)
            print("-----------------")
            nout+=1
    if nout > 10:
        break

# %%
for line in linesOrg[:4]:
    print(line)

# %%
nlines=0
eid= "20061277288"
print("Original")
for line in linesOrg:
    nlines+=1
    if line[1:12] == eid:
        print(line)
        break
        
nlines=0
print("Joes New")
for line in linesNew:
    nlines+=1
    if line[1:12] == eid:
        print(line)
        break
        
nlines=0
print("Transformed")
for line in linesTrn:
    nlines+=1
    if line[0:11] == eid:
        print(line)
        break
        
nlines=0
print("CIM tsv")

for line in linesCimT:
    nlines+=1
    if line[0:11] == eid:
        print(line)
        break
        
nlines=0
print("CIM csv")
for line in linesCimC:
    nlines+=1
    if line[0:11] == eid:
        print(line)
        break

# %%
dfCimC.loc[dfCimC["entityid"] == int(eid)]

# %%
dfCimT.loc[dfCimT["entityid"] == int(eid)]

# %%
389 1 6 """ABUNDANT LIFE FELLOWSHIP OF ELIZABETH, COLORADO"", Dissolved January 1, 1983"
19711235788	"""ABUNDANT LIFE FELLOWSHIP OF ELIZABETH, COLORADO"", Dissolved January 1, 1983"	123 Kiowa Street		Elizabeth	CO	80107	US

# %%
nbad=0
for nline,line in enumerate(linesOrg):
    line2=linesNew[nline]    
    for nn,c in enumerate(line):
        if c != line2[nn:nn+1]:
            print(nline,c,line2[nn:nn+1])
            print(line)
            print(line2)
            print("--------------------------------")
            nbad+=1
            break
    if nbad > 10:
        break

# %%
linesOrg[67969]

# %%
linesNew[67969]

# %% [markdown]
# ## Trademarks

# %%
fin1 = open("/home/joe/bic_etl/cdos/business/business/data_source/trademarks.tsv","r")
linesOrg = fin1.readlines()
fin1.close()

fin1 = open("/home/joe/bic_etl/cdos/business/business/data_source/trademarks-new.tsv","r")
linesNew = fin1.readlines()
fin1.close()

# %%
len(linesOrg[1].split("\t"))

# %%
def  analyzeString(string,hist,histNFields,histNDoubleQuotes,type=1,delimiter=","): 
    for c in string:
        if type == 1:
            nc=ord(c)
        else:
            nc=c
        if nc not in hist:
            hist[nc]=0
        hist[nc]+=1
    spl=line.split(delimiter)    
    nn = len(spl)
    if nn not in histNFields:
        histNFields[nn]=0
    histNFields[nn]+=1
    for mm,val in enumerate(spl):
        ndq = val.count('"')
        if ndq not in histNDoubleQuotes[mm]:
            histNDoubleQuotes[mm][ndq]=0
        histNDoubleQuotes[mm][ndq]+=1
    
    return hist,histNFields,histNDoubleQuotes

def getAsciiCodes():
    codesdf = pd.read_excel("/home/joe/Python/ascii-codes.xlsx",engine='openpyxl')
    asciiCodes={}
    for index,row in codesdf.iterrows():
        asciiCodes[row['DEC']] = {}
        asciiCodes[row['DEC']]['symbol'] = row['Symbol']
        asciiCodes[row['DEC']]['desc'] = row['Description']
    return asciiCodes
asciiCodes=getAsciiCodes()

# %%
histChars={}
histNFields={}
histNDoubleQuotes={}
for nline,line in enumerate(linesOrg):
    if nline == 0:
        header=line.split("\t")
        for nn in range(len(header)):
            histNDoubleQuotes[nn]={}
    histChars,histNFields,histNDoubleQuotes = analyzeString(line,histChars,histNFields,histNDoubleQuotes,1,delimiter="\t")

# %%
histChars,histNFields

# %%
histNDoubleQuotes

# %%
for nline,line in enumerate(linesNew):
    spl=line.split("\t")
    for nn,val in enumerate(spl):
        if val.count('"') > 2:
            splO=linesOrg[nline].split("\t")
            print(splO[nn])
            print(val)
            print("-----------------------------------------")

# %%
fin1 = open("/home/joe/bic_etl/cdos/business/business/data_source/trademarks.tsv","r")
linesOrg = fin1.readlines()
fin1.close()

fin1 = open("/home/joe/bic_etl/cdos/business/business/data_source/trademarks-new.tsv","r")
linesNew = fin1.readlines()
fin1.close()

fin1 = open("/home/joe/bic_etl/cdos/business/business/data_transformed/trademarks.csv","r")
linesTrn = fin1.readlines()
fin1.close()

# %%
lines=linesOrg.copy()
lines=linesNew.copy()
histNew={}
for nline,line in enumerate(lines):
    spl=line.split("\t")
    nn=len(spl)
    if nn != 14:
        print(nline,nn)
        print(line)
    if nn not in histNew:
        histNew[nn]=0
    histNew[nn]+=1

# %%
print(linesOrg[60])
print(linesNew[60])

# %%
print(len(linesOrg[60]))
print(len(linesNew[60]))

# %%
line = linesOrg[60]

for nn,c in enumerate(line):
    print(nn,ord(c),c)
    
line = linesNew[60]
for nn,c in enumerate(line):
    print(nn,ord(c),c)

# %%
print(len(linesOrg[60].split("\t")))
print(len(linesNew[60].split("\t")))

# %%
def  analyzeString(string,hist,histNFields,histNDoubleQuotes,type=1,delimiter=","): 
#    print("String Delim",ord(delimiter),delimiter)
    for c in string:
        if type == 1:
            nc=ord(c)
        else:
            nc=c
        if nc not in hist:
            hist[nc]=0
        hist[nc]+=1
    spl=string.split(delimiter)    
    nn = len(spl)
#   print("STRING ",nn,spl)
    if nn not in histNFields:
        histNFields[nn]=0
    histNFields[nn]+=1
    for mm,val in enumerate(spl):
        ndq = val.count('"')
        if ndq not in histNDoubleQuotes[mm]:
            histNDoubleQuotes[mm][ndq]=0
        histNDoubleQuotes[mm][ndq]+=1
    
    return hist,histNFields,histNDoubleQuotes

# %%
fileO="/home/joe/bic_etl/cdos/business/business/data_source/trademarks.tsv"
fileN="/home/joe/bic_etl/cdos/business/business/data_source/trademarks-new.tsv"
fileT="/home/joe/bic_etl/cdos/business/business/data_transformed/trademarks.csv"


def analyzeDataset(file,delimiter=","):
    
    print(file)
    fin1 = open(file,"r")
    lines = fin1.readlines()
    fin1.close()
    histChars={}
    histNFields={}
    histNDoubleQuotes = {}
    
    for nline,line in enumerate(lines):
        if nline == 0:
           header=line.split("\t")
           print("Header: ",len(header))
           for mm in range(len(header)):
               histNDoubleQuotes[mm]={}
        histChars,histNFields,histNDoubleQuotes=analyzeString(line,histChars,histNFields,histNDoubleQuotes,delimiter=delimiter)
    return histChars,histNFields,histNDoubleQuotes

histCharsO,histNFieldsO,histNDoubleQuotesO = analyzeDataset(fileO,delimiter="\t")
histCharsN,histNFieldsN,histNDoubleQuotesN= analyzeDataset(fileN,delimiter="\t")
histCharsT,histNFieldsT,histNDoubleQuotesT= analyzeDataset(fileT,delimiter="\t")

# %%
def compDict(A,B):
    for key,valA in sorted(A.items()):
        if key in B:
            valB = B[key]
        else:
            valB = 0
            
        if valA != valB:
            print(f"A->B  {key}  A:{valA}  B:{valB}  A-B:{valA-valB}")
            
            
    for key,valB in sorted(B.items()):
        if key in A:
            valA = A[key]
        else:
            valA = 0
            
        if valA != valB:
            print(f"B->A  {key}  B:{valB}  A:{valA}  B-A:{valB-valA}")
            
compDict(histCharsO,histCharsN)
compDict(histCharsO,histCharsT)

# %%
import csv
from io import StringIO

for nline,line1 in enumerate(linesOrg):
    
    if nline > 0:
        line2 = linesTrn[nline]
        spl2 = list(csv.reader(StringIO(line2,newline=''), delimiter=','))[0]

        spl1 = line1.split("\t")
        print(line1)
        print(line2)
        for mm,val1 in enumerate(spl1):
            val2 = spl2[mm]
            # if val1 != val2:
            print(f"{nline} {mm}  O:{val1}  B:{val2}")
        print("----------------")

# %%
import csv
for line in linesTrn:
    csv_input = list(csv.reader(StringIO(line,newline=''), delimiter=','))
    print(len(rows[0]))

# %%
var header_columns = [
    "masterTrademarkId",
    "entityId",
    "entityName",
    "status",
    "type",
    "registrationDate",
    "dateFirstUsed",
    "expirationDate",
    "goodServiceClass",
    "goodServiceDetail",
    "description",
    "trademarkForm",
    "entityStatus",
    "entityFormDate"
];

# %%
headerOrg=linesOrg[0].split("\t")

# %%
header

# %%
headerTrn = list(csv.reader(StringIO(linesTrn[0],newline=''), delimiter=','))[0]

# %%
headerTrn

# %%
Org2Trn = {headerOrg[mm]:headerTrn[mm] for mm in range(len(headerOrg))}
Trn2Org = {headerTrn[mm]:headerOrg[mm] for mm in range(len(headerTrn))}

# %%
Trn2Org

# %%
org2TrnXref

# %%
fin1 = open("/home/joe/bic_etl/cdos/business/business/data_source/trademarks.tsv","r")
linesOrg = fin1.readlines()
fin1.close()

fin1 = open("/home/joe/bic_etl/cdos/business/business/data_source/trademarks-new.tsv","r")
linesNew = fin1.readlines()
fin1.close()

fin1 = open("/home/joe/bic_etl/cdos/business/business/data_transformed/trademarks.csv","r")
linesTrn = fin1.readlines()
fin1.close()

fin1 = open("/home/joe/bic_etl/cdos/business/business/data_transformed/trademarks-bad.csv","r")
linesTrnB = fin1.readlines()
fin1.close()

# %%
len(linesTrn[6].split(","))

# %% [markdown]
# ### New

# %%
fin1 = open("/home/joe/bic_etl/cdos/business/business/data_source/trademarks.tsv","r")
reader = csv.DictReader(fin1,delimiter='\t')
linesDictOrg = []
for row in reader:
   linesDictOrg.append(row)

fin1 = open("/home/joe/bic_etl/cdos/business/business/data_source/trademarks-new.tsv","r")
reader = csv.DictReader(fin1,delimiter='\t')
linesDictNew = []
for row in reader:
   linesDictNew.append(row)

fin1 = open("/home/joe/bic_etl/cdos/business/business/data_transformed/trademarks.csv","r")
reader = csv.DictReader(fin1)
linesDictTrn = []
for row in reader:
   linesDictTrn.append(row)

# fin1 = open("/home/joe/bic_etl/cdos/business/business/data_transformed/trademarks-bad.csv","r")
# reader = csv.DictReader(fin1)
# linesDictTrnB = []
# for row in reader:
#    linesDictTrnB.append(row)

# %%
fin1 = open("/home/joe/bic_etl/cdos/business/business/data_source/trademarks-test.tsv","r")
reader = csv.DictReader(fin1,delimiter='\t')
linesDictOrg = []
for row in reader:
   linesDictOrg.append(row)

fin1 = open("/home/joe/bic_etl/cdos/business/business/data_transformed/trademarks-test.csv","r")
reader = csv.DictReader(fin1)
linesDictTrn = []
for row in reader:
   linesDictTrn.append(row)

# %%
fin1 = open("/home/joe/bic_etl/cdos/business/business/data_source/trademarks.tsv","r",encoding='latin')
linesOrg = fin1.readlines()
fin1.close()

fin1 = open("/home/joe/bic_etl/cdos/business/business/data_source/trademarks-new.tsv","r")
linesNew = fin1.readlines()
fin1.close()

fin1 = open("/home/joe/bic_etl/cdos/business/business/data_transformed/trademarks.csv","r")
linesTrn = fin1.readlines()
fin1.close()

fin1 = open("/home/joe/bic_etl/cdos/business/business/data_transformed/trademarks-bad.csv","r")
linesTrnB = fin1.readlines()
fin1.close()

# %%
def  analyzeString(string,hist,type=1): 
    for c in string:
        if type == 1:
            nc=ord(c)
        else:
            nc=c
        if nc not in hist:
            hist[nc]=0
        hist[nc]+=1
    return hist

def getAsciiCodes():
    codesdf = pd.read_excel("/home/joe/Python/ascii-codes.xlsx",engine='openpyxl')
    asciiCodes={}
    for index,row in codesdf.iterrows():
        asciiCodes[row['DEC']] = {}
        asciiCodes[row['DEC']]['symbol'] = row['Symbol']
        asciiCodes[row['DEC']]['desc'] = row['Description']
    return asciiCodes
asciiCodes=getAsciiCodes()

# %%
t1=time.time()

histOrgChars={}
histOrgNFields={}
histNDoubleQuotes={}
for nline,line in enumerate(linesOrg):
    histOrgChars=analyzeString(line,histOrgChars,1)
    spl=line.split("\t")
    nn=len(spl)
    if nn not in histOrgNFields:
        histOrgNFields[nn]=0
    histOrgNFields[nn]+=1
    
t2 = time.time()
print(t2-t1)

# %%
t1 = time.time()

histNewChars={}
histNewNFields={}
histNDoubleQuotes={}
for nline,line in enumerate(linesNew):
    histNewChars=analyzeString(line,histNewChars,1)
    spl=line.split("\t")
    nn=len(spl)
    if nn not in histNewNFields:
        histNewNFields[nn]=0
    histNewNFields[nn]+=1
    
t2 = time.time()
print(t2-t1)

# %%
for val,cnt in sorted(histOrgChars.items()):
    if val in histNewChars:
        cntN=histNewChars[val]
    else:
        cntN=0
    if cnt != cntN:
        print(val,cnt,cntN,asciiCodes[val]['desc'],cnt-cntN)

# %%
trn2OrgXref = {
'masterTrademarkId': 'Master Trademark ID',
 'entityId': 'Entity ID',
 'entityName': 'Registrant Name',
 'status': 'Trademark Status',
 'type': 'Trademark Type',
 'registrationDate': 'Registration Date',
 'dateFirstUsed': 'Date of First Use',
 'expirationDate': 'Expiration Date',
 'goodServiceClass': 'Goods and Services Class',
 'goodServiceDetail': 'Goods and Services Detail',
 'description': 'Trademark Description',
 'trademarkForm': 'Trademark Form',
 'entityStatus': 'Entity Status',
 'entityFormDate': 'Entity Form Date'
 }

org2TrnXref = {val:key for key,val in trn2OrgXref.items()}

# %%
nbad=0
histBad={}
for nline,row1 in enumerate(linesDictOrg):
    rowT=linesDictTrn[nline]
#    rowN=linesDictNew[nline]
    
    for key in row1:
        if key.lower().count("date") == 0:
     #   if key != "Registrant Name":
            keyT = org2TrnXref[key]
            keyN=key
      #      if row1[key] != rowT[keyT] and len(rowT[keyT]) == 0:
            if row1[key] != rowT[keyT] :
            
                # print(f"{nline} {key}:  O:{row1[key]}   {len(row1[key])}")
                # print(f"{nline} {key}:  N:{rowN[keyN]}  {len(rowN[keyN])}")
                # print(f"{nline} {key}:  T:{rowT[keyT]}  {len(rowT[keyT])}")
                # print()
                val=row1[key]
                if key not in histBad:
                    histBad[key] = {}
                    
                if val not in histBad[key]:
                    histBad[key][val]=0
                
                histBad[key][val]+=1
                
                nbad+=1
#                 print("O ",linesOrg[nline+1])
#                 print("N ",linesNew[nline+1])
                
#                 print("T ",linesTrn[nline+1])
#                 print("---------------")
  #              if nbad > 10: break

# %%
histBad.keys()

# %%
total=0
for key,dct in histBad.items():
    total=0
    for k,v in sorted(dct.items()):
    #    print(k,v)
        total+=v
    print(key,total)
print("Total ",total)

# %%
histBad["Registrant Name"]

# %%
nbad=0
histBad={}
histBadTotal={}
histBadMap={}

for nline,row1 in enumerate(linesDictTrn):
    rowT=linesDictTrnB[nline]
    rowN=linesDictNew[nline]
    
    for key in row1:
        # if key.lower().count("dtm") == 0 and key.count("Nm") == 0 and key.lower().count("city") == 0 and \
        # key.lower().count("zip") == 0 and key.lower().count("suffix") == 0:
 #       if key.lower().count("tradename form")  > 0:
     #   if key != "Registrant Name":
         #   keyT = org2TrnXref[key]
            keyT = key
        
            keyN=key
      #      if row1[key] != rowT[keyT] and len(rowT[keyT]) == 0:
            if row1[key] != rowT[keyT] :
               # if nbad < 100: 
            
                    val=row1[key]
                    valT=rowT[keyT]
                    if key not in histBadMap:
                        histBadMap[key]={}
                        
                    if val not in histBadMap[key]:
                        histBadMap[key][val]={}
                        histBadMap[key][val]['count']=0
                    
                    histBadMap[key][val]['count']+=1
                    
                    histBadMap[key][val]['val']=valT
                    if key not in histBad:
                        histBad[key] = {}

                    if val not in histBad[key]:
                        histBad[key][val]=0

                    histBad[key][val]+=1

                    nbad+=1

# %%
total=0
nrecs=0
for key,dct1 in histBadMap.items():
    for k2,dct2 in dct1.items():
        print(f"{key}  {dct2['count']}  New:{k2}  OLD:{dct2['val']}")
        total+=dct2['count']
        nrecs+=1
        
print(nrecs,total)

# %% [markdown]
# ## Trade Names

# %%
fin1 = open("/home/joe/bic_etl/cdos/business/business/data_source/tradenames.tsv","r",encoding='latin')
reader = csv.DictReader(fin1,delimiter='\t')
linesDictOrg = []
for row in reader:
   linesDictOrg.append(row)

fin1 = open("/home/joe/bic_etl/cdos/business/business/data_source/tradenames-new.tsv","r")
reader = csv.DictReader(fin1,delimiter='\t')
linesDictNew = []
for row in reader:
   linesDictNew.append(row)

fin1 = open("/home/joe/bic_etl/cdos/business/business/data_transformed/tradenames.csv","r")
reader = csv.DictReader(fin1)
linesDictTrn = []
for row in reader:
   linesDictTrn.append(row)

# %%
linesDictTrnB=[]
fin1 = open("/home/joe/bic_etl/cdos/business/business/data_transformed/tradenames-bad.csv","r")
reader = csv.DictReader(fin1)
for row in reader:
   linesDictTrnB.append(row)

fin1 = open("/home/joe/bic_etl/cdos/business/business/data_transformed/tradenames-good.csv","r")
linesTrnB = fin1.readlines()
fin1.close()

# %%
fin1 = open("/home/joe/bic_etl/cdos/business/business/data_source/tradenames.tsv","r",encoding='latin')
linesOrg = fin1.readlines()
fin1.close()

fin1 = open("/home/joe/bic_etl/cdos/business/business/data_source/tradenames-new.tsv","r")
linesNew = fin1.readlines()
fin1.close()

fin1 = open("/home/joe/bic_etl/cdos/business/business/data_transformed/tradenames.csv","r")
linesTrn = fin1.readlines()
fin1.close()

# %%
def  analyzeString(string,hist,type=1): 
    for c in string:
        if type == 1:
            nc=ord(c)
        else:
            nc=c
        if nc not in hist:
            hist[nc]=0
        hist[nc]+=1
    return hist

def getAsciiCodes():
    codesdf = pd.read_excel("/home/joe/Python/ascii-codes.xlsx",engine='openpyxl')
    asciiCodes={}
    for index,row in codesdf.iterrows():
        asciiCodes[row['DEC']] = {}
        asciiCodes[row['DEC']]['symbol'] = row['Symbol']
        asciiCodes[row['DEC']]['desc'] = row['Description']
    return asciiCodes
asciiCodes=getAsciiCodes()

# %%
t1=time.time()

histOrgChars={}
histOrgNFields={}
histNDoubleQuotes={}
nDouble=0

for nline,line in enumerate(linesOrg):
    histOrgChars=analyzeString(line,histOrgChars,1)
    spl=line.split("\t")
    nn=len(spl)
    for val in spl:
        mm=val.count('"')
        if mm not in histNDoubleQuotes:
            histNDoubleQuotes[mm]=0
        histNDoubleQuotes[mm]+=1
        if val.count('"') != 2 and val.count('"') != 0:
            nDouble+=1
    if nn not in histOrgNFields:
        histOrgNFields[nn]=0
    histOrgNFields[nn]+=1
    
t2 = time.time()
print("# of Too Many Double Quotes ",nDouble)
print(t2-t1)

# %%
for nn,count in sorted(histNDoubleQuotes.items()):
    print(nn,count)

# %%
t1 = time.time()

histNewChars={}
histNewNFields={}
histNDoubleQuotes={}
for nline,line in enumerate(linesNew):
    histNewChars=analyzeString(line,histNewChars,1)
    spl=line.split("\t")
    nn=len(spl)
    if nn not in histNewNFields:
        histNewNFields[nn]=0
    histNewNFields[nn]+=1
    
t2 = time.time()
print(t2-t1)

# %%
for val,cnt in sorted(histOrgChars.items()):
    if val in histNewChars:
        cntN=histNewChars[val]
    else:
        cntN=0
    if cnt != cntN:
        print(val,cnt,cntN,asciiCodes[val]['desc'],cnt-cntN)

# %%
org2TrnXref = {'Mstr Trdnm Id' : 'masterTradenameId',
'Trdnm Dscr' : 'tradenameDescription',
'Tradename Form' : 'tradenameForm',
'Entity Status' : 'entityStatus',
'Entity Form Date' : 'entityFormDate',
'Effective Dtm' : 'effectiveDate',
'First Nm' : 'firstName',
'Middle Nm' : 'middleName',
'Last Nm' : 'lastName',
'Suffix' : 'suffix',
'Registrant Organization' : 'registrantOrganization',
'Address1' : 'address1',
'Address2' : 'address2',
'City' : 'city',
'State' : 'state',
'Zip' : 'zipCode',
'Country' : 'country',
'Mailing Address 1' : 'mailingAddress1',
'Mailing Address 2' : 'mailingAddress2',
'Mailing City' : 'mailingCity',
'Mailing State' : 'mailingState',
'Mailing Zip' : 'mailingZipCode',
'Mailing Country' : 'mailingCountry',
'Add Dtm' : 'dateAdded',
'Entity ID' : 'entityId'}

# %%
nbad=0
histBad={}
histBadTotal={}
histBadMap={}

for nline,row1 in enumerate(linesDictOrg):
    rowT=linesDictTrn[nline]
    rowN=linesDictNew[nline]
    
    for key in row1:
        if key.lower().count("dtm") == 0 and key.count("Nm") == 0 and key.lower().count("city") == 0 and \
        key.lower().count("zip") == 0 and key.lower().count("suffix") == 0:
 #       if key.lower().count("tradename form")  > 0:
     #   if key != "Registrant Name":
            keyT = org2TrnXref[key]
            keyN=key
      #      if row1[key] != rowT[keyT] and len(rowT[keyT]) == 0:
            if row1[key] != rowT[keyT] :
               # if nbad < 100: 
            
                    # print(f"{nline} {key}:  O:{row1[key]}   {len(row1[key])}")
                    # print(f"{nline} {key}:  N:{rowN[keyN]}  {len(rowN[keyN])}")
                    # print(f"{nline} {key}:  T:{rowT[keyT]}  {len(rowT[keyT])}")
                    # print()
                    val=row1[key]
                    valT=rowT[keyT]
                    # if len(valT) > 2:
                    #     print(valT)
                    if key not in histBadMap:
                        histBadMap[key]={}
                        
                    if val not in histBadMap[key]:
                        histBadMap[key][val]={}
                        histBadMap[key][val]['count']=0
                    
                    histBadMap[key][val]['count']+=1
                    
                    histBadMap[key][val]['val']=valT
                    if key not in histBad:
                        histBad[key] = {}

                    if val not in histBad[key]:
                        histBad[key][val]=0

                    histBad[key][val]+=1

                    nbad+=1
#                     print("O ",linesOrg[nline+1])
#                     print("N ",linesNew[nline+1])

#                     print("T ",linesTrn[nline+1])
#                     print("---------------")
  #              if nbad > 10: break

# %%
for key,dct in histBad.items():
    tot=0
    nn=0
    for k,cnt in dct.items():
     #   print(k,cnt)
        tot+=cnt
        nn+=1
    print(key,nn,tot)

# %% [markdown]
# Trdnm Dscr 168 170
# Entity Form Date 14704 204290
# Address1 7 10
# Registrant Organization 140 197
# Tradename Form 11 200
# Address2 7 8
# State 4 4
# Country 3 4
# Mailing Country 4 4
# Entity ID 1 4
# Mailing Address 1 3 3
# Mailing Address 2 2 2
# Mailing State 2 2

# %%
for k,dct in histBadMap['Tradename Form'].items():
    print(k,dct['count'],dct['val'])

# %%
for key,dct in histBadMap.items():
    for k,dct2 in dct.items():
        print(key,dct2['count'],k,dct2['val'])

# %%
tot=0
for key,val in histBadMap.items():
    if len(val['val']) > 2:
       tot+=val['count']
       print(f"{val['count']}  {key}  -> {val['val']}")
print("total ",tot)

# %% [markdown]
# Chairitable 1
# CORPORATION 7
# LLC 171
# S-Corp 7
# Trade mark 1
# S Corp 13
# Tradename 2
# Social club. 1
# Trade name 1
# Non Profit 3
# Sole member of the LLC seeking to operate under the trade name Elevaite Consulting"" 1
#
#
# Tradename Form 11 208

# %% [markdown]
# Tradename Form 372 1003
# Trdnm Dscr 172 174
# Entity Form Date 14718 205182
# Address1 7 10
# Registrant Organization 139 196
# Address2 7 8
# State 4 4
# Country 3 4
# Mailing Country 4 4
# Entity ID 1 4
# Mailing Address 1 3 3
# Mailing Address 2 2 2
# Mailing State 2 2

# %%
histBad['Trdnm Dscr']

# %%
header = linesOrg[0]
for line in linesOrg:
    spl = line.split("\t")
    for nn,val in enumerate(spl):
        if val.count('"') != 2 and val.count('"') != 0:
            print(nn,val)

# %%
nbad=0
for nline,row  in enumerate(linesDictOrg):
    nval=0
    for key,val in row.items():
        spl=linesOrg[nline+1].split('\t')
        spl2=linesNew[nline+1].split('\t')
        
        try:
            if val.count('"') != 2 and val.count('"') != 0:
                print(val.count('"'),key,val,spl[nval],spl2[nval])
                nbad+=1
            if nbad > 100:
                break
        except:
            print("BAD ",key,val)
        nval+=1

# %%
df=pd.DataFrame(linesDictTrn)

# %%
df.columns

# %%
len(linesDictTrn)

# %%
nbad=0
histBad={}
histBadTotal={}
histBadMap={}

for nline,row1 in enumerate(linesDictTrn):
    rowT=linesDictTrnB[nline]
    rowN=linesDictNew[nline]
    
    for key in row1:
        if key.lower().count("dtm") == 0 and key.count("Nm") == 0 and key.lower().count("city") == 0 and \
        key.lower().count("zip") == 0 and key.lower().count("suffix") == 0:
 #       if key.lower().count("tradename form")  > 0:
     #   if key != "Registrant Name":
         #   keyT = org2TrnXref[key]
            keyT = key
        
            keyN=key
      #      if row1[key] != rowT[keyT] and len(rowT[keyT]) == 0:
            if row1[key] != rowT[keyT] :
               # if nbad < 100: 
            
                    # print(f"{nline} {key}:  O:{row1[key]}   {len(row1[key])}")
                    # print(f"{nline} {key}:  N:{rowN[keyN]}  {len(rowN[keyN])}")
                    # print(f"{nline} {key}:  T:{rowT[keyT]}  {len(rowT[keyT])}")
                    # print()
                    val=row1[key]
                    valT=rowT[keyT]
                    # if len(valT) > 2:
                    #     print(valT)
                    if key not in histBadMap:
                        histBadMap[key]={}
                        
                    if val not in histBadMap[key]:
                        histBadMap[key][val]={}
                        histBadMap[key][val]['count']=0
                    
                    histBadMap[key][val]['count']+=1
                    
                    histBadMap[key][val]['val']=valT
                    if key not in histBad:
                        histBad[key] = {}

                    if val not in histBad[key]:
                        histBad[key][val]=0

                    histBad[key][val]+=1

                    nbad+=1

# %%
total=0
nrecs=0
for key,dct1 in histBadMap.items():
    for k2,dct2 in dct1.items():
        print(f"{key}  {dct2['count']}  New:{k2}  OLD:{dct2['val']}")
        total+=dct2['count']
        nrecs+=1
        
print(nrecs,total)

# %%
len(linesDictTrn)
