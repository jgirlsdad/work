# %%
import requests

url = "https://api.elections.kalshi.com/trade-api/v2/series/KXHIGHNY"
response = requests.get(url)
series_data = response.json()
print(series_data)
#for series in series_data['series']:
    # if series["title"].find("temp") != -1:
    #    print(f"{series['ticker']}: {series['title']}")
# Out:
# {'series': {'ticker': 'KXHIGHNY', 'frequency': 'daily', 'title': 'Highest temperature in NYC', 'category': 'Climate and Weather', 'tags': ['Daily temperature'], 'settlement_sources': [{'url': 'https://forecast.weather.gov/product.php?site=OKX&product=CLI&issuedby=NYC', 'name': 'NWS Climatological Report'}], 'contract_url': 'https://kalshi-public-docs.s3.us-east-1.amazonaws.com/regulatory/product-certifications/NHIGH.pdf', 'contract_terms_url': 'https://kalshi-public-docs.s3.amazonaws.com/contract_terms/NHIGH.pdf', 'fee_type': 'quadratic', 'fee_multiplier': 1, 'additional_prohibitions': None}}

# %%
ticker = "KXHIGHNY"
url = f"https://api.elections.kalshi.com/trade-api/v2/markets/{ticker}"

response = requests.get(url)
market_data = response.json()

print(f"Title: {market_data['market']['title']}")
print(f"Yes Price: {market_data['market']['yes_price']}¢")
print(f"Volume: {market_data['market']['volume']}")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[5], line 7
#       4 response = requests.get(url)
#       5 market_data = response.json()
# ----> 7 print(f"Title: {market_data['market']['title']}")
#       8 print(f"Yes Price: {market_data['market']['yes_price']}¢")
#       9 print(f"Volume: {market_data['market']['volume']}")
#
# KeyError: 'market'

# %%
market_data
# Out:
# {'error': {'code': 'not_found',
#   'message': 'not found',
#   'service': 'query-exchange'}}

# %%
url = "https://api.elections.kalshi.com/trade-api/v2/markets?status=open"
response = requests.get(url)
markets = response.json()

# Browse available tickers
for market in markets['markets'][:10]:  # First 10
    print(f"{market['ticker']}: {market['title']}")
# Out:
# KXMVENFLSINGLEGAME-S202592F8DB1905B-8D9E4D225FE: yes Cincinnati,yes Jaylen Warren: 40+,no Over 44.5 points scored
# KXMVENFLSINGLEGAME-S2025166B04344F5-AB8704E008B: yes Chase Brown: 10+,yes Jaylen Warren: 10+,yes Kenneth Gainwell: 10+
# KXMVENFLMULTIGAMEEXTENDED-S2025ED3D95FD782-59C8783B70A: yes Cincinnati,yes San Francisco,yes New York J,yes Green Bay,yes Los Angeles C,yes Jacksonville,yes Kansas City,yes Miami,yes Tennessee,yes New Orleans,yes New York G,yes Minnesota,yes Washington,yes Seattle,yes Detroit
# KXMVENFLMULTIGAMEEXTENDED-S20256F39B84FA98-73C3797EFD4: yes Cincinnati,yes San Francisco,yes New York J,yes Green Bay,yes Los Angeles C,yes Jacksonville,yes Kansas City,yes Miami,yes Tennessee,yes New Orleans,yes New York G,yes Minnesota,yes Washington,yes Detroit
# KXMVENFLSINGLEGAME-S202592F8DB1905B-9D49DDD1682: yes Cincinnati,yes Samaje Perine: 10+,no Over 44.5 points scored
# KXMVENFLMULTIGAMEEXTENDED-S2025CEA1B50F43C-27B5B815736: yes Cincinnati,yes San Francisco,yes New York J,yes Green Bay,yes Los Angeles C,yes Jacksonville,yes Kansas City,yes Miami,yes Tennessee,yes New Orleans,yes New York G,yes Minnesota,yes Washington
# KXMVENFLMULTIGAMEEXTENDED-S2025184BBAE6D8D-6F765CDB7E6: yes Aaron Rodgers: 200+,yes Chase Brown: 10+,yes Tee Higgins: 30+,yes Chase Brown: 40+
# KXMVENFLMULTIGAMEEXTENDED-S2025AE199AB8B40-5C6BF451248: yes Cincinnati,yes New York J,yes Green Bay,yes Los Angeles C,yes Jacksonville,yes Kansas City,yes Miami,yes Tennessee,yes New Orleans,yes New York G,yes Minnesota,yes Washington
# KXMVENFLMULTIGAMEEXTENDED-S20251B61130CB29-AF7FD4DF78C: yes Carolina,yes Green Bay,yes Los Angeles C,yes Los Angeles R,yes Kansas City,yes Cleveland,yes Denver,yes Philadelphia,yes Seattle,yes Detroit
# KXMVENFLMULTIGAMEEXTENDED-S202556EED75B68A-F42AB16AA89: yes Cincinnati,yes New York J,yes Green Bay,yes Los Angeles C,yes Jacksonville,yes Kansas City,yes Miami,yes Tennessee,yes New Orleans,yes New York G,yes Minnesota
