# %%
from calendar import monthrange
import sqlite3
import pandas as pd
import datetime
import datetime
from dateutil.relativedelta import relativedelta

# %%
conn = sqlite3.connect('Data/DB/allData.db')

# %%
#df = pd.read_sql("select * from data where shortName='TMAX' and level='2 m above ground'",conn)
df = pd.read_sql("select * from data where shortName='TMP' and level='2 m above ground'",conn)

# %%
df.shape
# Out:
# (45268, 45)

# %%
df["shortName"].value_counts()
# Out:
# shortName
# TMP    45268
# Name: count, dtype: int64

# %%
df["validDate"] = pd.to_datetime(df["validDate"])
df["forecastDate"] = pd.to_datetime(df["forecastDate"])
df["forecastDate"] = df["forecastDate"].dt.date
df["validDate"] = df["validDate"].dt.date

# %%
yrs = df['validDate'].astype(str).str[0:4]

# %%
yrs.value_counts().sort_index
# Out:
# <bound method Series.sort_index of validDate
# 2020    3659
# 2016    3650
# 2017    3650
# 2018    3650
# 2019    3633
# 2022    3587
# 2015    3573
# 2014    3572
# 2021    3548
# 2013    3541
# 2023    3402
# 2012    3230
# 2011    2573
# Name: count, dtype: int64>

# %%
vrs = ["p1","p2","p3","p4","p5","p6","p7","p8","p9","p10","p11","p12","p13","p14","p15","p16","p17","p18","p19","p20","p21","p22","p23","p24","p25","p26","p27","p28","p29","p30","p31","p32"]

nper=5
minDate = df.loc[(df["valueOfForecastTime"] == 0),"validDate"].min()
start = minDate+relativedelta(days=nper)

# %%
hist={}
dfOut = pd.DataFrame(columns=["parameter","level","validDate","forecastDate","forecastPeriod","window","point",
                              "observedValue","forecastValue","difference",
                              "numberOfForecastValues","forecastStdDev"])
tyearS = 2011
tyearE = 2017
for tdate in df.loc[(df["valueOfForecastTime"] == 0) & (df["validDate"] >= start),"validDate"].sort_values():
    year = tdate.year
    month = tdate.month 
    day = tdate.day
    bin = round(day/10,0)
    if year < tyearS:
        continue
    if year > tyearE:
        break
    if bin > 2:
        bin=2
    print(tdate)
    for pt in vrs: 
        
        for nf in range(1,10):
            sdate = tdate - relativedelta(days=nper)
            edate = tdate + relativedelta(days=nper)
            fdate = tdate + relativedelta(months=nf)  #  forecast date
            fsdate = fdate - relativedelta(days=nper)  #  forecast date
            fedate = fdate + relativedelta(days=nper)  #  forecast date
            an = df.loc[(df["valueOfForecastTime"] == 0) & (df["validDate"] == fdate),["shortName","level",pt]]
            if an.shape[0] < 1:
                continue
            par = an["shortName"].values[0]
            level = an["level"].values[0]
            anl = an[pt].values[0]
            fcs = df.loc[(df["valueOfForecastTime"] == nf) & (df["forecastDate"] >= fsdate) & (df["forecastDate"] <= fedate),pt]
            fv = fcs.mean()
            std = fcs.std()
            
            diff = abs(anl- fv)
            tdate,pt,nf,fdate,fsdate,fedate,fv,fcs,diff
            tmp = {
                   "parameter":[par],
                       "level":[level],
                   "validDate":[tdate],
                "forecastDate":[fdate],
              "forecastPeriod":[nf],
                      "window":[nper],
                       "point":[pt],
               "observedValue":[anl],
               "forecastValue":[fv],
                  "difference":[diff],
      "numberOfForecastValues":[fcs.shape[0]],
              "forecastStdDev":[std]}
            tmp = pd.DataFrame(tmp)
            dfOut = pd.concat([dfOut,tmp])
            # if pt not in hist:
            #     hist[pt]={}
            # if month not in hist[pt]:
            #     hist[pt][month]={}
            # if bin not in hist[pt][month]:
            #     hist[pt][month][bin]={}
            #     hist[pt][month][bin]["sum"]=0
            #     hist[pt][month][bin]["count"]=0
                

            # hist[pt][month][bin]["sum"]+=abs(diff)
            # hist[pt][month][bin]["count"]+=abs(diff) 
            
    
 #           print(pt,tdate,sdate,edate,fdate,anl,fv,diff)
# Out:
# 2011-04-06
# /tmp/ipykernel_12792/2160961376.py:53: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   dfOut = pd.concat([dfOut,tmp])
# 2011-04-07
# 2011-04-08
# 2011-04-09
# 2011-04-10
# 2011-04-11
# 2011-04-12
# 2011-04-13
# 2011-04-14
# 2011-04-15
# 2011-04-16
# 2011-04-17
# 2011-04-18
# 2011-04-19
# 2011-04-20
# 2011-04-21
# 2011-04-22
# 2011-04-23
# 2011-04-24
# 2011-05-01
# 2011-05-02
# 2011-05-03
# 2011-05-04
# 2011-05-05
# 2011-05-06
# 2011-05-07
# 2011-05-08
# 2011-05-09
# 2011-05-10
# 2011-05-11
# 2011-05-12
# 2011-05-13
# 2011-05-14
# 2011-05-15
# 2011-05-16
# 2011-05-17
# 2011-05-18
# 2011-05-19
# 2011-05-20
# 2011-05-21
# 2011-05-22
# 2011-05-23
# 2011-05-24
# 2011-06-01
# 2011-06-02
# 2011-06-03
# 2011-06-06
# 2011-06-07
# ...

# %%
connO = sqlite3.connect('Data/DB/analysis.db')

# %%
dfOut.to_sql('qmax', connO,if_exists="append")
# Out:
# 581344

# %%
connI = sqlite3.connect('Data/DB/analysis.db')

# %%
da = pd.read_sql("select * from data",connI)

# %%
yrs = da['validDate'].str[0:4]

# %%
da['valideDate'].min()

# %%
yrs.value_counts().sort_index

# %% [markdown]
# ## Extra

# %%
df.shape
# Out:
# (45268, 45)

# %%
df.head()
# Out:
#    index                                      file     refDate  \
# 0      6  flxf.01.2016080400.201703.avrg.grib.grb2  2016-08-04
# 1      6  flxf.01.2016071800.201703.avrg.grib.grb2  2016-07-18
# 2      6  flxf.01.2016042600.201611.avrg.grib.grb2  2016-04-26
# 3      6  flxf.01.2016121200.201704.avrg.grib.grb2  2016-12-12
# 4      6  flxf.01.2016051600.201702.avrg.grib.grb2  2016-05-16
#
#               typeOfData             fullName shortName  paramNum units  \
# 0  1 - Forecast Products  Maximum Temperature      TMAX         4     K
# 1  1 - Forecast Products  Maximum Temperature      TMAX         4     K
# 2  1 - Forecast Products  Maximum Temperature      TMAX         4     K
# 3  1 - Forecast Products  Maximum Temperature      TMAX         4     K
# 4  1 - Forecast Products  Maximum Temperature      TMAX         4     K
#
#     validDate forecastDate  ...    p23    p24    p25    p26    p27    p28  \
# 0  2016-08-04   2017-03-04  ...  281.5  280.8  280.5  277.0  274.4  275.0
# ...

# %%
df.columns
# Out:
# Index(['index', 'file', 'refDate', 'typeOfData', 'fullName', 'shortName',
#        'paramNum', 'units', 'validDate', 'forecastDate', 'valueOfForecastTime',
#        'unitOfForecastTime', 'level', 'p1', 'p2', 'p3', 'p4', 'p5', 'p6', 'p7',
#        'p8', 'p9', 'p10', 'p11', 'p12', 'p13', 'p14', 'p15', 'p16', 'p17',
#        'p18', 'p19', 'p20', 'p21', 'p22', 'p23', 'p24', 'p25', 'p26', 'p27',
#        'p28', 'p29', 'p30', 'p31', 'p32'],
#       dtype='object')

# %%
df["valueOfForecastTime"].value_counts()
# Out:
# valueOfForecastTime
# 5    4565
# 7    4564
# 8    4564
# 4    4564
# 9    4563
# 1    4562
# 6    4562
# 2    4561
# 3    4560
# 0    4203
# Name: count, dtype: int64

# %%
anls = df.loc[df["valueOfForecastTime"] == 0]

# %%
anls.shape
# Out:
# (4203, 45)

# %%
anls.head()
# Out:
#     index                                      file     refDate  \
# 11      5  flxf.01.2016122100.201612.avrg.grib.grb2  2016-12-21
# 28      5  flxf.01.2016022300.201602.avrg.grib.grb2  2016-02-23
# 38      5  flxf.01.2016020700.201602.avrg.grib.grb2  2016-02-07
# 40      5  flxf.01.2016061100.201606.avrg.grib.grb2  2016-06-11
# 45      5  flxf.01.2016062300.201606.avrg.grib.grb2  2016-06-23
#
#                typeOfData     fullName shortName  paramNum units   validDate  \
# 11  1 - Forecast Products  Temperature       TMP         0     K  2016-12-21
# 28  1 - Forecast Products  Temperature       TMP         0     K  2016-02-23
# 38  1 - Forecast Products  Temperature       TMP         0     K  2016-02-07
# 40  1 - Forecast Products  Temperature       TMP         0     K  2016-06-11
# 45  1 - Forecast Products  Temperature       TMP         0     K  2016-06-23
#
#    forecastDate  ...    p23    p24    p25    p26    p27    p28    p29    p30  \
# ...

# %%
a = anls.loc[(anls["validDate"].astype(str) >=  "2016-06-18") & (anls["validDate"].astype(str) <=  "2016-06-28")]

# %%
b = anls.loc[(anls["validDate"].astype(str) ==  "2016-06-23") ]

# %%
b["p1"].values[0]
# Out:
# 295.5

# %%
def K2F(K):
       return (K - 273.15) * 9/5 + 32
for col in ['p1', 'p2', 'p3', 'p4', 'p5', 'p6', 'p7',
       'p8', 'p9', 'p10', 'p11', 'p12', 'p13', 'p14', 'p15', 'p16', 'p17',
       'p18', 'p19', 'p20', 'p21', 'p22', 'p23', 'p24', 'p25', 'p26', 'p27',
       'p28', 'p29', 'p30', 'p31', 'p32']:
       print(col,K2F(b[col].values[0]),K2F(a[col].min()),K2F(a[col].max()),K2F(a[col].mean()))
# Out:
# p1 72.23000000000005 70.79000000000002 74.93000000000004 72.50818181818171
# p2 65.21000000000008 63.41000000000008 68.99000000000002 65.8318181818182
# p3 58.37000000000006 57.47000000000006 61.43000000000004 59.0736363636365
# p4 61.79000000000002 59.45 63.77000000000006 62.05181818181817
# p5 68.27000000000007 65.03000000000004 70.97000000000006 67.97545454545467
# p6 74.03000000000004 70.43000000000004 77.63000000000004 73.32636363636371
# p7 75.83000000000004 73.13000000000004 81.23000000000005 75.7972727272728
# p8 74.21000000000008 73.31000000000009 81.77000000000007 75.7972727272727
# p9 74.21000000000008 72.41000000000008 76.55 74.25909090909084
# p10 65.57000000000006 63.59000000000002 68.27000000000007 65.96272727272728
# p11 57.83000000000004 56.570000000000064 61.43000000000004 58.74636363636366
# p12 61.070000000000064 59.09000000000002 62.87000000000006 61.13545454545455
# p13 67.19000000000003 64.85 69.53000000000004 66.81363636363642
# ...

# %%
col="p1"
a[col].std()
# Out:
# 0.6668787541429744

# %%
b = a[col].min(),a[col].max(),a[col].mean(),a[col].std()

# %%
b
# Out:
# (299.0, 301.1, 299.75454545454545, 0.6668787541429744)

# %%
for val in b:
    print(val)
# Out:
# 299.0
# 301.1
# 299.75454545454545
# 0.6668787541429744
