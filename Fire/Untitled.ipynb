# %%
import geopandas as gpd

# %%
df = gpd.read_file("610prcp_20240613.shp")

# %%
df.columns
# Out:
# Index(['Fcst_Date', 'Start_Date', 'End_Date', 'Prob', 'Cat', 'InPoly_FID',
#        'SmoPgnFlag', 'geometry'],
#       dtype='object')

# %%
df['geometry']
# Out:
# 0     MULTIPOLYGON (((-122.52575 48.32104, -122.5286...
# 1     MULTIPOLYGON (((-84.33894 29.94714, -84.33983 ...
# 2     POLYGON ((-145.61061 70.06478, -144.97059 69.9...
# 3     MULTIPOLYGON (((-146.09898 60.39222, -146.4094...
# 4     MULTIPOLYGON (((-88.22228 47.20075, -88.41284 ...
# 5     MULTIPOLYGON (((-80.35567 25.15823, -80.58782 ...
# 6     MULTIPOLYGON (((-155.09619 19.87711, -155.0721...
# 7     POLYGON ((-107.34346 35.25796, -107.66170 35.1...
# 8     MULTIPOLYGON (((-97.37880 27.20477, -97.38483 ...
# 9     MULTIPOLYGON (((-97.17205 26.07808, -97.17959 ...
# 10    MULTIPOLYGON (((-76.46890 34.69345, -76.54392 ...
# 11    POLYGON ((-113.38532 40.26819, -113.21111 39.7...
# 12    MULTIPOLYGON (((-75.81115 35.16419, -75.86703 ...
# 13    POLYGON ((-117.07253 37.32973, -117.44334 37.2...
# 14    MULTIPOLYGON (((-80.66662 32.22011, -80.81927 ...
# Name: geometry, dtype: geometry

# %%
df.plot()
# Out:
# <AxesSubplot:>

# %%
df8 = gpd.read_file("814prcp_latest.shp")

# %%
df8.columns
# Out:
# Index(['Fcst_Date', 'Start_Date', 'End_Date', 'Prob', 'Cat', 'InPoly_FID',
#        'SmoPgnFlag', 'geometry'],
#       dtype='object')

# %%
df8['Prob'].value_counts()
# Out:
# 40.0    4
# 33.0    2
# 36.0    1
# 50.0    1
# Name: Prob, dtype: int64

# %%
df8.plot()
# Out:
# <AxesSubplot:>

# %%
df8['Cat'].value_counts()
# Out:
# Above     5
# Below     2
# Normal    1
# Name: Cat, dtype: int64

# %%
# !pip install pynio
# Out:
# ERROR: Could not find a version that satisfies the requirement pynio (from versions: none)
# ERROR: No matching distribution found for pynio
