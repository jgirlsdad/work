# %%
import pygrib
# Out:
# /home/joe/miniconda3/lib/python3.13/site-packages/pyproj/network.py:59: UserWarning: pyproj unable to set PROJ database path.
#   _set_context_ca_bundle_path(ca_bundle_path)

# %%
grbs = pygrib.open(f"Data/5a3ae8db27390c50563d0f512b4c44ad.grib")
    
years={}
months={}
vars={}
#    print(len(grbs))
#    print(grbs[1].numberOfDataPoints)
print(grbs[1].numberOfDataPoints)
# Out:
# 2982

# %%
dir(grbs[1])
# Out:
# ['GRIBEXSection1Problem',
#  'GRIBEditionNumber',
#  'Ni',
#  'Nj',
#  'P1',
#  'P2',
#  'PLPresent',
#  'PVPresent',
#  'WMO',
#  '__class__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__setitem__',
#  '__setstate__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '_all_keys',
#  '_get_key',
#  '_read_only_keys',
#  '_reshape_mask',
#  '_ro_keys',
#  '_set_projparams',
#  '_unshape_mask',
#  'additionalFlagPresent',
#  'alternativeRowScanning',
#  'analDate',
#  'analDate',
#  'angleSubdivisions',
#  'average',
#  'binaryScaleFactor',
#  'bitMapIndicator',
#  'bitmapPresent',
#  'bitsPerValue',
#  'bitsPerValueAndRepack',
# ...

# %%
for data in grbs[1].data():
    print(data[1])
    break
# Out:
# [4.22596929e-06 2.63154504e-06 1.90138815e-06 3.67462633e-06
#  1.18851661e-05 2.08258629e-05 2.99602747e-05 3.61144542e-05
#  3.92138958e-05 4.33564186e-05 4.86165285e-05 4.36842441e-05
#  3.65912914e-05 3.24189663e-05 5.03599643e-05 9.28729772e-05
#  1.39439106e-04 1.90773606e-04 2.60794163e-04 3.34286690e-04
#  4.13203239e-04 4.57757711e-04 4.16868925e-04 3.68574262e-04
#  3.21799517e-04 2.83309817e-04 2.69109011e-04 2.55697966e-04
#  2.36162543e-04 2.10070610e-04 1.79329514e-04 1.49065256e-04
#  1.23897195e-04 1.07774138e-04 9.09954309e-05 7.59303570e-05
#  6.78092241e-05 6.43223524e-05 6.12229109e-05 6.19828701e-05
#  7.08341598e-05 8.17716121e-05 9.10848379e-05 1.01366639e-04
#  1.10098720e-04 1.18845701e-04 1.27428770e-04 1.28576159e-04
#  1.27309561e-04 1.25089288e-04 1.22511387e-04 1.17325783e-04
#  1.12602115e-04 1.09323859e-04 1.08444691e-04 1.11052394e-04
#  1.13004446e-04 1.12661719e-04 1.10009313e-04 1.05598569e-04
# ...

# %%
data.shape
# Out:
# (42, 71)

# %%
a=grbs[1].data()

# %%
len(a)
# Out:
# 3

# %%
a[1]
# Out:
# array([[41.1, 41.1, 41.1, ..., 41.1, 41.1, 41.1],
#        [41. , 41. , 41. , ..., 41. , 41. , 41. ],
#        [40.9, 40.9, 40.9, ..., 40.9, 40.9, 40.9],
#        ...,
#        [37.2, 37.2, 37.2, ..., 37.2, 37.2, 37.2],
#        [37.1, 37.1, 37.1, ..., 37.1, 37.1, 37.1],
#        [37. , 37. , 37. , ..., 37. , 37. , 37. ]], shape=(42, 71))

# %%
len(a[1])
# Out:
# 42

# %%
len(a[2])
# Out:
# 42

# %%
npt=0
fout=open("latlons_42x71.csv","w")
for j in range(len(a[1])):
    print(a[1][j])
    for i in range(len(a[1][j])):
        fout.write(f"{npt},{a[1][j][i]},{a[2][j][i]}\n")
        npt += 1
fout.close()
# Out:
# [41.1 41.1 41.1 41.1 41.1 41.1 41.1 41.1 41.1 41.1 41.1 41.1 41.1 41.1
#  41.1 41.1 41.1 41.1 41.1 41.1 41.1 41.1 41.1 41.1 41.1 41.1 41.1 41.1
#  41.1 41.1 41.1 41.1 41.1 41.1 41.1 41.1 41.1 41.1 41.1 41.1 41.1 41.1
#  41.1 41.1 41.1 41.1 41.1 41.1 41.1 41.1 41.1 41.1 41.1 41.1 41.1 41.1
#  41.1 41.1 41.1 41.1 41.1 41.1 41.1 41.1 41.1 41.1 41.1 41.1 41.1 41.1
#  41.1]
# [41. 41. 41. 41. 41. 41. 41. 41. 41. 41. 41. 41. 41. 41. 41. 41. 41. 41.
#  41. 41. 41. 41. 41. 41. 41. 41. 41. 41. 41. 41. 41. 41. 41. 41. 41. 41.
#  41. 41. 41. 41. 41. 41. 41. 41. 41. 41. 41. 41. 41. 41. 41. 41. 41. 41.
#  41. 41. 41. 41. 41. 41. 41. 41. 41. 41. 41. 41. 41. 41. 41. 41. 41.]
# [40.9 40.9 40.9 40.9 40.9 40.9 40.9 40.9 40.9 40.9 40.9 40.9 40.9 40.9
#  40.9 40.9 40.9 40.9 40.9 40.9 40.9 40.9 40.9 40.9 40.9 40.9 40.9 40.9
#  40.9 40.9 40.9 40.9 40.9 40.9 40.9 40.9 40.9 40.9 40.9 40.9 40.9 40.9
#  40.9 40.9 40.9 40.9 40.9 40.9 40.9 40.9 40.9 40.9 40.9 40.9 40.9 40.9
# ...
