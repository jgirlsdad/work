# %%
import sqlite3
import pandas as pd

# %%
conn = sqlite3.connect('Data/DB/allData.db')

# %%
df = pd.read_sql("select * from data",conn)

# %%
df.head()
# Out:
#    index                                      file     refDate  \
# 0      0  flxf.01.2016080400.201703.avrg.grib.grb2  2016-08-04
# 1      1  flxf.01.2016080400.201703.avrg.grib.grb2  2016-08-04
# 2      2  flxf.01.2016080400.201703.avrg.grib.grb2  2016-08-04
# 3      3  flxf.01.2016080400.201703.avrg.grib.grb2  2016-08-04
# 4      4  flxf.01.2016080400.201703.avrg.grib.grb2  2016-08-04
#
#               typeOfData                          fullName shortName  \
# 0  1 - Forecast Products                          Pressure      PRES
# 1  1 - Forecast Products                       Temperature       TMP
# 2  1 - Forecast Products  Volumetric Soil Moisture Content     SOILW
# 3  1 - Forecast Products  Volumetric Soil Moisture Content     SOILW
# 4  1 - Forecast Products        Potential Evaporation Rate     PEVPR
#
#    paramNum     units   validDate forecastDate  ...           p23  \
# 0         0        Pa  2016-08-04   2017-03-04  ...  86373.000000
# 1         0         K  2016-08-04   2017-03-04  ...    280.000000
# 2       192  Fraction  2016-08-04   2017-03-04  ...      0.250740
# 3       192  Fraction  2016-08-04   2017-03-04  ...      0.253460
# 4       200     W m-2  2016-08-04   2017-03-04  ...    180.300003
#
#             p24           p25          p26           p27           p28  \
# 0  88414.000000  80337.000000  76157.00000  72868.000000  72934.000000
# 1    279.400000    278.800000    275.30000    272.900000    273.700000
# 2      0.265040      0.291320      0.34632      0.418840      0.278380
# 3      0.264460      0.299260      0.34358      0.356240      0.352940
# 4    179.300003    175.199997    170.00000    141.699997    162.800003
#
#             p29           p30           p31          p32
# 0  76549.000000  81609.000000  85644.000000  88332.00000
# 1    276.500000    279.400000    280.300000    280.30000
# 2      0.298760      0.279900      0.253180      0.24334
# 3      0.292900      0.278000      0.256960      0.24236
# 4    194.900009    156.199997    184.300003    200.50000
#
# [5 rows x 45 columns]

# %%
df["level"].value_counts()
# Out:
# level
# 2 m above ground         271608
# surface                  135804
# 0-0.1 m underground       45268
# 0.1-0.4 m underground     45268
# Name: count, dtype: int64

# %%
## Show all tables in the db file
# sql_query = """SELECT name FROM sqlite_master  
#   WHERE type='table';"""
# cursor = conn.cursor()
# cursor.execute(sql_query)
# print(cursor.fetchall())
