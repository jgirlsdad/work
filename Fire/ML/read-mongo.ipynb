# %%
import pymongo,json
import sys
import pandas as pd

# %%
def mongoConnect():    
    try:
      client = pymongo.MongoClient("mongodb+srv://jcomeaux:444Jayla.@cluster0.qjm0b.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0")
      
    # return a friendly error if a URI error is thrown 
    except pymongo.errors.ConfigurationError:
      print("An Invalid URI host error was received. Is your Atlas host name correct in your connection string?")
      sys.exit(1)
        
    return client

client = mongoConnect()
db = client["Fire"]      # replace with your database name
collection = db["VPD"] # replace with your collection name

# Read all records
# records = collection.find()
# for record in records:
#     print(record)
# print("DONE")

recs = list(collection.find())
df = pd.DataFrame(recs)
print(df)
# Out:
#                           _id  statefule  batch_size  forecast_period  \
# 0    67c3ec8f9f8c93b67411ab93      False          48                8
# 1    67c3ec9b9f8c93b67411ab94      False          48                8
# 2    67c3eca89f8c93b67411ab95      False          48                8
# 3    67c3ecb49f8c93b67411ab96      False          48                8
# 4    67c3ecc19f8c93b67411ab97      False          48                8
# ..                        ...        ...         ...              ...
# 255  67d64b3a25f5eb0e62c59b09       True          56                8
# 256  67d64b5b25f5eb0e62c59b0a       True          56                8
# 257  67d64b7c25f5eb0e62c59b0b       True          56                8
# 258  67d64b9f25f5eb0e62c59b0c       True          56                8
# 259  67d64bc025f5eb0e62c59b0d       True          56                8
#
#      features  timesteps  shuffle  TotalLength  learningRate  \
# 0           6         24    False          420         0.002
# ...

# %%
df.shape
# Out:
# (260, 19)

# %%
df.head()
# Out:
#                         _id  statefule  batch_size  forecast_period  features  \
# 0  67c3ec8f9f8c93b67411ab93      False          48                8         6
# 1  67c3ec9b9f8c93b67411ab94      False          48                8         6
# 2  67c3eca89f8c93b67411ab95      False          48                8         6
# 3  67c3ecb49f8c93b67411ab96      False          48                8         6
# 4  67c3ecc19f8c93b67411ab97      False          48                8         6
#
#    timesteps  shuffle  TotalLength  learningRate  \
# 0         24    False          420         0.002
# 1         24    False          420         0.002
# 2         24    False          420         0.002
# 3         24    False          420         0.002
# 4         24    False          420         0.002
#
#                                              history  earlyStoppingLength  \
# 0  {'loss': [0.0891372486948967, 0.07234407961368...                  100
# ...

# %%
df["forecast_period"].value_counts()
# Out:
# forecast_period
# 8    260
# Name: count, dtype: int64

# %%
df["batch_size"].value_counts()
# Out:
# batch_size
# 48    170
# 24     20
# 64     20
# 56     20
# 60     20
# 72     10
# Name: count, dtype: int64

# %%
df["timesteps"].value_counts()
# Out:
# timesteps
# 24    240
# 12     10
# 36     10
# Name: count, dtype: int64

# %%
df.groupby(["batch_size","earlyStoppingLength","neurons"])[["trainError","testError"]].mean()
# Out:
#                                         trainError  testError
# batch_size earlyStoppingLength neurons
# 24         150                 200.0      0.122403   0.524502
# 48         15                  200.0      0.160434   0.425303
#            100                 100.0      0.072244   0.442269
#                                200.0      0.083674   0.403008
#            150                 200.0      0.188465   0.442639
#            200                 200.0      0.053912   0.336473
# 56         15                  200.0      0.178313   0.381306
# 60         15                  200.0      0.164854   0.365837
# 64         15                  200.0      0.156797   0.445933
#            150                 200.0      0.147044   0.528034
# 72         15                  200.0      0.192572   0.452933
