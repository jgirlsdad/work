# %%
import sqlite3,pandas as pd

# %%
def readWxData(db):
    connr = sqlite3.connect(db)
    df=pd.read_sql('select * from MEANS_TTdRHVPD', connr)
    return df


df=readWxData('/home/joe/work/Fire/Data/DB/era5DataMeans.db')

# %%
df.head()
# Out:
#    index  Point    Yrmo  Length         T         Td         RH       VPD
# 0      0      0  199001     248 -8.463992 -12.366048  74.223548  0.092007
# 1      1      0  199002     224 -9.227723 -12.758839  76.263616  0.079737
# 2      2      0  199003     248 -3.466290  -7.204153  76.585927  0.127759
# 3      3      0  199004     240  4.388708  -3.163000  60.712417  0.380563
# 4      4      0  199005     248  7.292621  -4.213629  48.368589  0.628547

# %%
df['Point'].value_counts().sort_index(ascending=True)
# Out:
# Point
# 0       420
# 1       420
# 2       420
# 3       420
# 4       420
#        ...
# 2977    420
# 2978    420
# 2979    420
# 2980    420
# 2981    420
# Name: count, Length: 2982, dtype: int64

# %%
dfz = pd.read_csv('New/Data/latlon_elevation.csv')

# %%
dfz
# Out:
#       latitude  longitude  elevation_m  point
# 0         41.1      251.0  2431.132808      1
# 1         41.1      251.1  2410.339385      2
# 2         41.1      251.2  2285.373990      3
# 3         41.1      251.3  2188.474594      4
# 4         41.1      251.4  2127.528356      5
# ...        ...        ...          ...    ...
# 2977      37.0      257.6  1192.643800   2978
# 2978      37.0      257.7  1165.294816   2979
# 2979      37.0      257.8  1142.657642   2980
# 2980      37.0      257.9  1121.249636   2981
# 2981      37.0      258.0  1105.270454   2982
#
# [2982 rows x 4 columns]

# %%
dfz['longitude'] = (dfz['longitude']-360).round(1)

# %%
dfz.head()
# Out:
#    latitude  longitude  elevation_m  point
# 0      41.1     -109.0  2431.132808      1
# 1      41.1     -108.9  2410.339385      2
# 2      41.1     -108.8  2285.373990      3
# 3      41.1     -108.7  2188.474594      4
# 4      41.1     -108.6  2127.528356      5

# %%
dfz.shape,df.shape
# Out:
# ((2982, 4), (1252440, 8))

# %%
dfll = pd.read_csv('latlons_42x71.csv')

# %%
dfll.shape
# Out:
# (2982, 3)

# %%
cnt=0
for _,row in dfz.iterrows():
    lat=row['latitude']
    lon=row['longitude']
    point=row['point']
    tmp=dfll[(dfll['lat']==lat)]
    
    if tmp.shape[0] == 0:
        print(tmp.shape[0],point,lat,lon)
        cnt+=1
print(cnt)
# Out:
# 0 427.0 40.5 -109.0
# 0 428.0 40.5 -108.9
# 0 429.0 40.5 -108.8
# 0 430.0 40.5 -108.7
# 0 431.0 40.5 -108.6
# 0 432.0 40.5 -108.5
# 0 433.0 40.5 -108.4
# 0 434.0 40.5 -108.3
# 0 435.0 40.5 -108.2
# 0 436.0 40.5 -108.1
# 0 437.0 40.5 -108.0
# 0 438.0 40.5 -107.9
# 0 439.0 40.5 -107.8
# 0 440.0 40.5 -107.7
# 0 441.0 40.5 -107.6
# 0 442.0 40.5 -107.5
# 0 443.0 40.5 -107.4
# 0 444.0 40.5 -107.3
# 0 445.0 40.5 -107.2
# 0 446.0 40.5 -107.1
# 0 447.0 40.5 -107.0
# 0 448.0 40.5 -106.9
# 0 449.0 40.5 -106.8
# 0 450.0 40.5 -106.7
# 0 451.0 40.5 -106.6
# 0 452.0 40.5 -106.5
# 0 453.0 40.5 -106.4
# 0 454.0 40.5 -106.3
# 0 455.0 40.5 -106.2
# 0 456.0 40.5 -106.1
# 0 457.0 40.5 -106.0
# 0 458.0 40.5 -105.9
# 0 459.0 40.5 -105.8
# 0 460.0 40.5 -105.7
# 0 461.0 40.5 -105.6
# 0 462.0 40.5 -105.5
# 0 463.0 40.5 -105.4
# 0 464.0 40.5 -105.3
# 0 465.0 40.5 -105.2
# 0 466.0 40.5 -105.1
# 0 467.0 40.5 -105.0
# 0 468.0 40.5 -104.9
# 0 469.0 40.5 -104.8
# 0 470.0 40.5 -104.7
# 0 471.0 40.5 -104.6
# ...

# %%
dfll.loc[dfll['point']==447]
# Out:
#      point   lat    lon
# 447    447  40.5 -106.9

# %%
dfz["point"].value_counts().sort_index(ascending=True)
# Out:
# point
# 1       1
# 2       1
# 3       1
# 4       1
# 5       1
#        ..
# 2978    1
# 2979    1
# 2980    1
# 2981    1
# 2982    1
# Name: count, Length: 2982, dtype: int64

# %%
print(dfll['lat'].min(),dfll['lat'].max(),dfll['lon'].min(),dfll['lon'].max()   )
print(dfz['latitude'].min(),dfz['latitude'].max(),dfz['longitude'].min(),dfz['longitude'].max()   )
# Out:
# 37.0 41.1 -109.0 -102.0
# 37.0 41.1 -109.0 -102.0

# %%
dfz.dtypes
# Out:
# latitude       float64
# longitude      float64
# elevation_m    float64
# point            int64
# dtype: object

# %%
print(dfz['point'].min(),dfz['point'].max())
print(dfll['point'].min(),dfll['point'].max())
# Out:
# 1 2982
# 0 2981
