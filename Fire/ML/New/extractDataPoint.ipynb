# %%
import pandas as pd
import sqlite3,os

# %%
point=1316

def getClimateIndices(directory):
    temp = []  # temporary list/dict used throught the program 
 #   features = pd.DataFrame()  # this is a Pandas Dataframe that will hold the Climate Indices
    features={}
    #  add year-month pairs to the features dataframe that will match the available data
    with os.scandir(directory) as entries:
        for entry in entries:
            if entry.is_file():
             #   print(entry.name)
    #  the Climate Indices are stored in flat files, so read them all in and store them in features
                file=entry.name
                file = file.rstrip("\n")
                spl = file.split(".")
                name = spl[0]
                temp = []
                tempdf = pd.DataFrame()
                print(file)
                if file.find("Zone.Identifier") == -1:
                    spl=file.split(".")
                    name=".".join(spl[:-1])
                    with open(f"{directory}/{file}","r") as fin:
                        line=fin.readline()
                        spl = line.split()
                        start = int(spl[0])
                        end = int(spl[1])
                        nl=0
                        print(start,end)
                        process=True
                        for nn in range(start,end+1):
                           line = fin.readline()
                           spl = line.split()
                           year = int(spl[0])
                           if year > 1949  and year < 2024:
                               for mon in range(1,13):
                                   val=float(spl[mon])
                                   if val < -30:
                                       process=False
                                       print(file,year,mon,val)
                        fin.close()
                    if process: 
                        with open(f"{directory}/{file}","r") as fin:
                            line=fin.readline()
                            spl = line.split()
                            start = int(spl[0])
                            end = int(spl[1])
                            nl=0
                            print(start,end)
                            process=True
                            for nn in range(start,end+1):
                               line = fin.readline()
                               spl = line.split()
                               year = int(spl[0])
                               if year not in features:
                                   features[year]={}
                                   
                               for mon in range(1,13):
                                   if mon not in features[year]:
                                       features[year][mon]={}
                                   val=float(spl[mon])
                                   features[year][mon][name]=val
                    else:
                        print("SKIPPING ",file)
                            
        return features

def getIndices(climate,start,end,indices=["all"]):
    features=[]
    features4Pbi=[]
    noUse={}
    indicesToUse={}

    frufru=[]
    for year,dct in climate.items():
        if year > 1989 and year < 2025:
            for mo,dct2 in dct.items():
                for ds,val in dct2.items():
                    if val < -30:
                        if ds not in noUse:
                            noUse[ds]=0
                        noUse[ds]+=1

    
    for year in range(start,end+1):
        dct=climate[year]

        for month,dct2 in dct.items():
            tmp=[]
            tmp2=[]
            tmp.append(year)
            tmp.append(month)
            tmp.append(f"{year}{str(month).zfill(2)}")
            for name,val in sorted(dct2.items()):
                if (indices[0]=="all" or name in indices) and name not in noUse:
                  tmp.append(val)
                  tmp2.append(val)
                
                  if name not in indicesToUse:
                      indicesToUse[name]=0
                  indicesToUse[name]+=1
            features4Pbi.append(tmp)
            features.append(tmp2)
    return features,indicesToUse,features4Pbi 



def readWxData(db):
    connr = sqlite3.connect(db)
    df=pd.read_sql('select * from MEANS_TTdRHVPD', connr)
    return df

def selectWxData(df,point,var="T"):    
    data=df.loc[df["Point"] == point]
    yrmos=df.loc[df["Point"] == point,"Yrmo"].astype(int).values
    mos=df.loc[df["Point"] == point,"Yrmo"].str[4:6].astype(int).values
    
    data=data[[var]].values.tolist()
    
    return data,yrmos,mos


climate=getClimateIndices("/home/joe/work/Fire/ML/Data/Climate-Indices")
features,indicesToUse,features4Pbi=getIndices(climate,1990,2024,["all"])

df=readWxData('/home/joe/work/Fire/Data/DB/era5DataMeans.db')
df.drop(columns=['index'], inplace=True)
#wxData,yrmos,mos=selectWxData(df,point,"VPD") 
points = [71, 111, 141, 1491, 1531, 1561,2911, 2951, 2981]


for point in points:
    dfM = df.loc[df["Point"] == point].copy() 
    dfM["CDate"] = [int(dat[2]) for dat in features4Pbi]
    for nn in range(1,7):
        dfM[f"F{nn}"] = [dat[nn+2] for dat in features4Pbi]

    dfM.loc[dfM["Yrmo"].astype(int) != dfM["CDate"].astype(int)]
    dfM.drop(columns=['CDate'], inplace=True)
    outfile=f"full_data_point_{point}.csv"
    dfM.to_csv(outfile, index=False)
    print(f"Wrote {dfM.shape[0]} rows to {outfile}")
# Out:
# ea.data.txt
# 1948 2025
# 1948 2025
# aao.data.txt
# 1979 2024
# 1979 2024
# pna.data.txt
# 1948 2025
# 1948 2025
# nino34.long.anom.data.txt
# 1870 2024
# 1870 2024
# nao.long.data.txt
# 1821 2024
# 1821 2024
# heatcentra.data.txt
# 1979 2025
# 1979 2025
# nino12.long.anom.data.txt
# 1870 2024
# 1870 2024
# Wrote 420 rows to full_data_point_71.csv
# Wrote 420 rows to full_data_point_111.csv
# Wrote 420 rows to full_data_point_141.csv
# Wrote 420 rows to full_data_point_1491.csv
# Wrote 420 rows to full_data_point_1531.csv
# Wrote 420 rows to full_data_point_1561.csv
# Wrote 420 rows to full_data_point_2911.csv
# Wrote 420 rows to full_data_point_2951.csv
# Wrote 420 rows to full_data_point_2981.csv

# %%
dfM
# Out:
#          Point    Yrmo  Length          T         Td         RH       VPD  \
# 63168     1316  199001     248  -8.555847 -14.357056  64.811774  0.142406
# 63169     1316  199002     224  -5.802500 -12.719777  61.420446  0.195453
# 63170     1316  199003     248  -1.405081  -7.191976  68.160968  0.219871
# 63171     1316  199004     240   3.725708  -1.355875  72.685083  0.287634
# 63172     1316  199005     248   7.509395  -0.033548  64.354032  0.514816
# ...        ...     ...     ...        ...        ...        ...       ...
# 1192495   1316  202408     248  18.642137   8.611452  58.577258  1.106841
# 1192496   1316  202409     240  15.558417   3.064125  49.381417  1.097292
# 1192497   1316  202410     248  10.572016  -1.872419  48.948387  0.856775
# 1192498   1316  202411     240  -5.729542 -10.850792  70.058000  0.158985
# 1192499   1316  202412     183  -8.392732 -13.557322  68.458525  0.134312
#
#             F1    F2    F3    F4    F5    F6
# 63168   -0.352  0.18  0.68 -0.33  0.02 -1.09
# 63169    1.151 -0.14  0.98 -0.27  0.36 -2.78
# 63170    0.414 -0.03  0.88 -0.41  0.20  0.04
# 63171   -1.879 -1.11  0.56 -0.33  0.26 -0.62
# 63172   -1.803  2.25  0.05 -0.23  0.32  0.27
# ...        ...   ...   ...   ...   ...   ...
# 1192495 -2.150 -0.25 -0.50 -0.62  0.02 -1.04
# 1192496  0.098 -3.38 -0.59 -0.58 -0.11  1.08
# 1192497 -0.567 -1.35 -0.44 -0.47 -0.24  0.20
# 1192498  1.020  1.10 -0.41 -0.14 -0.05  0.05
# 1192499 -0.826  0.01 -0.92 -0.44 -0.58  1.39
#
# [420 rows x 13 columns]

# %% [markdown]
# ## Lat Lons

# %%
def readWxData(db):
    connr = sqlite3.connect(db)
    df=pd.read_sql('select * from MEANS_TTdRHVPD', connr)
    return df

df=readWxData('/home/joe/work/Fire/Data/DB/era5DataMeans.db')
df.drop(columns=['index'], inplace=True)

# %%
df.head()
# Out:
#    Point    Yrmo  Length         T         Td         RH       VPD
# 0      0  199001     248 -8.463992 -12.366048  74.223548  0.092007
# 1      0  199002     224 -9.227723 -12.758839  76.263616  0.079737
# 2      0  199003     248 -3.466290  -7.204153  76.585927  0.127759
# 3      0  199004     240  4.388708  -3.163000  60.712417  0.380563
# 4      0  199005     248  7.292621  -4.213629  48.368589  0.628547

# %%
latlons = pd.read_csv("latlons_42x71.csv")
latlons.rename(columns={"point":"Point"}, inplace=True)

# %%
latlons
# Out:
#       point   lat    lon
# 0         0  41.1 -109.0
# 1         1  41.1 -108.9
# 2         2  41.1 -108.8
# 3         3  41.1 -108.7
# 4         4  41.1 -108.6
# ...     ...   ...    ...
# 2977   2977  37.0 -102.4
# 2978   2978  37.0 -102.3
# 2979   2979  37.0 -102.2
# 2980   2980  37.0 -102.1
# 2981   2981  37.0 -102.0
#
# [2982 rows x 3 columns]

# %%
pd.merge(df,latlons, on="Point").to_csv("era5_with_latlons.csv", index=False)

# %%
df.head()
# Out:
#    Point    Yrmo  Length         T         Td         RH       VPD
# 0      0  199001     248 -8.463992 -12.366048  74.223548  0.092007
# 1      0  199002     224 -9.227723 -12.758839  76.263616  0.079737
# 2      0  199003     248 -3.466290  -7.204153  76.585927  0.127759
# 3      0  199004     240  4.388708  -3.163000  60.712417  0.380563
# 4      0  199005     248  7.292621  -4.213629  48.368589  0.628547

# %%
latlons.head()
# Out:
#    point   lat    lon
# 0      0  41.1 -109.0
# 1      1  41.1 -108.9
# 2      2  41.1 -108.8
# 3      3  41.1 -108.7
# 4      4  41.1 -108.6

# %%
df.columns
# Out:
# Index(['Point', 'Yrmo', 'Length', 'T', 'Td', 'RH', 'VPD'], dtype='object')

# %%
latlons.columns
# Out:
# Index(['point', 'lat', 'lon'], dtype='object')
