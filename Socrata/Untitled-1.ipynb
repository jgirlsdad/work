# %%
import pandas as pd

# %%
dfo = pd.read_csv("Septic_Systems_in_Boulder_County_Colorado_20260626.csv")
dfn = pd.read_csv("Septic_Systems_in_Boulder_County_Colorado_20260706.csv")

# %%
dfo.shape,dfn.shape
# Out:
# ((31435, 20), (31435, 20))

# %%
df = pd.read_csv("/home/joe/bic_etl/boulder/")

# %%
dfo.columns
# Out:
# Index(['b1AltId', 'b1AppTypeAlias', 'b1ApplStatus', 'typeOfSystem',
#        'dwellingType', 'areaOfLot', 'bedrooms', 'limitingLayer',
#        'treatmentDepth', 'installerName', 'installingFirm', 'engineerName',
#        'engineeringFirm', 'addressNumber', 'streetDirection', 'streetName',
#        'streetSuffix', 'b1UnitStart', 'city', 'zipCode'],
#       dtype='object')

# %%
dfo.isna().sum()
# Out:
# b1AltId                0
# b1AppTypeAlias         0
# b1ApplStatus         106
# typeOfSystem       29665
# dwellingType        3386
# areaOfLot           7091
# bedrooms            7634
# limitingLayer      30972
# treatmentDepth     30523
# installerName      23061
# installingFirm     15865
# engineerName       26555
# engineeringFirm    15865
# addressNumber          0
# streetDirection    27588
# streetName             0
# streetSuffix        1898
# b1UnitStart        31241
# city                   0
# zipCode                5
# dtype: int64

# %%
df1 = pd.read_csv("/home/joe/bic_etl/boulder/data_transformed/septic_export_cleaned.csv",encoding='latin')

# %%
df1.dtypes
# Out:
# b1ApplStatus        object
# b1AppTypeAlias      object
# b1AltId             object
# typeOfSystem        object
# dwellingType        object
# areaOfLot           object
# bedrooms            object
# limitingLayer       object
# treatmentDepth      object
# installerName       object
# installingFirm      object
# engineerName        object
# engineeringFirm     object
# addressNumber        int64
# streetDirection     object
# streetName          object
# streetSuffix        object
# b1UnitStart         object
# city                object
# zipCode            float64
# dtype: object

# %%
df1 = pd.read_csv("/home/joe/bic_etl/boulder/data_transformed/septic_export_cleaned.csv",encoding='latin',dtype_backend="numpy_nullable")

# %%
df1.dtypes
# Out:
# b1ApplStatus       string[python]
# b1AppTypeAlias     string[python]
# b1AltId            string[python]
# typeOfSystem       string[python]
# dwellingType       string[python]
# areaOfLot          string[python]
# bedrooms           string[python]
# limitingLayer      string[python]
# treatmentDepth     string[python]
# installerName      string[python]
# installingFirm     string[python]
# engineerName       string[python]
# engineeringFirm    string[python]
# addressNumber               Int64
# streetDirection    string[python]
# streetName         string[python]
# streetSuffix       string[python]
# b1UnitStart        string[python]
# city               string[python]
# zipCode                     Int64
# dtype: object

# %%
df1['zipCode'].fillna("", inplace=True)
# Out:
# /tmp/ipykernel_295346/3081652943.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df1['zipCode'].fillna("", inplace=True)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~/miniconda3/envs/geo/lib/python3.11/site-packages/pandas/core/internals/blocks.py:2401, in ExtensionBlock.fillna(self, value, limit, inplace, downcast, using_cow, already_warned)
#    2400 try:
# ...
