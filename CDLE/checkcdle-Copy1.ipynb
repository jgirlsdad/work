# %% [markdown]
# # Check Fields for CDLE

# %%
import pandas as pd

pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', None)

# %%
fin = open("list")
files=fin.readlines()
files
# Out:
# ['Ces.csv\n',
#  'Income.csv\n',
#  'Industry.csv\n',
#  'Labforce.csv\n',
#  'OESWage.csv\n',
#  'lngproj.csv\n',
#  'shproj.csv\n']

# %% [markdown]
# ## Current-Employment-Statistics (CES)

# %%
path = "/home/joe/bic_etl/cdle/cdle_LaborAndEmployment/data_transformed/"
file="Ces.csv"
file=file.strip()
ces = pd.read_csv(f"{path}0824/{file}")

# %%
ces.head()
# Out:
#   stateabbrv statename  stfips areatyname  areaname  area  periodyear  \
# 0         CO  Colorado       8      State  Colorado     0        1999
# 1         CO  Colorado       8      State  Colorado     0        1999
# 2         CO  Colorado       8      State  Colorado     0        2024
# 3         CO  Colorado       8      State  Colorado     0        1999
# 4         CO  Colorado       8      State  Colorado     0        1999
#
#    periodtype pertypdesc  period  seriescode  \
# 0           3    Monthly       4    30000000
# 1           3    Monthly       4     8000000
# 2           3    Monthly       6    42445000
# 3           3    Monthly       4           0
# 4           3    Monthly       4    20237000
#
#                                  seriesttls seriesdesc  adjusted  benchmark  \
# 0                             Manufacturing      31-33         0       2023
# 1                 Private Service Providing        NaN         0       2023
# 2               Food and Beverage Retailers         72         0       2023
# 3                             Total Nonfarm        NaN         0       2023
# 4  Heavy and Civil Engineering Construction        237         0       2023
#
#    prelim   empces  empprodwrk  empfemale  hours  earnings  hourearn  \
# 0       0   187300         NaN        NaN    NaN       NaN       NaN
# 1       0  1446000         NaN        NaN    NaN       NaN       NaN
# 2       1    51700         NaN        NaN    NaN       NaN       NaN
# 3       0  2123100         NaN        NaN    NaN       NaN       NaN
# 4       0    19300         NaN        NaN    NaN       NaN       NaN
#
#    supprecord  supphe  supppw  suppfem  hoursallwrkr  earningsallwrkr  \
# 0           0       0       1        1           NaN              NaN
# 1           0       1       1        1           NaN              NaN
# 2           0       1       1        1           NaN              NaN
# 3           0       1       1        1           NaN              NaN
# 4           0       1       1        1           NaN              NaN
#
#    hourearnallwrkr  suppheallwrkr
# 0              NaN              0
# 1              NaN              0
# 2              NaN              1
# 3              NaN              1
# 4              NaN              1

# %%
ces.columns
# Out:
# Index(['stateabbrv', 'statename', 'stfips', 'areatyname', 'areaname', 'area',
#        'periodyear', 'periodtype', 'pertypdesc', 'period', 'seriescode',
#        'seriesttls', 'seriesdesc', 'adjusted', 'benchmark', 'prelim', 'empces',
#        'empprodwrk', 'empfemale', 'hours', 'earnings', 'hourearn',
#        'supprecord', 'supphe', 'supppw', 'suppfem', 'hoursallwrkr',
#        'earningsallwrkr', 'hourearnallwrkr', 'suppheallwrkr'],
#       dtype='object')

# %%
ces.shape
# Out:
# (155582, 30)

# %%
wfile=f"https://data.colorado.gov/resource/pt2g-89wc.csv?$limit=10000000"
cesCIM = pd.read_csv(wfile)

# %%
cesCIM.shape
# Out:
# (154206, 30)

# %%
ces["periodyear"].value_counts().sort_index()
# Out:
# periodyear
# 1990    4431
# 1991    4431
# 1992    4431
# 1993    4431
# 1994    4431
# 1995    4431
# 1996    4431
# 1997    4431
# 1998    4431
# 1999    4431
# 2000    4457
# 2001    4457
# 2002    4470
# 2003    4535
# 2004    4561
# 2005    4561
# 2006    4561
# 2007    4561
# 2008    4561
# 2009    4561
# 2010    4561
# 2011    4561
# 2012    4561
# 2013    4561
# 2014    4561
# 2015    4561
# 2016    4561
# 2017    4561
# 2018    4561
# 2019    4535
# 2020    4535
# 2021    4535
# 2022    4535
# 2023    4431
# 2024    2367
# Name: count, dtype: int64

# %%
cesCIM["periodyear"].value_counts().sort_index()
# Out:
# periodyear
# 1990    4431
# 1991    4431
# 1992    4431
# 1993    4431
# 1994    4431
# 1995    4431
# 1996    4431
# 1997    4431
# 1998    4431
# 1999    4431
# 2000    4457
# 2001    4457
# 2002    4470
# 2003    4535
# 2004    4561
# 2005    4561
# 2006    4561
# 2007    4561
# 2008    4561
# 2009    4561
# 2010    4561
# 2011    4561
# 2012    4561
# 2013    4561
# 2014    4561
# 2015    4561
# 2016    4561
# 2017    4561
# 2018    4561
# 2019    4535
# 2020    4535
# 2021    4535
# 2022    4535
# 2023    4431
# 2024     991
# Name: count, dtype: int64

# %%
ces["period"].value_counts()
# Out:
# period
# 4     12237
# 6     12237
# 5     12237
# 3     12237
# 2     12237
# 1     12237
# 9     11893
# 10    11893
# 7     11893
# 11    11893
# 12    11893
# 8     11893
# 0     10802
# Name: count, dtype: int64

# %%
cesInvt={}
#years = cesCIM["periodyear"].values.tolist()
#mons = cesCIM["period"].values.tolist()

years = ces["periodyear"].values.tolist()
mons = ces["period"].values.tolist()


for nn,year in enumerate(years):
    mon = mons[nn]
    if year not in cesInvt:
        cesInvt[year]={}
    if mon not in cesInvt[year]:
        cesInvt[year][mon]=0
    cesInvt[year][mon]+=1

# %%
cesCIMInvt={}
#years = cesCIM["periodyear"].values.tolist()
#mons = cesCIM["period"].values.tolist()

years = cesCIM["periodyear"].values.tolist()
mons = cesCIM["period"].values.tolist()


for nn,year in enumerate(years):
    mon = mons[nn]
    if year not in cesCIMInvt:
        cesCIMInvt[year]={}
    if mon not in cesCIMInvt[year]:
        cesCIMInvt[year][mon]=0
    cesCIMInvt[year][mon]+=1

# %%
years = list(cesInvt.keys()) + list(cesCIMInvt.keys())
year1 = min(years)
year2 = max(years)
print("YEAR MON  CIM  UPT DIFF")
for year in range(year1,year2+1):
    for mo in range(13):
        if year in cesInvt and mo in cesInvt[year]:
            cnt=cesInvt[year][mo]
        else:
            cnt=0

        if year in cesCIMInvt and mo in cesCIMInvt[year]:
            cntCIM=cesCIMInvt[year][mo]
        else:
            cntCIM=0
        diff = cnt-cntCIM
        print(f"{year:4d}  {mo:2d} {cntCIM:4d} {cnt:4d} {diff:4d}")
# Out:
# YEAR MON  CIM  UPT DIFF
# 1990   0  303  303    0
# 1990   1  344  344    0
# 1990   2  344  344    0
# 1990   3  344  344    0
# 1990   4  344  344    0
# 1990   5  344  344    0
# 1990   6  344  344    0
# 1990   7  344  344    0
# 1990   8  344  344    0
# 1990   9  344  344    0
# 1990  10  344  344    0
# 1990  11  344  344    0
# 1990  12  344  344    0
313  354  354  354  354  354  354  354  354  354  354  354  354
# 2008  313  354  354  354  354  354  354  354  354  354  354  354  354
# 2009  313  354  354  354  354  354  354  354  354  354  354  354  354
# 2010  313  354  354  354  354  354  354  354  354  354  354  354  354
# 2011  313  354  354  354  354  354  354  354  354  354  354  354  354
# 2012  313  354  354  354  354  354  354  354  354  354  354  354  354
# 2013  313  354  354  354  354  354  354  354  354  354  354  354  354
# 2014  313  354  354  354  354  354  354  354  354  354  354  354  354
# 2015  313  354  354  354  354  354  354  354  354  354  354  354  354
# 2016  313  354  354  354  354  354  354  354  354  354  354  354  354
# 2017  313  354  354  354  354  354  354  354  354  354  354  354  354
# 2018  313  354  354  354  354  354  354  354  354  354  354  354  354
# 2019  311  352  352  352  352  352  352  352  352  352  352  352  352
# 2020  311  352  352  352  352  352  352  352  352  352  352  352  352
# 2021  311  352  352  352  352  352  352  352  352  352  352  352  352
# 2022  311  352  352  352  352  352  352  352  352  352  352  352  352
# 2023  303  344  344  344  344  344  344  344  344  344  344  344  344
# 2024  303  344  344  344  344  344  344    0    0    0    0    0    0

# %% [markdown]
# ## Income-Data-for-Colorado-Counties (Income)

# %%
path = "/home/joe/bic_etl/cdle/cdle_LaborAndEmployment/data_transformed/"
file="Income.csv"
file=file.strip()
income = pd.read_csv(f"{path}0824/{file}")

# %%
income.shape
# Out:
# (9022, 19)

# %%
income.head()
# Out:
#   stateabbrv statename  stfips     areatyname       areaname  areatype  area  \
# 0         US    U.S.A.       0  United States  United States         0     0
# 1         US    U.S.A.       0  United States  United States         0     0
# 2         US    U.S.A.       0  United States  United States         0     0
# 3         US    U.S.A.       0  United States  United States         0     0
# 4         US    U.S.A.       0  United States  United States         0     0
#
#    periodyear  periodtype pertypdesc  period  inctype  \
# 0        1929           1     Annual       0        1
# 1        1929           1     Annual       0        2
# 2        1930           1     Annual       0        1
# 3        1930           1     Annual       0        2
# 4        1931           1     Annual       0        1
#
#                                              incdesc  incsource  \
# 0  Total Personal Income - Bureau of Economic Ana...          3
# 1  Per Capita Personal Income - Bureau of Economi...          3
# 2  Total Personal Income - Bureau of Economic Ana...          3
# 3  Per Capita Personal Income - Bureau of Economi...          3
# 4  Total Personal Income - Bureau of Economic Ana...          3
#
#                           incsrcdesc       income  incrank   population  \
# 0  Bureau of Economic Analysis (BEA)  85126000000      0.0  121769000.0
# 1  Bureau of Economic Analysis (BEA)          699      0.0  121769000.0
# 2  Bureau of Economic Analysis (BEA)  76371000000      0.0  123075000.0
# 3  Bureau of Economic Analysis (BEA)          621      0.0  123075000.0
# 4  Bureau of Economic Analysis (BEA)  65507000000      0.0  124038000.0
#
#    releasedate
# 0   20140612.0
# 1   20140612.0
# 2   20140612.0
# 3   20140612.0
# 4   20140612.0

# %%
income["incdesc"].value_counts()
# Out:
# incdesc
# Total Personal Income - Bureau of Economic Analysis                   3636
# Per Capita Personal Income - Bureau of Economic Analysis              3636
# Median Household Income - United States Census                        1718
# Dividends, Interest, and Rent Income - Bureau of Economic Analysis      16
# Transfer Payments - Bureau of Economic Analysis                         16
# Name: count, dtype: int64

# %%
income["pertypdesc"].value_counts()
# Out:
# pertypdesc
# Annual    9022
# Name: count, dtype: int64

# %%
years = income["periodyear"].values.tolist()
incomeInvt = {}
for year in years:
    if year not in incomeInvt:
        incomeInvt[year]=0
    incomeInvt[year]+=1

# %%
year1=min(incomeInvt.keys())
year2=max(incomeInvt.keys())

for year in range(year1,year2+1):
    if year in incomeInvt:
        cnt=incomeInvt[year]
    else:
        cnt=0
    print(f"{year:4d} {cnt:4d}")
# Out:
# 1929    4
# 1930    4
# 1931    4
# 1932    4
# 1933    4
# 1934    4
# 1935    4
# 1936    4
# 1937    4
# 1938    4
year1=min(years)
year2=max(years)
print("YEAR   CIM   UPT  DIFF")
for year in range(year1,year2+1):
    if year in incomeInvt:
        cnt=incomeInvt[year]
    else:
        cnt=0

    if year in incomeCIMInvt:
        cntCIM = incomeCIMInvt[year]
    else:
        cntCIM=0

    diff=cnt-cntCIM
    print(f"{year:4d} {cntCIM:5d} {cnt:5d} {diff:5d}")
# Out:
# YEAR   CIM   UPT  DIFF
# 1929     4     4     0
# 1930     4     4     0
# 1931     4     4     0
# 1932     4     4     0
# 1933     4     4     0
# 1934     4     4     0
# 1935     4     4     0
# 1936     4     4     0
# 1937     4     4     0
# 1938     4     4     0
# 1939     4     4     0
# 1940     4     4     0
# 1941     4     4     0
# 1942     4     4     0
# 1943     4     4     0
# 1944     4     4     0
# 1945     4     4     0
# 1946     4     4     0
# 1947     4     4     0
# 1948     4     4     0
# 1949     4     4     0
# 1950     4     4     0
# 1951     4     4     0
# 1952     4     4     0
# 1953     4     4     0
# 1954     4     4     0
# 1955     4     4     0
# 1956     4     4     0
# 1957     4     4     0
# 1958     4     4     0
# 1959     4     4     0
# 1960     4     4     0
# 1961     4     4     0
# 1962     4     4     0
# 1963     4     4     0
# 1964     4     4     0
# 1965     4     4     0
# 1966     4     4     0
# 1967     4     4     0
# 1968     4     4     0
# 1969   146   146     0
# 1970   146   146     0
# 1971   146   146     0
# 1972   146   146     0
# 1973   146   146     0
# 1974   146   146     0
# 1975   146   146     0
# 1976   146   146     0
# 1977   146   146     0
# 1978   146   146     0
# 1979   146   146     0
# 1980   146   146     0
# 1981   146   146     0
# 1982   146   146     0
# 1983   146   146     0
# 1984   148   148     0
# 1985   148   148     0
# 1986   148   148     0
# 1987   148   148     0
# 1988   148   148     0
# 1989   211   211     0
# 1990   211   211     0
# 1991   148   148     0
# 1992   148   148     0
# 1993   211   211     0
# 1994   148   148     0
# 1995   211   211     0
# 1996   148   148     0
# 1997   211   211     0
# 1998   211   211     0
# 1999   211   211     0
# 2000   211   211     0
# 2001   212   212     0
# 2002   212   212     0
# 2003   212   212     0
# 2004   212   212     0
# 2005   212   212     0
# 2006   212   212     0
# 2007   212   212     0
# 2008   216   216     0
# 2009   216   216     0
# 2010   216   216     0
# 2011   215   215     0
# 2012   215   215     0
# 2013   215   215     0
# 2014   215   215     0
# 2015   201   201     0
# 2016   197   197     0
# 2017   132   132     0
# 2018     0     0     0
# 2019     0     0     0
# 2020    65    65     0
# 2021    65    65     0

# %% [markdown]
# ## Occupational-Employment-Statistics (OESWage)

# %%
path = "/home/joe/bic_etl/cdle/cdle_LaborAndEmployment/data_transformed/"
file="OESWage.csv"
file=file.strip()
oes = pd.read_csv(f"{path}0824/{file}")
# Out:
# /tmp/ipykernel_1256/3720787909.py:4: DtypeWarning: Columns (16) have mixed types. Specify dtype option on import or set low_memory=False.
#   oes = pd.read_csv(f"{path}0824/{file}")

# %%
oes.shape
# Out:
# (329410, 40)

# %%
oes.head()
# Out:
#   stateabbrv statename  stfips                   areaname  areatype  \
# 0         CO  Colorado       8       Colorado Springs MSA        21
# 1         CO  Colorado       8       Colorado Springs MSA        21
# 2         CO  Colorado       8                 Pueblo MSA        21
# 3         CO  Colorado       8  Fort Collins-Loveland MSA        21
# 4         CO  Colorado       8  Fort Collins-Loveland MSA        21
#
#                       areatyname   area  periodyear  periodtype pertypdesc  \
# 0  Metropolitan Statistical Area  17820        2011           1     Annual
# 1  Metropolitan Statistical Area  17820        2011           1     Annual
# 2  Metropolitan Statistical Area  39380        2009           1     Annual
# 3  Metropolitan Statistical Area  22660        2011           1     Annual
# 4  Metropolitan Statistical Area  22660        2011           1     Annual
#
#    period  indcodty  indcode indcodetitle  occodetype occodetydesc occcode  \
# 0       0        10        0    Total All           8     SOC 2000       0
# 1       0        10        0    Total All           8     SOC 2000       0
# 2       0        10        0    Total All           8     SOC 2000       0
# 3       0        10        0    Total All           8     SOC 2000       0
# 4       0        10        0    Total All           8     SOC 2000       0
#
#                codetitle  wagesource  \
# 0  Total All occupations           3
# 1  Total All occupations           3
# 2  Total All occupations           3
# 3  Total All occupations           3
# 4  Total All occupations           3
#
#                                   wagesrdesc  ratetype             ratetydesc  \
# 0  Occupational Employment Statistics Survey         4  Annual wage or salary
# 1  Occupational Employment Statistics Survey         1            Hourly wage
# 2  Occupational Employment Statistics Survey         4  Annual wage or salary
# 3  Occupational Employment Statistics Survey         1            Hourly wage
# 4  Occupational Employment Statistics Survey         4  Annual wage or salary
#
#    empcount  response      mean   entrywg  experience     pct10     pct25  \
# 0  241620.0      77.0  45082.00  20375.00    57435.00  17996.00  22990.00
# 1  241620.0      77.0     21.67      9.80       27.61      8.65     11.05
# 2   56230.0      79.0  36531.00  18354.00    45620.00  16427.00  20052.00
# 3  127420.0      77.0     21.39      9.64       27.27      8.58     10.85
# 4  127420.0      77.0  44499.00  20049.00    56724.00  17844.00  22571.00
#
#      median     pct75     pct90  udpct  udpctwage  udrnglopct  udrnghipct  \
# 0  35100.00  57044.00  86582.00    NaN        NaN         NaN         NaN
# 1     16.88     27.42     41.63    NaN        NaN         NaN         NaN
# 2  30308.00  45354.00  64700.00    0.0        NaN         0.0         0.0
# 3     16.77     26.40     39.76    NaN        NaN         NaN         NaN
# 4  34891.00  54906.00  82692.00    NaN        NaN         NaN         NaN
#
#    udrngmean  wpctrelerr  epctrelerr  panelcode
# 0        NaN        2.03        1.09        NaN
# 1        NaN        2.03        1.09        NaN
# 2        NaN        2.12        1.95   200905.0
# 3        NaN        2.23        1.27        NaN
# 4        NaN        2.23        1.27        NaN

# %%
oes["period"].value_counts()
# Out:
# period
# 0    329410
# Name: count, dtype: int64

# %%
oesInvt=oes["periodyear"].value_counts().sort_index().to_dict()

# %%
oes["areatyname"].value_counts()
# Out:
# areatyname
# County                           104639
# Metropolitan Statistical Area     88591
# Workforce Development Region      80295
# State                             21898
# Balance of State                  18118
# Balance of State (pre-2015)       15869
# Name: count, dtype: int64

# %%
oes.groupby(["periodyear","areatyname"])["period"].count()
# Out:
# periodyear  areatyname
# 2009        Balance of State (pre-2015)       1732
#             Metropolitan Statistical Area     5435
#             State                             1377
# 2010        Balance of State (pre-2015)       2430
#             Metropolitan Statistical Area     5436
#             State                             1418
# 2011        Balance of State (pre-2015)       2225
#             Metropolitan Statistical Area     5308
#             State                             1361
# 2012        Balance of State (pre-2015)       2472
#             Metropolitan Statistical Area     5714
#             State                             1494
# 2013        Balance of State (pre-2015)       2386
#             Metropolitan Statistical Area     5770
#             State                             1490
# 2014        Balance of State (pre-2015)       2476
#             Metropolitan Statistical Area     5756
#             State                             1490
# 2015        Balance of State                  2114
#             Metropolitan Statistical Area     5824
#             State                             1494
# 2016        Balance of State                  2076
#             Metropolitan Statistical Area     5816
#             State                             1466
# 2017        Balance of State                  2060
#             Metropolitan Statistical Area     5836
#             State                             1454
# 2018        Balance of State                  2080
#             County                           15744
#             Metropolitan Statistical Area     5778
#             State                             1430
#             Workforce Development Region     12004
# 2019        Balance of State (pre-2015)       2148
#             County                           15684
#             Metropolitan Statistical Area     5952
#             State                             1440
#             Workforce Development Region     12614
# 2020        Balance of State                  2114
#             County                           12094
#             Metropolitan Statistical Area     5750
#             State                             1432
#             Workforce Development Region      9897
# 2021        Balance of State                  2592
#             County                           20859
#             Metropolitan Statistical Area     6774
#             State                             1532
#             Workforce Development Region     15460
# 2022        Balance of State                  2558
#             County                           21030
#             Metropolitan Statistical Area     6762
#             State                             1526
#             Workforce Development Region     15512
# 2023        Balance of State                  2524
#             County                           19228
#             Metropolitan Statistical Area     6680
#             State                             1494
#             Workforce Development Region     14808
# Name: period, dtype: int64

# %%
wfile=f"https://data.colorado.gov/resource/busm-qa5b.csv?$limit=10000000"
oesCIM = pd.read_csv(wfile)
# Out:
# /tmp/ipykernel_1256/2733437481.py:2: DtypeWarning: Columns (16) have mixed types. Specify dtype option on import or set low_memory=False.
#   oesCIM = pd.read_csv(wfile)

# %%
oesCIMInvt=oesCIM["periodyear"].value_counts().sort_index().to_dict()

# %%
years =  list(oesCIMInvt.keys()) + list(oesInvt.keys())
year1=min(years)
year2=max(years)
print("YEAR  CIM   UPDT   DIFF")
for year in range(year1,year2+1):
    if year in oesCIMInvt:
        cntCIM=oesCIMInvt[year]
    else:
        cntCIM=0
    if year in oesInvt:
        cnt=oesInvt[year]
    else:
        cnt=0
    diff = cnt-cntCIM
    print(f"{year:4d} {cntCIM:5d} {cnt:5d}  {diff:5d}")
# Out:
# YEAR  CIM   UPDT   DIFF
# 2009  8544  8544      0
# 2010  9284  9284      0
# 2011  8894  8894      0
# 2012  9680  9680      0
# 2013  9646  9646      0
# 2014  9722  9722      0
# 2015  9432  9432      0
# 2016  9358  9358      0
# 2017  9350  9350      0
# 2018 36858 37036    178
# 2019 37618 37838    220
# 2020 31070 31287    217
# 2021 47217 47217      0
# 2022 47388 47388      0
# 2023     0 44734  44734

# %% [markdown]
# ## Employment-by-Industry-from-Census-of-Employment (Industry)

# %%
path = "/home/joe/bic_etl/cdle/cdle_LaborAndEmployment/data_transformed/"
file="Industry.csv"
file=file.strip()
industry = pd.read_csv(f"{path}0824/{file}")

# %%
industry.shape
# Out:
# (1394830, 29)

# %%
industry.head()
# Out:
#   stateabbrv statename  stfips  \
# 0         CO  Colorado       8
# 1         CO  Colorado       8
# 2         CO  Colorado       8
# 3         CO  Colorado       8
# 4         CO  Colorado       8
#
#                                             areaname  areatype areatyname  \
# 0  Boulder County                                ...         4     County
# 1  Boulder County                                ...         4     County
# 2  Boulder County                                ...         4     County
# 3  Boulder County                                ...         4     County
# 4  Boulder County                                ...         4     County
#
#    area  periodyear  periodtype  period pertypdesc  indcodty indcode  \
# 0    13        2019           2       3  Quarterly        10  624
# 1    13        2019           2       3  Quarterly        10  624
# 2    13        2019           2       3  Quarterly        10  71
# 3    13        2019           2       3  Quarterly        10  71
# 4    13        2019           2       3  Quarterly        10  71
#
#                                            codetitle ownership  \
# 0  Social Assistance                             ...        00
# 1  Social Assistance                             ...        50
# 2  Arts, Entertainment, and Recreation           ...        00
# 3  Arts, Entertainment, and Recreation           ...        10
# 4  Arts, Entertainment, and Recreation           ...        50
#
#                ownertitle  prelim  firms  estab  avgemp  mnth1emp  mnth2emp  \
# 0  Aggregate of all types       0      0    326  4377.0      4464      4474
# 1                 Private       0      0    326  4377.0      4464      4474
# 2  Aggregate of all types       0      0    340  3424.0      3597      3473
# 3      Federal Government       0      0      1     3.0         3         3
# 4                 Private       0      0    338  3409.0      3584      3458
#
#    mnth3emp  topempav     totwage  avgwkwage  taxwage  contrib  suppress
# 0      4193       0.0  30167004.0      530.0      0.0      0.0         0
# 1      4193       0.0  30167004.0      530.0      0.0      0.0         0
# 2      3201       0.0  25780758.0      579.0      0.0      0.0         0
# 3         3       0.0     91612.0     2349.0      0.0      0.0         0
# 4      3184       0.0  25574113.0      577.0      0.0      0.0         0

# %%
industry["pertypdesc"].value_counts()
# Out:
# pertypdesc
# Quarterly    1125286
# Annual        269544
# Name: count, dtype: int64

# %%
industry["period"].value_counts()
# Out:
# period
# 3    287032
# 2    286842
# 1    283038
# 0    269544
# 4    268374
# Name: count, dtype: int64

# %%
wfile=f"https://data.colorado.gov/resource/cjkq-q9ih.csv?$limit=10000000"
industryCIM = pd.read_csv(wfile)
# Out:
# /tmp/ipykernel_1256/215604729.py:2: DtypeWarning: Columns (12,14) have mixed types. Specify dtype option on import or set low_memory=False.
#   industryCIM = pd.read_csv(wfile)

# %%
a=industry.groupby(["periodyear","period"])["area"].count().to_dict()
industryInvt={}
for key,val in a.items():
    yr=key[0]
    mo=key[1]
    if yr not in industryInvt:
        industryInvt[yr]={}
    industryInvt[yr][mo]=val

# %%
a=industryCIM.groupby(["periodyear","period"])["area"].count().to_dict()
industryCIMInvt={}
for key,val in a.items():
    yr=key[0]
    mo=key[1]
    if yr not in industryCIMInvt:
        industryCIMInvt[yr]={}
    industryCIMInvt[yr][mo]=val

# %%
years = list(industryCIMInvt.keys()) + list(industryInvt.keys())
year1 = min(years)
year2 = max(years)
print("YEAR QTR   CIM  UPDT  DIFF")
for year in range(year1,year2+1):
    for qtr in range(5):
        if year in industryInvt and qtr in industryInvt[year]:
            cnt=industryInvt[year][qtr]
        else:
            cnt=0

        if year in industryCIMInvt and qtr in industryCIMInvt[year]:
            cntCIM=industryCIMInvt[year][qtr]
        else:
            cntCIM=0
        diff = cnt-cntCIM
        print(f"{year:4d}   {qtr:1d} {cntCIM:5d} {cnt:5d} {diff:5d}")
# Out:
# YEAR QTR   CIM  UPDT  DIFF
# 2020   2 10455 10455     0
# 2020   3 10442 10442     0
# 2020   4 10458 10458     0
# 2021   0 10508 10508     0
# 2021   1 10411 10411     0
# 2021   2 10529 10529     0
# 2021   3 10586 10586     0
# 2021   4 10527 10527     0
# 2022   0 10881 10926    45
# 2022   1 11004 12307  1303
# 2022   2 11068 12416  1348
# 2022   3 10983 12383  1400
# 2022   4 10990 11006    16
# 2023   0     0 10981 10981
# 2023   1 10964 10981    17
# 2023   2     0 11127 11127
# 2023   3     0 11116 11116
# 2023   4     0 11129 11129

# %% [markdown]
# ## Employment-and-Unemployment-Estimates (Labforce)

# %%
path = "/home/joe/bic_etl/cdle/cdle_LaborAndEmployment/data_transformed/"
file="Labforce.csv"
file=file.strip()
labf = pd.read_csv(f"{path}0824/{file}")

# %%
labf.shape
# Out:
# (35918, 18)

# %%
labf.head()
# Out:
#   stateabbrv statename  stfips  areaname  areatype areatyname  area  \
# 0         CO  Colorado       8  Colorado         1      State     0
# 1         CO  Colorado       8  Colorado         1      State     0
# 2         CO  Colorado       8  Colorado         1      State     0
# 3         CO  Colorado       8  Colorado         1      State     0
# 4         CO  Colorado       8  Colorado         1      State     0
#
#    periodyear  periodtype pertypdesc  period  adjusted  prelim  benchmark  \
# 0        1976           1     Annual       0         0       0       2023
# 1        1976           3    Monthly       1         0       0       2023
# 2        1976           3    Monthly       1         1       0       2023
# 3        1976           3    Monthly       2         0       0       2023
# 4        1976           3    Monthly       2         1       0       2023
#
#    laborforce   emplab  unemp  unemprate
# 0     1240720  1166629  74091        6.0
# 1     1212048  1126230  85818        7.1
# 2     1230966  1160104  70862        5.8
# 3     1210264  1130641  79623        6.6
# 4     1230680  1160001  70679        5.7

# %%
labf["period"].value_counts()
# Out:
# period
# 1     2828
# 3     2828
# 2     2828
# 4     2828
# 5     2828
# 6     2828
# 9     2748
# 7     2748
# 8     2748
# 11    2748
# 10    2748
# 12    2748
# 0     2462
# Name: count, dtype: int64

# %%
a=labf.groupby(["periodyear","period"])["area"].count().to_dict()
labfInvt={}
for key,val in a.items():
    yr=key[0]
    mo=key[1]
    if yr not in labfInvt:
       labfInvt[yr]={}
    labfInvt[yr][mo]=val

# %%
wfile=f"https://data.colorado.gov/resource/4e3w-qire.csv?$limit=10000000"
labfCIM = pd.read_csv(wfile)

# %%
a=labfCIM.groupby(["periodyear","period"])["area"].count().to_dict()
labfCIMInvt={}
for key,val in a.items():
    yr=key[0]
    mo=key[1]
    if yr not in labfCIMInvt:
       labfCIMInvt[yr]={}
    labfCIMInvt[yr][mo]=val

# %%
years = list(labfCIMInvt.keys()) + list(labfInvt.keys())
year1 = min(years)
year2 = max(years)
print("YEAR MON   CIM  UPDT  DIFF")
for year in range(year1,year2+1):
    for qtr in range(13):
        if year in labfInvt and qtr in labfInvt[year]:
            cnt=labfInvt[year][qtr]
        else:
            cnt=0

        if year in labfCIMInvt and qtr in labfCIMInvt[year]:
            cntCIM=labfCIMInvt[year][qtr]
        else:
            cntCIM=0
        diff = cnt-cntCIM
        print(f"{year:4d}   {qtr:2d} {cntCIM:5d} {cnt:5d} {diff:5d}")
# Out:
# 2021    4    80    80     0
# 2021    5    80    80     0
# 2021    6    80    80     0
# 2021    7    80    80     0
# 2021    8    80    80     0
# 2021    9    80    80     0
# 2021   10    80    80     0
# 2021   11    80    80     0
# 2021   12    80    80     0
# 2022    0    72    72     0
# 2022    1    80    80     0
# 2022    2    80    80     0
# 2022    3    80    80     0
# 2022    4    80    80     0
# 2022    5    80    80     0
# 2022    6    80    80     0
# 2022    7    80    80     0
# 2022    8    80    80     0
# 2022    9    80    80     0
# 2022   10    80    80     0
# 2022   11    80    80     0
# 2022   12    80    80     0
# 2023    0    72    72     0
# 2023    1    80    80     0
# 2023    2    80    80     0
# 2023    3    80    80     0
# 2023    4    80    80     0
# 2023    5    80    80     0
# 2023    6    80    80     0
# 2023    7    80    80     0
# 2023    8    80    80     0
# 2023    9    80    80     0
# 2023   10    80    80     0
# 2023   11    80    80     0
# 2023   12    80    80     0
# 2024    0     0     0     0
# 2024    1    80    80     0
# 2024    2    80    80     0
# 2024    3     0    80    80
# 2024    4     0    80    80
# 2024    5     0    80    80
# 2024    6     0    80    80
# 2024    7     0     0     0
# 2024    8     0     0     0
# 2024    9     0     0     0
# 2024   10     0     0     0
# 2024   11     0     0     0
# 2024   12     0     0     0

# %% [markdown]
# ## Long-Term Employment Projections in Colorado (lngproj)

# %%
path = "/home/joe/bic_etl/cdle/cdle_LaborAndEmployment/data_transformed/"
file="lngproj.csv"
file=file.strip()
long = pd.read_csv(f"{path}0824/{file}")

# %%
long.shape
# Out:
# (96797, 29)

# %%
long.head()
# Out:
#   stateabbrv statename  stfips  areatype                     areatyname  \
# 0         CO  Colorado       8        21  Metropolitan Statistical Area
# 1         CO  Colorado       8        21  Metropolitan Statistical Area
# 2         CO  Colorado       8        21  Metropolitan Statistical Area
# 3         CO  Colorado       8        21  Metropolitan Statistical Area
# 4         CO  Colorado       8        21  Metropolitan Statistical Area
#
#     area              areaname  periodid  \
# 0  17820  Colorado Springs MSA        32
# 1  17820  Colorado Springs MSA        32
# 2  17820  Colorado Springs MSA        32
# 3  17820  Colorado Springs MSA        32
# 4  17820  Colorado Springs MSA        32
#
#                                           perioddesc  periodtype  matincodty  \
# 0  Colorado Long-Term Projections, 2022-2032, Jul...           1           2
# 1  Colorado Long-Term Projections, 2022-2032, Jul...           1           2
# 2  Colorado Long-Term Projections, 2022-2032, Jul...           1           2
# 3  Colorado Long-Term Projections, 2022-2032, Jul...           1           2
# 4  Colorado Long-Term Projections, 2022-2032, Jul...           1           2
#
#    matincode                                         matintitle  matoccodty  \
# 0     900000                                         Government           2
# 1     910000                Total Federal Government Employment           2
# 2     930000  Local Government, Excluding Education and Hosp...           2
# 3     999300  Local Government, Excluding Education and Hosp...           2
# 4     920000  State Government, Excluding Education and Hosp...           2
#
#    matoccode              matocctitl  estemp  projemp  pctestind  pctestocc  \
# 0          0  Total, All Occupations   25229    26695      100.0       7.00
# 1          0  Total, All Occupations   12343    12616      100.0       3.42
# 2          0  Total, All Occupations   10772    11819      100.0       2.99
# 3          0  Total, All Occupations   10772    11819      100.0       2.99
# 4          0  Total, All Occupations    2114     2260      100.0       0.59
#
#    pctprojind  pctprojocc  nchg    pchg  growrate  aopeng  aopenr  aopent  \
# 0       100.0        6.58  1466  5.8108    0.5664     NaN     NaN     NaN
# 1       100.0        3.11   273  2.2118    0.2190     NaN     NaN     NaN
# 2       100.0        2.91  1047  9.7196    0.9319     NaN     NaN     NaN
# 3       100.0        2.91  1047  9.7196    0.9319     NaN     NaN     NaN
# 4       100.0        0.56   146  6.9063    0.6701     NaN     NaN     NaN
#
#    suppress
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0

# %%
long["perioddesc"].value_counts()
# Out:
# perioddesc
# Colorado Long-Term Projections, 2022-2032, July 2023    96797
# Name: count, dtype: int64

# %%
longInvt=long["areaname"].value_counts().to_dict()

# %%
wfile=f"https://data.colorado.gov/resource/gyeb-jc69.csv?$limit=10000000"
longCIM = pd.read_csv(wfile)

# %%
longCIMInvt=longCIM["areaname"].value_counts().to_dict()

# %%
for area,cnt in longInvt.items():
    if area in longCIMInvt:
        cntCIM = longCIMInvt[area]
    else:
        cntCIM=0
    diff=cnt-cntCIM
    print(f"{area:30s} {cntCIM:5d}  {cnt:5d}  {diff:5d}")
# Out:
# Colorado                       20541  20541      0
# Denver - Aurora MSA            16016  16016      0
# Colorado Springs MSA            9278   9278      0
# Boulder-Longmont MSA            8257   8257      0
# Fort Collins-Loveland MSA       7856   7856      0
# Northwest Colorado              6592   6592      0
# Southwest Colorado              6537   6537      0
# Greeley MSA                     6220   6220      0
# Eastern and Southern Colorado   5686   5686      0
# Grand Junction MSA              5282   5282      0
# Pueblo MSA                      4532   4532      0

# %% [markdown]
# ## Short-Term Employment Projections in Colorado (shproj)

# %%
path = "/home/joe/bic_etl/cdle/cdle_LaborAndEmployment/data_transformed/"
file="shproj.csv"
file=file.strip()
short = pd.read_csv(f"{path}0824/{file}")

# %%
short.shape
# Out:
# (91198, 29)

# %%
short.head()
# Out:
#   stateabbrv statename  stfips  areatype                     areatyname  \
# 0         CO  Colorado       8        75               Balance of State
# 1         CO  Colorado       8        21  Metropolitan Statistical Area
# 2         CO  Colorado       8         1                          State
# 3         CO  Colorado       8        75               Balance of State
# 4         CO  Colorado       8        75               Balance of State
#
#     area                       areaname  periodid  \
# 0  80002             Southwest Colorado        82
# 1  19740            Denver - Aurora MSA        82
# 2      0                       Colorado        82
# 3  80001  Eastern and Southern Colorado        82
# 4  80002             Southwest Colorado        82
#
#                                           perioddesc  periodtype  matincodty  \
# 0  Colorado Short-Term Projections, 2023-2025, Ma...           1           2
# 1  Colorado Short-Term Projections, 2023-2025, Ma...           1           2
# 2  Colorado Short-Term Projections, 2023-2025, Ma...           1           2
# 3  Colorado Short-Term Projections, 2023-2025, Ma...           1           2
# 4  Colorado Short-Term Projections, 2023-2025, Ma...           1           2
#
#    matincode                                         matintitle  matoccodty  \
# 0     722000                  Food Services and Drinking Places           2
# 1     713000     Amusement, Gambling, and Recreation Industries           2
# 2     312000         Beverage and Tobacco Product Manufacturing           2
# 3     999100          Federal Government, Excluding Post Office           2
# 4     813000  Religious, Grantmaking, Civic, Professional, a...           2
#
#    matoccode              matocctitl  estemp  projemp  pctestind  pctestocc  \
# 0          0  Total, All Occupations   10465    10767      100.0       9.11
# 1          0  Total, All Occupations   22150    22986      100.0       1.26
# 2          0  Total, All Occupations    9807    10112      100.0       0.31
# 3          0  Total, All Occupations     561      552      100.0       0.71
# 4          0  Total, All Occupations     969     1000      100.0       0.84
#
#    pctprojind  pctprojocc  nchg    pchg  growrate  aopeng  aopenr  aopent  \
# 0       100.0        9.09   302  2.8858    1.4326     NaN     NaN     NaN
# 1       100.0        1.28   836  3.7743    1.8697     NaN     NaN     NaN
# 2       100.0        0.31   305  3.1100    1.5431     NaN     NaN     NaN
# 3       100.0        0.69    -9 -1.6043   -0.8054     NaN     NaN     NaN
# 4       100.0        0.84    31  3.1992    1.5870     NaN     NaN     NaN
#
#    suppress
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0

# %%
short["perioddesc"].value_counts()
# Out:
# perioddesc
# Colorado Short-Term Projections, 2023-2025, March 2024    91198
# Name: count, dtype: int64

# %%
shortInvt = short["areaname"].value_counts().to_dict()

# %%
wfile=f"https://data.colorado.gov/resource/u2t6-bfhr.csv?$limit=10000000"
shortCIM = pd.read_csv(wfile)

# %%
shortCIMInvt = shortCIM["areaname"].value_counts().to_dict()

# %%
for area,cnt in shortInvt.items():
    if area in shortCIMInvt:
        cntCIM = shortCIMInvt[area]
    else:
        cntCIM=0
    diff=cnt-cntCIM
    print(f"{area:30s} {cntCIM:5d}  {cnt:5d}  {diff:5d}")
# Out:
# Colorado                       17617  17617      0
# Pueblo MSA                     15640  15640      0
# Denver - Aurora MSA            13639  13639      0
# Colorado Springs MSA            6848   6848      0
# Boulder-Longmont MSA            5962   5962      0
# Fort Collins-Loveland MSA       5901   5901      0
# Northwest Colorado              5819   5819      0
# Southwest Colorado              5509   5509      0
# Greeley MSA                     5122   5122      0
# Eastern and Southern Colorado   4854   4854      0
# Grand Junction MSA              4287   4287      0

# %% [markdown]
# ## School Programs

# %% [markdown]
# ### Fix School Data

# %%
dfSchoolMan = pd.read_csv("/home/joe/bic_etl/cdle/cdle_education/data_transformed/school_programs.csv")

# %%
dfSchoolMan.shape
# Out:
# (10304, 13)

# %%
dfbad = dfSchoolMan.loc[dfSchoolMan['progdesc'].isna()]
dfgood = dfSchoolMan.loc[~dfSchoolMan['progdesc'].isna()]

# %%
print(dfbad.shape)
print(dfgood.shape)
# Out:
# (5542, 13)
# (4762, 13)

# %%
tot=0
histbad = {}
dftmp = pd.DataFrame(columns=dfgood.columns)
dfdel = pd.DataFrame(columns=dfgood.columns)

for index,row in dfbad.iterrows():
    inst = row['instname1']
    prog = row['progtitle']
    area = row['areaname']
    url = row['url']
    ownd = row['instowndes']
    indes = row['insttydesc']
    if inst not in histbad:
        histbad[inst]={}
        histbad[inst]['count']=0
        histbad[inst]['bad']=0
        
    histbad[inst]['count']+=1
    nn = dfgood.loc[(dfgood['instname1'] == inst) & 
                    (dfgood['progtitle'] == prog) & 
                    (dfgood['areaname']==area) & 
                    (dfgood['url'] == url) & 
                    (dfgood['instowndes'] == ownd) & 
                    (dfgood['insttydesc'] == indes)                   
                   ].shape[0]
    if nn == 0: # There are no other records, so we need to keep this record
        tot+=1
        histbad[inst]['bad']+=1
    #    dftmp = dftmp.append(row)
        dftmp=pd.concat([dftmp,row.to_frame().T])
    elif nn == 1: # There IS another record and the descripiton is NOT missing, so we can delete this record with the missing description
    #    dfdel=dfdel.append(row)
        dfdel=pd.concat([dfdel,row.to_frame().T])
    else:
        print(inst,prog,area)
        
        
print(dfbad.shape[0],tot)
# Out:
# 5542 1873

# %%
print(dftmp.shape)
print(dfdel.shape)
# Out:
# (1873, 13)
# (3669, 13)

# %%
dfdel.shape
# Out:
# (3669, 14)

# %%
for inst,res in histbad.items():
    print(inst,res['count'],res['bad'])
# Out:
# "University of Phoenix-Colorado Campus" 60 60
# "CollegeAmerica-Colorado Springs South" 7 7
# "Remington College-Colorado Springs Campus" 5 5
# "University of Phoenix-Southern Colorado Campus" 13 13
# "Adams State University" 116 0
# "College of International Esthetics Inc" 1 0
# "Empire Beauty School-Arvada" 1 1
# "American Sentinel University" 100 55
# "Anthem College-Denver" 30 30
# "Colorado Technical University-Greenwood Village" 150 150
# "Community College of Aurora" 165 25
# "Concorde Career College-Aurora" 80 35
# "Ecotech Institute" 70 45
# "Empire Beauty School-Aurora" 5 0
# "Everest College-Aurora" 45 45
# "ITT Technical Institute-Aurora" 95 95
# "Pickens Technical College" 160 25
# "Pima Medical Institute-Aurora" 30 5
# "Platt College-Aurora" 15 10
# "Utah College of Massage Therapy-Aurora" 5 0
# "Westwood College-Aurora Campus" 66 66
# "Xenon International Academy-Denver" 15 5
# "Auguste Escoffier School of Culinary Arts-Boulder" 9 3
# "Boulder College of Massage Therapy" 3 3
# "Montessori Education Center of the Rockies" 3 0
# "Naropa University" 54 0
# "Rolf Institute of Structural Integration" 3 0
# "Southwest Acupuncture College-Boulder" 3 0
# "University of Colorado Boulder" 294 21
# "Spartan College of Aeronautics and Technology" 15 6
# "Jones International University" 20 20
# "National American University-Centennial" 115 10
# "CollegeAmerica-Colorado Springs" 7 1
# "Colorado Academy of Veterinary Technology" 1 0
# "Colorado College" 54 6
# "Colorado Technical University-Colorado Springs" 29 13
# "Colorado Technical University-Online" 25 25
# "Everest College-Colorado Springs" 9 0
# "IBMC College" 21 5
# "Intellitec College-Colorado Springs" 9 3
# "International Salon and Spa Academy" 5 1
# "National American University-Colorado Springs South" 23 2
# "National American University-Colorado Springs" 28 4
# "National Personal Training Institute of Colorado" 2 0
# "Nazarene Bible College" 11 2
# "Paul Mitchell the School-Colorado Springs" 2 0
# "Pikes Peak Community College" 49 1
# "Pima Medical Institute-Colorado Springs" 8 1
# "The Salon Professional Academy-Colorado Springs" 3 0
# "Toni & Guy Hairdressing Academy-Colorado Springs" 2 0
# "University of Colorado Colorado Springs" 49 7
# "Delta Montrose Technical College" 13 3
# "Aspen University" 120 120
# "Bel-Rea Institute of Animal Technology" 5 0
# "Taft University System" 40 0
# "National Beauty College" 28 0
# "Pima Medical Institute-Denver" 105 7
# "Westwood College-Denver North" 196 196
# "Argosy University-Denver" 26 9
# "Aveda Institute-Denver" 3 0
# "CollegeAmerica-Denver" 8 2
# "Colorado Heights University" 2 1
# "Colorado School of Traditional Chinese Medicine" 2 0
# "Community College of Denver" 31 4
# "Denver School of Nursing" 1 0
# "Emily Griffith Technical College" 63 24
# "Iliff School of Theology" 3 1
# "Johnson & Wales University-Denver" 23 11
# "Lincoln College of Technology-Denver" 7 1
#
#                                              areadesc  \
# 85  "Alamosa County is one of the 64 counties of t...
# 87  "Alamosa County is one of the 64 counties of t...
# 89  "Alamosa County is one of the 64 counties of t...
# 91  "Alamosa County is one of the 64 counties of t...
# 93  "Alamosa County is one of the 64 counties of t...
#
#                    instname1  \
# 85  "Adams State University"
# 87  "Adams State University"
# 89  "Adams State University"
# 91  "Adams State University"
# 93  "Adams State University"
#
#                                             progtitle progdesc  \
# 85  "American Government and Politics (United Stat...      NaN
# 87            "Biology/Biological Sciences, General."      NaN
# 89  "Business Administration and Management, Gener...      NaN
# 91  "Business Administration, Management and Opera...      NaN
# 93                      "Business/Commerce, General."      NaN
#
#               instowndes                             insttydesc    latitude  \
# 85  "Public Institution"  "Four-year Colleges and Universities"  "0.000000"
# 87  "Public Institution"  "Four-year Colleges and Universities"  "0.000000"
# 89  "Public Institution"  "Four-year Colleges and Universities"  "0.000000"
# 91  "Public Institution"  "Four-year Colleges and Universities"  "0.000000"
# 93  "Public Institution"  "Four-year Colleges and Universities"  "0.000000"
#
#      longitude                     url      zip
# 85  "0.000000"  "http://www.adams.edu"  "81101"
# 87  "0.000000"  "http://www.adams.edu"  "81101"
# 89  "0.000000"  "http://www.adams.edu"  "81101"
# 91  "0.000000"  "http://www.adams.edu"  "81101"
# 93  "0.000000"  "http://www.adams.edu"  "81101"

# %%
4762+1873
# Out:
# 6635

# %%
5542-1873
# Out:
# 3669

# %%
## Add the records with missing descriptions that do not have a corresponding non-missing description record back for output 
dfgood = pd.concat([dfgood,dftmp])

# %%
for index,row in dfdel.iterrows():
    inst = row['instname1']
    prog = row['progtitle']
    area = row['areaname']
    url = row['url']
    ownd = row['instowndes']
    indes = row['insttydesc']
 
    histbad[inst]['count']+=1
    hld= dfgood.loc[(dfgood['instname1'] == inst) & 
                    (dfgood['progtitle'] == prog) & 
                    (dfgood['areaname']==area) & 
                    (dfgood['url'] == url) & 
                    (dfgood['instowndes'] == ownd) & 
                    (dfgood['insttydesc'] == indes)                   
                   ]
    nn=hld.shape[0]
    
    if nn == 1:
        mm = hld['progdesc'].isna().sum()
        if mm != 0:
            print("ROH ROH")
            print(hld.head())
            print("----")
    else:
        print("BAD BAD BAD",nn)
        print(hld.head())
        print("----")

# %%
longs = dfSchool['longitude'].values.tolist()

# %%
display(dfSchool.iloc[85])
# Out:
# statename                                              Colorado
# city                                                    Alamosa
# areaname      Alamosa County                                ...
# areadesc      Alamosa County is one of the 64 counties of th...
# instname1                                Adams State University
# progtitle     American Government and Politics (United States).
# progdesc                                                    NaN
# instowndes                                   Public Institution
# insttydesc                  Four-year Colleges and Universities
# latitude                                                    0.0
# longitude                                              0.000000
# url                                        http://www.adams.edu
# zip                                                     81101.0
# Name: 85, dtype: object

# %%
dfSchool.iloc[86]
# Out:
# statename                                              Colorado
# city                                                    Alamosa
# areaname      Alamosa County                                ...
# areadesc      Alamosa County is one of the 64 counties of th...
# instname1                                Adams State University
# progtitle     American Government and Politics (United States).
# progdesc      A program that focuses on the systematic study...
# instowndes                  Four-year Colleges and Universities
# insttydesc                                             0.000000
# latitude                                                    0.0
# longitude                                  http://www.adams.edu
# url                                                       81101
# zip                                                         NaN
# Name: 86, dtype: object

# %%
dfgood.to_csv("school_programs.csv",index=False)

# %%
schoolNew = pd.read_csv("school_programs.csv")

# %%
schoolNew.loc[schoolNew['instname1'] == "Western State Colorado University"]
dfgood.loc[dfgood['instname1'] == "Western State Colorado University"]
print(dfSchoolMan.loc[dfSchoolMan['instname1'].str.lower() == '"Western State Colorado University"'.lower()])

# %%
dfSchoolMan['instname1'].value_counts().sort_index()
# Out:
# instname1
# "Academy of Natural Therapy Inc"                                        3
# "Adams State University"                                              232
# "Aims Community College"                                              108
# "American Sentinel University"                                        155
# "Anthem College-Denver"                                                30
# "Arapahoe Community College"                                          485
# "Argosy University-Denver"                                             46
# "Aspen University"                                                    141
# "Auguste Escoffier School of Culinary Arts-Boulder"                    15
# "Aveda Institute-Denver"                                                7
# "Bel-Rea Institute of Animal Technology"                               10
# "Boulder College of Massage Therapy"                                    3
# "Cheeks International Academy of Beauty Culture-Fort Collins"           7
# "Cheeks International Academy of Beauty Culture-Greeley"                3
# "College of International Esthetics Inc"                                2
# "CollegeAmerica-Colorado Springs South"                                 7
# "CollegeAmerica-Colorado Springs"                                      14
# "CollegeAmerica-Denver"                                                14
# "CollegeAmerica-Fort Collins"                                          15
# "Colorado Academy of Veterinary Technology"                             2
# "Colorado Christian University"                                        94
# "Colorado College"                                                    104
# "Colorado Heights University"                                           3
# "Colorado Media School"                                                 6
# "Colorado Mesa University"                                            139
# "Colorado Mountain College"                                           168
# "Colorado Northwestern Community College"                              45
# "Colorado School of Healing Arts"                                       2
# "Colorado School of Mines"                                             62
# "Colorado School of Trades"                                             2
# "Colorado School of Traditional Chinese Medicine"                       4
# "Colorado State University-Fort Collins"                              259
# "Colorado State University-Global Campus"                             200
# "Colorado State University-Pueblo"                                     64
# "Colorado Technical University-Colorado Springs"                       51
# "Colorado Technical University-Greenwood Village"                     150
# "Colorado Technical University-Online"                                 25
# "Community College of Aurora"                                         315
# "Community College of Denver"                                          59
# "Concorde Career College-Aurora"                                      130
# "DeVry University's Keller Graduate School of Management-Colorado"     63
# "DeVry University-Colorado"                                           343
# "Delta Montrose Technical College"                                     26
# "Denver School of Nursing"                                              2
# "Denver Seminary"                                                     105
# "Ecotech Institute"                                                    95
# "Emily Griffith Technical College"                                    104
# "Empire Beauty School-Arvada"                                           1
# "Empire Beauty School-Aurora"                                          15
# "Empire Beauty School-Lakewood"                                         1
# "Empire Beauty School-Littleton"                                        2
# "Empire Beauty School-Thornton"                                        14
# "Everest College-Aurora"                                               45
# "Everest College-Colorado Springs"                                     18
# "Everest College-Thornton"                                            126
# "Fort Lewis College"                                                   74
# "Front Range Community College"                                       546
# "Glenwood Beauty Academy"                                              16
# "Hair Dynamics Education Center"                                       10
# "Healing Arts Institute"                                                2
# "Heritage College-Denver"                                              17
# "IBMC College"                                                         39
# "ITT Technical Institute-Aurora"                                       95
# "ITT Technical Institute-Westminster"                                 161
#    "Colorado" NULL NULL.1  \
# 0  "Colorado"  NaN    NaN
# 1  "Colorado"  NaN    NaN
# 2  "Colorado"  NaN    NaN
# 3  "Colorado"  NaN    NaN
# 4  "Colorado"  NaN    NaN
#
#   "Douglas County                                              "  \
# 0  "Douglas County                               ...
# 1  "Douglas County                               ...
# 2  "Douglas County                               ...
# 3  "Douglas County                               ...
# 4  "Douglas County                               ...
#
#   "Douglas County is the eighth most populous of the 64 counties of the state of Colorado, in the United States. The county is located midway between Colorado's two largest cities: Denver and Colorado Springs. The United States Census Bureau that the county population was 285,465 in 2010 census, a 62.4% increase since the 2000 census, making Douglas County one of the fastest growing counties in the United States. Douglas County is part of the Denver-Aurora Metropolitan Statistical Area and the Denver-Aurora-Boulder Combined Statistical Area. The county seat is Castle Rock. Douglas County has the highest median household income of any Colorado county or statistical equivalent. It is ranked eighth nationally in that category, and has the highest of any county or equivalent not in the northeastern US."  \
# 0  "Douglas County is the eighth most populous of...
# 1  "Douglas County is the eighth most populous of...
# 2  "Douglas County is the eighth most populous of...
# 3  "Douglas County is the eighth most populous of...
# 4  "Douglas County is the eighth most populous of...
#
#    "University of Phoenix-Colorado Campus"  \
# 0  "University of Phoenix-Colorado Campus"
# 1  "University of Phoenix-Colorado Campus"
# 2  "University of Phoenix-Colorado Campus"
# 3  "University of Phoenix-Colorado Campus"
# 4  "University of Phoenix-Colorado Campus"
#
#                "Accounting and Business/Management." NULL.2  \
# 0                                      "Accounting."    NaN
# 1                             "Behavioral Sciences."    NaN
# 2  "Business Administration and Management, Gener...    NaN
# 3               "Computer and Information Sciences,"    NaN
# 4  "Computer and Information Systems Security/Inf...    NaN
#
#    "Private for profit institution"  "Four-year Colleges and Universities"  \
# 0  "Private for profit institution"  "Four-year Colleges and Universities"
# 1  "Private for profit institution"  "Four-year Colleges and Universities"
# 2  "Private for profit institution"  "Four-year Colleges and Universities"
# 3  "Private for profit institution"  "Four-year Colleges and Universities"
# 4  "Private for profit institution"  "Four-year Colleges and Universities"
#
#    "39.551643"  "-104.873421"  "http://" NULL.3
# 0  "39.551643"  "-104.873421"  "http://"    NaN
# 1  "39.551643"  "-104.873421"  "http://"    NaN
# 2  "39.551643"  "-104.873421"  "http://"    NaN
# 3  "39.551643"  "-104.873421"  "http://"    NaN
# 4  "39.551643"  "-104.873421"  "http://"    NaN

# %%
df = pd.read_csv("school_programs.csv")

# %%
df.head()
# Out:
#   statename city                                           areaname  \
# 0  Colorado  NaN  Douglas County                                ...
# 1  Colorado  NaN  Douglas County                                ...
# 2  Colorado  NaN  Douglas County                                ...
# 3  Colorado  NaN  Douglas County                                ...
# 4  Colorado  NaN  Douglas County                                ...
#
#                                             areadesc  \
# 0  Douglas County is the eighth most populous of ...
# 1  Douglas County is the eighth most populous of ...
# 2  Douglas County is the eighth most populous of ...
# 3  Douglas County is the eighth most populous of ...
# 4  Douglas County is the eighth most populous of ...
#
#                                instname1  \
# 0  University of Phoenix-Colorado Campus
# 1  University of Phoenix-Colorado Campus
# 2  University of Phoenix-Colorado Campus
# 3  University of Phoenix-Colorado Campus
# 4  University of Phoenix-Colorado Campus
#
#                                           progtitle progdesc  \
# 0               Accounting and Business/Management.      NaN
# 1                                       Accounting.      NaN
# 2                              Behavioral Sciences.      NaN
# 3  Business Administration and Management, General.      NaN
# 4                Computer and Information Sciences,      NaN
#
#                        instowndes                           insttydesc  \
# 0  Private for profit institution  Four-year Colleges and Universities
# 1  Private for profit institution  Four-year Colleges and Universities
# 2  Private for profit institution  Four-year Colleges and Universities
# 3  Private for profit institution  Four-year Colleges and Universities
# 4  Private for profit institution  Four-year Colleges and Universities
#
#     latitude   longitude      url  zip
# 0  39.551643 -104.873421  http://  NaN
# 1  39.551643 -104.873421  http://  NaN
# 2  39.551643 -104.873421  http://  NaN
# 3  39.551643 -104.873421  http://  NaN
# 4  39.551643 -104.873421  http://  NaN

# %%
df['longitude'].value_counts()
# Out:
#  0.000000      9714
# -104.986386     196
# -105.000000     154
# -104.822841      66
# -104.873421      60
# -104.820000      30
# -104.980000      28
# -104.875949      20
# -104.821001      13
# -104.780941       7
# -104.787967       5
# -105.053321       4
# -105.200000       3
# -104.967732       1
# -105.043282       1
# -105.080647       1
# -105.065051       1
# Name: longitude, dtype: int64

# %%
dfSchool = pd.read_csv("/home/joe/bic_etl/cdle/cdle_education/data_transformed/school_programs.csv")

# %%
dfSchool.shape
# Out:
# (10304, 13)

# %%
dfSchool.head()
# Out:
#     statename city                                           areaname  \
# 0  "Colorado"  NaN  "Douglas County                               ...
# 1  "Colorado"  NaN  "Douglas County                               ...
# 2  "Colorado"  NaN  "Douglas County                               ...
# 3  "Colorado"  NaN  "Douglas County                               ...
# 4  "Colorado"  NaN  "Douglas County                               ...
#
#                                             areadesc  \
# 0  "Douglas County is the eighth most populous of...
# 1  "Douglas County is the eighth most populous of...
# 2  "Douglas County is the eighth most populous of...
# 3  "Douglas County is the eighth most populous of...
# 4  "Douglas County is the eighth most populous of...
#
#                                  instname1  \
# 0  "University of Phoenix-Colorado Campus"
# 1  "University of Phoenix-Colorado Campus"
# 2  "University of Phoenix-Colorado Campus"
# 3  "University of Phoenix-Colorado Campus"
# 4  "University of Phoenix-Colorado Campus"
#
#                                            progtitle progdesc  \
# 0              "Accounting and Business/Management."      NaN
# 1                                      "Accounting."      NaN
# 2                             "Behavioral Sciences."      NaN
# 3  "Business Administration and Management, Gener...      NaN
# 4               "Computer and Information Sciences,"      NaN
#
#                          instowndes                             insttydesc  \
# 0  "Private for profit institution"  "Four-year Colleges and Universities"
# 1  "Private for profit institution"  "Four-year Colleges and Universities"
# 2  "Private for profit institution"  "Four-year Colleges and Universities"
# 3  "Private for profit institution"  "Four-year Colleges and Universities"
# 4  "Private for profit institution"  "Four-year Colleges and Universities"
#
#       latitude      longitude        url  zip
# 0  "39.551643"  "-104.873421"  "http://"  NaN
# 1  "39.551643"  "-104.873421"  "http://"  NaN
# 2  "39.551643"  "-104.873421"  "http://"  NaN
# 3  "39.551643"  "-104.873421"  "http://"  NaN
# 4  "39.551643"  "-104.873421"  "http://"  NaN

# %%
dfSchoolC = pd.read_csv("https://data.colorado.gov/resource/jnj7-fw37.csv?$limit=10000000")

# %%
dfSchoolC.shape
# Out:
# (6635, 15)

# %%
dfgood.shape
# Out:
# (6635, 13)

# %%
dfgood.columns
# Out:
# Index(['statename', 'city', 'areaname', 'areadesc', 'instname1', 'progtitle',
#        'progdesc', 'instowndes', 'insttydesc', 'latitude', 'longitude', 'url',
#        'zip'],
#       dtype='object')

# %%
dfSchoolC.columns
# Out:
# Index(['statename', 'city', 'address', 'areaname', 'areadesc', 'instname1',
#        'progtitle', 'progdesc', 'instowndes', 'insttydesc', 'latitude',
#        'longitude', 'url', 'zip', 'georeference'],
#       dtype='object')

# %%
upt = dfgood["instname1"].value_counts().to_dict()
cim = dfSchoolC["instname1"].value_counts().to_dict()

# %%
for ins,cnt in upt.items():
    ins=ins.strip()
    ins=ins.replace('"',"")
 #   print(ins,cnt)
 #   print(len(ins),ins)
    if ins in cim:
       cntCIM=cim[ins]
       diff=cnt-cntCIM
       print(f"{ins:65s}  {cntCIM:3d}  {cnt:3d}  {diff:3d}")
       

'University of Colorado Denver/Anschutz Medical Campus'
'University of Colorado Denver/Anschutz Medical Campus'
# Out:
# University of Colorado Denver/Anschutz Medical Campus              850  850    0
# University of Colorado Boulder                                     342  342    0
# Front Range Community College                                      294  294    0
# Arapahoe Community College                                         255  255    0
# Westwood College-Denver North                                      196  196    0
# DeVry University-Colorado                                          196  196    0
# Community College of Aurora                                        175  175    0
# Pickens Technical College                                          170  170    0
# ITT Technical Institute-Westminster                                161  161    0
# Colorado Technical University-Greenwood Village                    150  150    0
# Colorado State University-Fort Collins                             143  143    0
# Aspen University                                                   141  141    0
# National American University-Centennial                            130  130    0
# University of Denver                                               129  129    0
# Adams State University                                             116  116    0
# Colorado State University-Global Campus                            115  115    0
# Pima Medical Institute-Denver                                      112  112    0
# American Sentinel University                                       110  110    0
# Regis University                                                   101  101    0
# Colorado Mountain College                                          100  100    0
# ITT Technical Institute-Aurora                                      95   95    0
# University of Phoenix-Colorado                                      90   90    0
# Concorde Career College-Aurora                                      85   85    0
# Colorado Mesa University                                            77   77    0
# University of Northern Colorado                                     75   75    0
# Ecotech Institute                                                   70   70    0
# Red Rocks Community College                                         70   70    0
# Everest College-Thornton                                            70   70    0
# Metropolitan State University of Denver                             69   69    0
# Westwood College-Aurora Campus                                      66   66    0
# Emily Griffith Technical College                                    65   65    0
# DeVry University's Keller Graduate School of Management-Colorado    63   63    0
# Pueblo Community College                                            63   63    0
# University of Phoenix-Colorado Campus                               60   60    0
# Colorado College                                                    56   56    0
# Aims Community College                                              56   56    0
# University of Colorado Colorado Springs                             55   55    0
# Denver Seminary                                                     55   55    0
# Naropa University                                                   54   54    0
# Pikes Peak Community College                                        51   51    0
# Colorado Christian University                                       49   49    0
# Everest College-Aurora                                              45   45    0
# United States Air Force Academy                                     43   43    0
# Taft University System                                              40   40    0
# Trinidad State Junior College                                       39   39    0
# Fort Lewis College                                                  38   38    0
# Colorado Technical University-Colorado Springs                      35   35    0
# Colorado State University-Pueblo                                    33   33    0
"cjkq-q9ih ":"Employment-by-Industry-from-Census-of-Employment",
"4e3w-qire":"Employment-and-Unemployment-Estimates",
"pt2g-89wc":"Current-Employment-Statistics",
"gyeb-jc69":"Long-Term Employment Projections in Colorado",
"u2t6-bfhr":"Short-Term Employment Projections in Colorado"}

xrefsFiles = {
"2cpa-vbur":"Income.csv",
"busm-qa5b":"OESWage.csv",
"cjkq-q9ih":"Industry.csv",
"4e3w-qire":"Labforce.csv",
"pt2g-89wc":"Ces.csv",
"gyeb-jc69":"lngproj.csv",
"u2t6-bfhr":"shproj.csv"}

xrefs4x4s = {val:key for key,val in xrefsFiles.items()}

# %% [markdown]
# ## Read CIM Data

# %%
dfs = {}
for file in files:
    file=file.strip()
    w4x4=xrefs4x4s[file]
    wfile=f"https://data.colorado.gov/resource/{w4x4}.csv?$limit=10000000"
    print(file,w4x4,wfile)
    
    df = pd.read_csv(wfile)
    dfs[file]=df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-14e2d8a8de41> in <module>
#       1 dfs = {}
# ----> 2 for file in files:
#       3     file=file.strip()
#       4     w4x4=xrefs4x4s[file]
#       5     wfile=f"https://data.colorado.gov/resource/{w4x4}.csv?$limit=10000000"
#
# NameError: name 'files' is not defined

# %%
for file,df in dfs.items():
    print(file,df.columns)
# Out:
# Ces.csv Index(['stateabbrv', 'statename', 'stfips', 'areatyname', 'areaname', 'area',
#        'periodyear', 'periodtype', 'pertypdesc', 'period', 'seriescode',
#        'seriesttls', 'seriesdesc', 'adjusted', 'benchmark', 'prelim', 'empces',
#        'empprodwrk', 'empfemale', 'hours', 'earnings', 'hourearn',
#        'supprecord', 'supphe', 'supppw', 'suppfem', 'hoursallwrkr',
#        'earningsallwrkr', 'hourearnallwrkr', 'suppheallwrkr'],
#       dtype='object')
# Income.csv Index(['stateabbrv', 'statename', 'stfips', 'areatyname', 'areaname',
#        'areatype', 'area', 'periodyear', 'periodtype', 'pertypdesc', 'period',
#        'inctype', 'incdesc', 'incsource', 'incsrcdesc', 'income', 'incrank',
#        'population', 'releasedate'],
#       dtype='object')
# Industry.csv Index(['stateabbrv', 'statename', 'stfips', 'areaname', 'areatype',
#        'areatyname', 'area', 'periodyear', 'periodtype', 'period',
#        'pertypdesc', 'indcodty', 'indcode', 'codetitle', 'ownership',
#        'ownertitle', 'prelim', 'firms', 'estab', 'avgemp', 'mnth1emp',
#        'mnth2emp', 'mnth3emp', 'topempav', 'totwage', 'avgwkwage', 'taxwage',
#        'contrib', 'suppress'],
#       dtype='object')
# Labforce.csv Index(['stateabbrv', 'statename', 'stfips', 'areaname', 'areatype',
#        'areatyname', 'area', 'periodyear', 'periodtype', 'pertypdesc',
#        'period', 'adjusted', 'prelim', 'benchmark', 'laborforce', 'emplab',
#        'unemp', 'unemprate'],
#       dtype='object')
# OESWage.csv Index(['stateabbrv', 'statename', 'stfips', 'areaname', 'areatype',
#        'areatyname', 'area', 'periodyear', 'periodtype', 'pertypdesc',
#        'period', 'indcodty', 'indcode', 'indcodetitle', 'occodetype',
#        'occodetydesc', 'occcode', 'codetitle', 'wagesource', 'wagesrdesc',
#        'ratetype', 'ratetydesc', 'empcount', 'response', 'mean', 'entrywg',
#        'experience', 'pct10', 'pct25', 'median', 'pct75', 'pct90', 'udpct',
#        'udpctwage', 'udrnglopct', 'udrnghipct', 'udrngmean', 'wpctrelerr',
#        'epctrelerr', 'panelcode'],
#       dtype='object')
# lngproj.csv Index(['stateabbrv', 'statename', 'stfips', 'areatype', 'areatyname', 'area',
#        'areaname', 'periodid', 'perioddesc', 'periodtype', 'matincodty',
#        'matincode', 'matintitle', 'matoccodty', 'matoccode', 'matocctitl',
#        'estemp', 'projemp', 'pctestind', 'pctprojind', 'nchg', 'aopeng',
#        'aopenr', 'aopent', 'suppress', 'pctprojocc', 'pctestocc', 'growrate',
#        'pchg'],
#       dtype='object')
# shproj.csv Index(['stateabbrv', 'statename', 'stfips', 'areatype', 'areatyname',
#        'areaname', 'periodid', 'perioddesc', 'periodtype', 'matincodty',
#        'matintitle', 'matoccodty', 'matocctitl', 'estemp', 'projemp', 'nchg',
#        'aopeng', 'aopenr', 'aopent', 'suppress', 'area', 'matincode',
#        'matoccode', 'pctestind', 'pctprojind', 'pchg', 'growrate',
#        'pctprojocc', 'pctestocc'],
#       dtype='object')

# %%
print(dfs['shproj.csv']['perioddesc'].value_counts())
print(dfs3['shproj.csv']['perioddesc'].value_counts())
print(dfs4['shproj.csv']['perioddesc'].value_counts())
# Out:
# Colorado Short-Term Projections, 2016-2018, June 2016        372870
# Colorado Short-Term Projections, 2020-2022, December 2019     86350
# Name: perioddesc, dtype: int64
# Colorado Short-Term Projections, 2016-2018, June 2016    74574
# Name: perioddesc, dtype: int64
# Colorado Short-Term Projections, 2016-2018, June 2016    74574
# Name: perioddesc, dtype: int64

# %% [markdown]
#     CIM
#     Colorado Short-Term Projections, 2016-2018, June 2016        372870
#     Colorado Short-Term Projections, 2020-2022, December 2019     86350
#
#     0324 We Pulled
#     Colorado Short-Term Projections, 2016-2018, June 2016    74574
#
#     0424 We Pulled
#     Colorado Short-Term Projections, 2016-2018, June 2016    74574
#
#     0324 Actual
#     69	Colorado Short-Term Projections, 2016-2018, June 2016
#     81	Colorado Short-Term Projections, 2022-2024, July 2023
#     82	Colorado Short-Term Projections, 2023-2025, March 2024
#
#     0424 Actual
#     69	Colorado Short-Term Projections, 2016-2018, June 2016
#     82	Colorado Short-Term Projections, 2023-2025, March 2024

# %%
dfs['lngproj.csv']['perioddesc'].value_counts()
# Out:
# Colorado Long-Term Projections, 2022-2032, July 2023    193594
# Colorado Long-Term Projections, 2019-2029, June 2020    170496
# Colorado Long-Term Projections, 2020-2030, July 2021     90055
# Name: perioddesc, dtype: int64

# %%
print(dfs4['shproj.csv']['periodid'].value_counts())
print(dfs3['shproj.csv']['periodid'].value_counts())
# Out:
# 69    74574
# Name: periodid, dtype: int64
# 69    74574
# Name: periodid, dtype: int64

# %%
ffs = ["Ces.csv","Income.csv","Industry.csv","Labforce.csv","OESWage.csv"]
for file in ffs:
    print(file)
    print(dfs[file]["periodyear"].value_counts().sort_index())
# 0  Colorado Long-Term Projections, 2019-2029, Jun...           1           2
# 1  Colorado Long-Term Projections, 2019-2029, Jun...           1           2
# 2  Colorado Long-Term Projections, 2019-2029, Jun...           1           2
# 3  Colorado Long-Term Projections, 2019-2029, Jun...           1           2
# 4  Colorado Long-Term Projections, 2019-2029, Jun...           1           2
#
#    matincode                                         matintitle  matoccodty  \
# 0     541000   Professional, Scientific, and Technical Services           2
# 1          0                               Total All Industries           2
# 2     620000                  Health Care and Social Assistance           2
# 3     560000  Administrative and Support and Waste Managemen...           2
# 4     102000                                 Services Providing           2
#
#    matoccode                             matocctitl  estemp  projemp  \
# 0     292000   Health Technologists and Technicians      76       86
# 1     191029       Biological Scientists, All Other     213      265
# 2     110000                 Management Occupations     368      422
# 3     119000           Other Management Occupations     617      717
# 4     193000  Social Scientists and Related Workers    2913     3395
#
#    pctestind  pctprojind  nchg  aopeng  aopenr  aopent  suppress  pctprojocc  \
# 0       6.95        7.60    10     NaN     NaN     NaN         0        4.32
# 1       0.10        0.12    52     NaN     NaN     NaN         0      100.00
# 2       2.70        2.74    54     NaN     NaN     NaN         0       14.62
# 3       0.38        0.40   100     NaN     NaN     NaN         0        0.82
# 4       0.21        0.23   482     NaN     NaN     NaN         0       79.81
#
#    pctestocc  growrate     pchg
# 0       4.01    1.2438  13.1579
# 1     100.00    2.2084  24.4131
# 2      13.77    1.3786  14.6739
# 3       0.79    1.5134  16.2075
# 4      79.85    1.5430  16.5465

# %%
display(dfs["lngproj.csv"]["perioddesc"].value_counts())
# Out:
# Colorado Long-Term Projections, 2022-2032, July 2023    193594
# Colorado Long-Term Projections, 2019-2029, June 2020    170496
# Colorado Long-Term Projections, 2020-2030, July 2021     90055
# Name: perioddesc, dtype: int64

# %%
dfs["shproj.csv"].head()
# Out:
#   stateabbrv statename  stfips  areatype                     areatyname  \
# 0         CO  Colorado       8        21  Metropolitan Statistical Area
# 1         CO  Colorado       8        21  Metropolitan Statistical Area
# 2         CO  Colorado       8         1                          State
# 3         CO  Colorado       8        21  Metropolitan Statistical Area
# 4         CO  Colorado       8        75               Balance of State
#
#                         areaname  periodid  \
# 0           Colorado Springs MSA        76
# 1            Denver - Aurora MSA        76
# 2                       Colorado        76
# 3      Fort Collins-Loveland MSA        76
# 4  Eastern and Southern Colorado        76
#
#                                           perioddesc  periodtype  matincodty  \
# 0  Colorado Short-Term Projections, 2020-2022, De...           1           2
# 1  Colorado Short-Term Projections, 2020-2022, De...           1           2
# 2  Colorado Short-Term Projections, 2020-2022, De...           1           2
# 3  Colorado Short-Term Projections, 2020-2022, De...           1           2
# 4  Colorado Short-Term Projections, 2020-2022, De...           1           2
#
#                                           matintitle  matoccodty  \
# 0                                 Services Providing           2
# 1  Self Employed and Unpaid Family Workers, All Jobs           2
# 2            Printing and Related Support Activities           2
# 3                              Finance and Insurance           2
# 4                                         Government           2
#
#                                           matocctitl  estemp  projemp  nchg  \
# 0                                       Optometrists      98       99     1
# 1            Shipping, Receiving, and Traffic Clerks       7        7     0
# 2  Installation, Maintenance, and Repair Occupations      43       40    -3
# 3      Office and Administrative Support Occupations    1382     1381    -1
# 4                              Financial Specialists     194      197     3
#
#    aopeng  aopenr  aopent  suppress   area  matincode  matoccode  pctestind  \
# 0     NaN     NaN     NaN         0  17820     102000     291041       0.04
# 1     NaN     NaN     NaN         0  19740         67     435071       0.01
# 2     NaN     NaN     NaN         0      0     323000     490000       0.88
# 3     NaN     NaN     NaN         0  22660     520000     430000      37.73
# 4     NaN     NaN     NaN         0  80001     900000     132000       1.85
#
#    pctprojind    pchg  growrate  pctprojocc  pctestocc
# 0        0.04  1.0204    0.5089       89.19      89.09
# 1        0.01  0.0000    0.0000        0.13       0.13
# 2        0.87 -6.9767   -3.5514        0.04       0.04
# 3       37.28 -0.0724   -0.0362        6.09       6.06
# 4        1.87  1.5464    0.7702       19.54      19.44

# %%
display(dfs["shproj.csv"]["perioddesc"].value_counts())
display(dfs["lngproj.csv"]["perioddesc"].value_counts())
# Out:
# Colorado Short-Term Projections, 2016-2018, June 2016        372870
# Colorado Short-Term Projections, 2020-2022, December 2019     86350
# Name: perioddesc, dtype: int64
# Colorado Long-Term Projections, 2022-2032, July 2023    193594
# Colorado Long-Term Projections, 2019-2029, June 2020    170496
# Colorado Long-Term Projections, 2020-2030, July 2021     90055
# Name: perioddesc, dtype: int64

# %%
for file,df in dfs.items():
    print(file,df.shape,dfs4[file].shape,dfs4[file].shape[0]-df.shape[0])
    # print(df.columns)
    # print(dfs4[file].columns)
# Out:
# Ces.csv (151495, 30) (154206, 30) 2711
# Income.csv (8892, 19) (9022, 19) 130
# Industry.csv (1346348, 29) (1372736, 29) 26388
# Labforce.csv (34959, 18) (35598, 18) 639
# OESWage.csv (284061, 40) (284676, 40) 615
# lngproj.csv (260551, 29) (96797, 29) -163754
# shproj.csv (310072, 29) (74574, 29) -235498

# %% [markdown]
# Ces.csv (151495, 30) (154206, 30) 2711   Replace
# Income.csv (8892, 19) (9022, 19) 130     Replace
# Industry.csv (1346348, 29) (1372736, 29) 26388  Replace
# Labforce.csv (34959, 18) (35598, 18) 639  Replace
# OESWage.csv (284061, 40) (284676, 40) 615 Replace
# lngproj.csv (260551, 29) (96797, 29) -163754  Upsert
# shproj.csv (310072, 29) (74574, 29) -235498  Upsert

# %%
dfs4.keys()
# Out:
# dict_keys(['Ces.csv', 'Income.csv', 'Industry.csv', 'Labforce.csv', 'OESWage.csv', 'lngproj.csv', 'shproj.csv'])

# %% [markdown]
# ## Check Period of Record

# %%
dfs['Ces.csv'].columns
# Out:
# Index(['stateabbrv', 'statename', 'stfips', 'areatyname', 'areaname', 'area',
#        'periodyear', 'periodtype', 'pertypdesc', 'period', 'seriescode',
#        'seriesttls', 'seriesdesc', 'adjusted', 'benchmark', 'prelim', 'empces',
#        'empprodwrk', 'empfemale', 'hours', 'earnings', 'hourearn',
#        'supprecord', 'supphe', 'supppw', 'suppfem', 'hoursallwrkr',
#        'earningsallwrkr', 'hourearnallwrkr', 'suppheallwrkr'],
#       dtype='object')

# %%
print(dfs['Ces.csv']['pertypdesc'].value_counts())
print(dfs['Ces.csv']['periodtype'].value_counts())
# Out:
# Monthly    143404
# Annual      10802
# Name: pertypdesc, dtype: int64
# 3    143404
# 1     10802
# Name: periodtype, dtype: int64

# %%
dfs['Ces.csv']['period'].value_counts()
# Out:
# 2     12237
# 1     12237
# 12    11893
# 11    11893
# 10    11893
# 9     11893
# 8     11893
# 7     11893
# 6     11893
# 5     11893
# 4     11893
# 3     11893
# 0     10802
# Name: period, dtype: int64

# %%
ffs = ["Ces.csv","Income.csv","Industry.csv","Labforce.csv","OESWage.csv"]
for file in ffs:
    print(file)
    print(dfs[file]['periodtype'].value_counts())
    print(dfs[file]['pertypdesc'].value_counts())
# Out:
# Ces.csv
# 3    143404
# 1     10802
# Name: periodtype, dtype: int64
# Monthly    143404
# Annual      10802
# Name: pertypdesc, dtype: int64
# Income.csv
# 1    9022
# Name: periodtype, dtype: int64
# Annual    9022
# Name: pertypdesc, dtype: int64
# Industry.csv
# 2    1087830
# 1     258518
# Name: periodtype, dtype: int64
# Quarterly    1087830
# Annual        258518
# Name: pertypdesc, dtype: int64
# Labforce.csv
# 3    33136
# 1     2462
# Name: periodtype, dtype: int64
# Monthly    33136
# Annual      2462
# Name: pertypdesc, dtype: int64
# OESWage.csv
# 1    284061
# Name: periodtype, dtype: int64
# Annual    284061
# Name: pertypdesc, dtype: int64

# %%
### Labforce.csv -   [Unemployment Estimates in Colorado](https://data.colorado.gov/a/b/4e3w-qire) - "labforce"
### Industry.csv -   [Employee Counts by Industry in Colorado](https://data.colorado.gov/a/b/cjkq-q9ih) - "industry"
### Ces.csv -     [Hours Worked by Employees in Colorado](https://data.colorado.gov/a/b/pt2g-89wc) - "ces"
### Income.csv -  [Personal Income in Colorado](https://data.colorado.gov/a/b/2cpa-vbur) - "income"
### OESWage.csv - [Employment Wages in Colorado](https://data.colorado.gov/a/b/busm-qa5b) - "oes"

### lngproj.csv - [Long-Term Employment Projections in Colorado](https://data.colorado.gov/a/b/gyeb-jc69) - "lng proj, lmi"
### shproj.csv -  [Short-Term Employment Projections in Colorado](https://data.colorado.gov/a/b/u2t6-bfhr) - "shrt proj, lmi"

# %%
ffs = ["Ces.csv","Income.csv","Industry.csv","Labforce.csv","OESWage.csv"]
for file in ffs:
    invtYrMo={}
    print(file)
    print("Year  Jan  Feb  Mar  Apr  May  Jun  Jul  Aug  Sep  Oct  Nov  Dec")
    for index,row in dfs[file].loc[dfs[file]['periodtype']==3].iterrows():
        year=row['periodyear']
        month=row['period']

        if year not in invtYrMo:
            invtYrMo[year]={}
        if month not in invtYrMo[year]:
            invtYrMo[year][month]=0
        invtYrMo[year][month]+=1
        
    for year,invt in sorted(invtYrMo.items()):
        print(f"{year:4d}",end="")
        for mo in range(1,13):
            if mo in invt:
               cnt=invt[mo]
            else:
               cnt=0
            print(f"{cnt:5d}",end="")
        print()
    print()
    print()
# Out:
# Ces.csv
# Year  Jan  Feb  Mar  Apr  May  Jun  Jul  Aug  Sep  Oct  Nov  Dec
#
# 82	Colorado Short-Term Projections, 2023-2025, March 2024
#
# Labels
# Colorado Short-Term Projections, 2016-2018, June 2016
# Colorado Short-Term Projections, 2017-2019, Dec, 2016
# Colorado Short-Term Projections, 2017-2019, August 2017
# Colorado Short-Term Projections, 2019-2021, December 2018
# Colorado Short-Term Projections, 2020-2022, December 2019
# Colorado Short-Term Projections, 2022-2024, February 2023
# Colorado Short-Term Projections, 2022-2024, July 2023
# Colorado Short-Term Projections, 2023-2025, March 2024

# %%
dfs4['shproj.csv'].columns
# Out:
# Index(['Changed database context to 'GoCode_0424'.'], dtype='object')

# %%
print(dfs4['shproj.csv']['perioddesc'].value_counts())
print(dfs3['shproj.csv']['perioddesc'].value_counts())
print(dfs['shproj.csv']['perioddesc'].value_counts())
# Out:
# Colorado Short-Term Projections, 2023-2025, March 2024    91198
# Colorado Short-Term Projections, 2016-2018, June 2016     74574
# Name: perioddesc, dtype: int64
# Colorado Short-Term Projections, 2022-2024, July 2023     96584
# Colorado Short-Term Projections, 2023-2025, March 2024    91198
# Colorado Short-Term Projections, 2016-2018, June 2016     74574
# Name: perioddesc, dtype: int64
# Colorado Short-Term Projections, 2016-2018, June 2016        372870
# Colorado Short-Term Projections, 2020-2022, December 2019     86350
# Name: perioddesc, dtype: int64

# %%
print(dfs4['shproj.csv']['periodid'].value_counts())
print(dfs3['shproj.csv']['periodid'].value_counts())
print(dfs['shproj.csv']['periodid'].value_counts())
# Out:
# 69    74574
# Name: periodid, dtype: int64
# 69    74574
# Name: periodid, dtype: int64
# 69    372870
# 76     86350
# Name: periodid, dtype: int64

# %%
dfs4['lngproj.csv'].compare(dfs3['lngproj.csv'])
# Out:
#       areatype       areatyname           area                      areaname  \
#           self other       self other     self    other                 self
# 0          NaN   NaN        NaN   NaN  19740.0  17820.0  Denver - Aurora MSA
# 1          NaN   NaN        NaN   NaN  19740.0  17820.0  Denver - Aurora MSA
# 2          NaN   NaN        NaN   NaN  19740.0  17820.0  Denver - Aurora MSA
# 3          NaN   NaN        NaN   NaN  19740.0  17820.0  Denver - Aurora MSA
# 4          NaN   NaN        NaN   NaN  19740.0  17820.0  Denver - Aurora MSA
# ...        ...   ...        ...   ...      ...      ...                  ...
# 96792      NaN   NaN        NaN   NaN  80002.0  80003.0   Southwest Colorado
# 96793      NaN   NaN        NaN   NaN  80002.0  80003.0   Southwest Colorado
# 96794      NaN   NaN        NaN   NaN  80002.0  80003.0   Southwest Colorado
# 96795      NaN   NaN        NaN   NaN  80002.0  80003.0   Southwest Colorado
# 96796      NaN   NaN        NaN   NaN  80002.0  80003.0   Southwest Colorado
#
#                             matincode        ... pctprojind       pctprojocc  \
#                       other      self other  ...       self other       self
# 0      Colorado Springs MSA     670.0  67.0  ...       1.05  0.09       2.91
# 1      Colorado Springs MSA     670.0  67.0  ...       1.76  0.02       4.42
# 2      Colorado Springs MSA     670.0  67.0  ...       0.01  0.00       2.59
# 3      Colorado Springs MSA     670.0  67.0  ...       0.97  0.00      12.91
# 4      Colorado Springs MSA     670.0  67.0  ...       0.41  0.01       5.93
# ...                     ...       ...   ...  ...        ...   ...        ...
# 96792    Northwest Colorado       NaN   NaN  ...       1.35  3.43      79.67
# 96793    Northwest Colorado       NaN   NaN  ...       0.82  0.66       2.51
# 96794    Northwest Colorado       NaN   NaN  ...       0.20  2.41       2.14
# 96795    Northwest Colorado       NaN   NaN  ...       0.39  0.46      18.34
# 96796    Northwest Colorado       NaN   NaN  ...       0.18  0.37      76.00
#
#                nchg           pchg           growrate
#        other   self other     self     other     self   other
# 0       1.25 -154.0   4.0 -10.4265   22.2222  -1.0951  2.0270
# 1       1.68   70.0   0.0   3.2543    0.0000   0.3208  0.0000
# 2       2.70    NaN   NaN      NaN       NaN      NaN     NaN
# 3       0.49   -7.0   0.0  -0.5705    0.0000  -0.0572  0.0000
# 4       0.98   35.0   1.0   7.2464  100.0000   0.7020  7.1773
# ...      ...    ...   ...      ...       ...      ...     ...
# 96792   7.64   22.0  63.0  17.8862   20.7237   1.6591  1.9012
# 96793   4.71    NaN   NaN  15.7895   20.3390   1.4768  1.8687
# 96794  86.87    3.0  44.0  16.6667   20.5607   1.5534  1.8874
# 96795   1.45    6.0   9.0  16.6667   22.5000   1.5534  2.0501
# 96796  58.82    3.0   7.0  18.7500   21.2121   1.7334  1.9423
#
# [96797 rows x 34 columns]

# %%
dfs4["Income.csv"].loc[(dfs4["Income.csv"]['periodyear'] == 2024) & (dfs4["Income.csv"]['periodtype'] != 0),'periodtype'].value_counts()
# Out:
# Series([], Name: periodtype, dtype: int64)

# %%
dfs4["Ces.csv"].columns
# Out:
# Index(['stateabbrv', 'statename', 'stfips', 'areatyname', 'areaname', 'area',
#        'periodyear', 'periodtype', 'pertypdesc', 'period', 'seriescode',
#        'seriesttls', 'seriesdesc', 'adjusted', 'benchmark', 'prelim', 'empces',
#        'empprodwrk', 'empfemale', 'hours', 'earnings', 'hourearn',
#        'supprecord', 'supphe', 'supppw', 'suppfem', 'hoursallwrkr',
#        'earningsallwrkr', 'hourearnallwrkr', 'suppheallwrkr'],
#       dtype='object')

# %%
dfs4["Ces.csv"].loc[(dfs4["Ces.csv"]['periodyear'] == 2024),'period'].value_counts()
# Out:
# 2    344
# 1    344
# 0    303
# Name: period, dtype: int64

# %%
dfs3["Ces.csv"].loc[(dfs3["Ces.csv"]['periodyear'] == 2023),'period'].value_counts()
# Out:
# 11    344
# 7     344
# 3     344
# 10    344
# 6     344
# 2     344
# 9     344
# 5     344
# 1     344
# 12    344
# 8     344
# 4     344
# 0     303
# Name: period, dtype: int64

# %%
dfs3["Income.csv"]['periodyear'].value_counts().sort_index()
# Out:
# 1929      4
# 1930      4
# 1931      4
# 1932      4
# 1933      4
#        ...
# 2015    201
# 2016    197
# 2017    132
# 2020     65
# 2021     65
# Name: periodyear, Length: 91, dtype: int64

# %%
dfs["Ces.csv"].loc[(dfs["Ces.csv"]['periodyear'] == 2023),'period'].value_counts()
# Out:
# 7    344
# 5    344
# 3    344
# 1    344
# 6    344
# 4    344
# 2    344
# 0    303
# Name: period, dtype: int64

# %%
dfLng = pd.read_csv("/home/joe/bic_etl/cdle/cdle_LaborAndEmployment/data_transformed/lngproj.csv")
dfSh = pd.read_csv("/home/joe/bic_etl/cdle/cdle_LaborAndEmployment/data_transformed/shproj.csv")

# %%
dfLng.head()
# Out:
#   stateabbrv statename  stfips  areatype                     areatyname  \
# 0         CO  Colorado       8        21  Metropolitan Statistical Area
# 1         CO  Colorado       8        21  Metropolitan Statistical Area
# 2         CO  Colorado       8        21  Metropolitan Statistical Area
# 3         CO  Colorado       8        21  Metropolitan Statistical Area
# 4         CO  Colorado       8        21  Metropolitan Statistical Area
#
#     area             areaname  periodid  \
# 0  19740  Denver - Aurora MSA        32
# 1  19740  Denver - Aurora MSA        32
# 2  19740  Denver - Aurora MSA        32
# 3  19740  Denver - Aurora MSA        32
# 4  19740  Denver - Aurora MSA        32
#
#                                           perioddesc  periodtype  matincodty  \
# 0  Colorado Long-Term Projections, 2022-2032, Jul...           1           2
# 1  Colorado Long-Term Projections, 2022-2032, Jul...           1           2
# 2  Colorado Long-Term Projections, 2022-2032, Jul...           1           2
# 3  Colorado Long-Term Projections, 2022-2032, Jul...           1           2
# 4  Colorado Long-Term Projections, 2022-2032, Jul...           1           2
#
#    matincode                                         matintitle  matoccodty  \
# 0          0                               Total All Industries           2
# 1         67  Self Employed and Unpaid Family Workers, All Jobs           2
# 2        670  Self Employed and Unpaid Family Workers, All Jobs           2
# 3        671  Total Self Employed and Unpaid Family Workers,...           2
# 4       6010                    Self Employed Workers, All Jobs           2
#
#    matoccode              matocctitl   estemp  projemp  pctestind  pctestocc  \
# 0          0  Total, All Occupations  1716301  1967762      100.0     100.00
# 1          0  Total, All Occupations   116133   125966      100.0       6.77
# 2          0  Total, All Occupations   116133   125966      100.0       6.77
# 3          0  Total, All Occupations   116133   125966      100.0       6.77
# 4          0  Total, All Occupations   116133   125966      100.0       6.77
#
#    pctprojind  pctprojocc    nchg     pchg  growrate  aopeng  aopenr  aopent  \
# 0       100.0       100.0  251461  14.6513    1.3766     NaN     NaN     NaN
# 1       100.0         6.4    9833   8.4670    0.8161     NaN     NaN     NaN
# 2       100.0         6.4    9833   8.4670    0.8161     NaN     NaN     NaN
# 3       100.0         6.4    9833   8.4670    0.8161     NaN     NaN     NaN
# 4       100.0         6.4    9833   8.4670    0.8161     NaN     NaN     NaN
#
#    suppress
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0

# %%
dfLng.shape
# Out:
# (96797, 29)

# %%
dfLng['perioddesc'].value_counts()
# Out:
# Colorado Long-Term Projections, 2022-2032, July 2023    96797
# Name: perioddesc, dtype: int64

# %%
dfSh['perioddesc'].value_counts()
# Out:
# Colorado Short-Term Projections, 2023-2025, March 2024    91198
# Name: perioddesc, dtype: int64

# %%
dfLngC = pd.read_csv("https://data.colorado.gov/resource/gyeb-jc69.csv?$limit=10000000")
dfShC = pd.read_csv("https://data.colorado.gov/resource/u2t6-bfhr.csv?$limit=10000000")

# %%
dfShC['perioddesc'].value_counts()
# Out:
# Colorado Short-Term Projections, 2023-2025, March 2024    91198
# Name: perioddesc, dtype: int64

# %%
dfLngC['perioddesc'].value_counts()
# Out:
# Colorado Long-Term Projections, 2022-2032, July 2023    96797
# Name: perioddesc, dtype: int64

# %%
print(dfLngC.shape)
print(dfShC.shape)
# Out:
# (96797, 29)
# (91198, 29)

# %% [markdown]
# ## School Programs

# %%
dfSchoolC = pd.read_csv("https://data.colorado.gov/resource/jnj7-fw37.csv?$limit=10000000")

# %%
dfSchoolC.shape
# Out:
# (10304, 13)

# %%
dfSchoolC.head()
# Out:
#   statename city        areaname  \
# 0  Colorado  NaN  Douglas County
# 1  Colorado  NaN  Douglas County
# 2  Colorado  NaN  Douglas County
# 3  Colorado  NaN  Douglas County
# 4  Colorado  NaN  Douglas County
#
#                                             areadesc  \
# 0  Douglas County is the eighth most populous of ...
# 1  Douglas County is the eighth most populous of ...
# 2  Douglas County is the eighth most populous of ...
# 3  Douglas County is the eighth most populous of ...
# 4  Douglas County is the eighth most populous of ...
#
#                                instname1  \
# 0  University of Phoenix-Colorado Campus
# 1  University of Phoenix-Colorado Campus
# 2  University of Phoenix-Colorado Campus
# 3  University of Phoenix-Colorado Campus
# 4  University of Phoenix-Colorado Campus
#
#                                           progtitle progdesc  \
# 0               Accounting and Business/Management.      NaN
# 1                                       Accounting.      NaN
# 2                              Behavioral Sciences.      NaN
# 3  Business Administration and Management, General.      NaN
# 4                Computer and Information Sciences,      NaN
#
#                        instowndes                           insttydesc  \
# 0  Private for profit institution  Four-year Colleges and Universities
# 1  Private for profit institution  Four-year Colleges and Universities
# 2  Private for profit institution  Four-year Colleges and Universities
# 3  Private for profit institution  Four-year Colleges and Universities
# 4  Private for profit institution  Four-year Colleges and Universities
#
#     latitude   longitude      url  zip
# 0  39.551643 -104.873421  http://  NaN
# 1  39.551643 -104.873421  http://  NaN
# 2  39.551643 -104.873421  http://  NaN
# 3  39.551643 -104.873421  http://  NaN
# 4  39.551643 -104.873421  http://  NaN

# %%
dfSchool = pd.read_csv("/home/joe/bic_etl/cdle/cdle_education/data_transformed/school_programs.csv")

# %%
dfSchool.shape
# Out:
# (10304, 13)

# %%
dfSchool.columns
# Out:
# Index(['statename', 'city', 'areaname', 'areadesc', 'instname1', 'progtitle',
#        'progdesc', 'instowndes', 'insttydesc', 'latitude', 'longitude', 'url',
#        'zip'],
#       dtype='object')

# %%
dfSchool['longitude'].nunique()
# Out:
# 120

# %%
dfSchool['instname1'].nunique()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 dfSchoolC['instname1'].nunique()
#
# NameError: name 'dfSchoolC' is not defined

# %%
dct = dict(zip(dfSchool["instname1"],dfSchool["progtitle"]))
dctC = dict(zip(dfSchoolC["instname1"],dfSchoolC["progtitle"]))

# %%
for inst,prg in dct.items():
    prgC = dctC[inst]
    if prg != prgC:
        print(inst,prg,prgC)
# Out:
# Intellitec College-Colorado Springs Physical Fitness Technician. Physical Fitness Technician. (NEW)
# Pikes Peak Community College Wildland/Forest Firefighting and Investigation. Wildland/Forest Firefighting and Investigation. (NEW)
# Heritage College-Denver Physical Fitness Technician. Physical Fitness Technician. (NEW)
# Intellitec College-Grand Junction Physical Fitness Technician. Physical Fitness Technician. (NEW)
# Aims Community College Wildland/Forest Firefighting and Investigation. Wildland/Forest Firefighting and Investigation. (NEW)

# %%
for instC,prgC in dctC.items():
    prg = dct[instC]
    if prg != prgC:
        print(instC)
        print(prg)        
        print(prgC)   
        print("---------")
# Out:
# Intellitec College-Colorado Springs
# Physical Fitness Technician.
# Physical Fitness Technician. (NEW)
# ---------
# Pikes Peak Community College
# Wildland/Forest Firefighting and Investigation.
# Wildland/Forest Firefighting and Investigation. (NEW)
# ---------
# Heritage College-Denver
# Physical Fitness Technician.
# Physical Fitness Technician. (NEW)
# ---------
# Intellitec College-Grand Junction
# Physical Fitness Technician.
# Physical Fitness Technician. (NEW)
# ---------
# Aims Community College
# Wildland/Forest Firefighting and Investigation.
# Wildland/Forest Firefighting and Investigation. (NEW)
# ---------

# %%
fin = open("/home/joe/bic_etl/cdle/cdle_education/data_transformed/school_programs.csv")
hist={}
for line in fin:
    spl = line.split(",")
    nn=len(spl)
    if nn in hist:
        hist[nn]+=1
    else:
        hist[nn]=1
        
    if nn != 13:
        print(nn)
        print(line)
        print("--------")

# %%
hist
# Out:
# {13: 1153,
#  18: 597,
#  19: 813,
#  22: 416,
#  23: 372,
#  14: 1689,
#  15: 814,
#  16: 786,
#  20: 613,
#  17: 635,
#  25: 152,
#  24: 193,
#  26: 239,
#  31: 88,
#  28: 363,
#  21: 327,
#  27: 550,
#  29: 148,
#  30: 142,
#  32: 89,
#  33: 74,
#  37: 8,
#  34: 22,
#  35: 13,
#  36: 4,
#  38: 5}

# %%
dfSchool.shape
# Out:
# (10304, 13)

# %%
dfSchool.to_csv("school.csv",index=False)

# %%
dfSchoolNew = pd.read_csv("school.csv")

# %%
dfSchoolNew.shape
# Out:
# (10304, 13)

# %%
dfSchoolC['areadesc'].values
# Out:
# array(["Douglas County is the eighth most populous of the 64 counties of the state of Colorado, in the United States. The county is located midway between Colorado's two largest cities: Denver and Colorado Springs. The United States Census Bureau that the county population was 285,465 in 2010 census, a 62.4% increase since the 2000 census, making Douglas County one of the fastest growing counties in the United States. Douglas County is part of the Denver-Aurora Metropolitan Statistical Area and the Denver-Aurora-Boulder Combined Statistical Area. The county seat is Castle Rock. Douglas County has the highest median household income of any Colorado county or statistical equivalent. It is ranked eighth nationally in that category, and has the highest of any county or equivalent not in the northeastern US.",
#        "Douglas County is the eighth most populous of the 64 counties of the state of Colorado, in the United States. The county is located midway between Colorado's two largest cities: Denver and Colorado Springs. The United States Census Bureau that the county population was 285,465 in 2010 census, a 62.4% increase since the 2000 census, making Douglas County one of the fastest growing counties in the United States. Douglas County is part of the Denver-Aurora Metropolitan Statistical Area and the Denver-Aurora-Boulder Combined Statistical Area. The county seat is Castle Rock. Douglas County has the highest median household income of any Colorado county or statistical equivalent. It is ranked eighth nationally in that category, and has the highest of any county or equivalent not in the northeastern US.",
#        "Douglas County is the eighth most populous of the 64 counties of the state of Colorado, in the United States. The county is located midway between Colorado's two largest cities: Denver and Colorado Springs. The United States Census Bureau that the county population was 285,465 in 2010 census, a 62.4% increase since the 2000 census, making Douglas County one of the fastest growing counties in the United States. Douglas County is part of the Denver-Aurora Metropolitan Statistical Area and the Denver-Aurora-Boulder Combined Statistical Area. The county seat is Castle Rock. Douglas County has the highest median household income of any Colorado county or statistical equivalent. It is ranked eighth nationally in that category, and has the highest of any county or equivalent not in the northeastern US.",
#        ...,
#        'Teller County is the 22nd most populous of the 64 counties of the State of Colorado of the United States. The county population was 23,350 at U.S. Census 2010. The county seat is Cripple Creek, and the most populous city is Woodland Park. The Colorado Springs Metropolitan Statistical Area which comprises El Paso County and Teller County, had an estimated population of 660,319 in 2011.',
#        'Teller County is the 22nd most populous of the 64 counties of the State of Colorado of the United States. The county population was 23,350 at U.S. Census 2010. The county seat is Cripple Creek, and the most populous city is Woodland Park. The Colorado Springs Metropolitan Statistical Area which comprises El Paso County and Teller County, had an estimated population of 660,319 in 2011.',
#        'Teller County is the 22nd most populous of the 64 counties of the State of Colorado of the United States. The county population was 23,350 at U.S. Census 2010. The county seat is Cripple Creek, and the most populous city is Woodland Park. The Colorado Springs Metropolitan Statistical Area which comprises El Paso County and Teller County, had an estimated population of 660,319 in 2011.'],
#       dtype=object)

# %%
histC={}
for col in dfSchoolC.columns:
    vals = dfSchoolC[col].values.tolist()
    for val in vals:
        if isinstance(val,str):
           if col not in histC:
                histC[col]={}
           for c in val:
               nn = ord(c)
               if nn in histC[col]:
                    histC[col][nn]+=1
               else:
                    histC[col][nn]=1

# %%
for col,chrs in histC.items():
    for chr,cnt in sorted(chrs.items()):
        print(col,chr,cnt)
    print("------------------")

# %%
vals = dfSchoolC['areadesc'].values.tolist()

for val in vals:
    hit=False
    if isinstance(val,str):
        for nn,chr in enumerate(val):
            if ord(chr) == 34:
                print(nn,chr,ord(chr))
                hit=True
        if hit:
            print(val)
        print("---")

# %%
dfSchool['progdesc'].value_counts()
# Out:
# A program that generally prepares individuals to plan, organize, direct, and control the functions and processes of a firm or organization.  Includes instruction in management theory, human resources management and behavior, accounting and other quantitat,Public Institution"                46
# Any single instructional program in liberal arts and sciences, general studies and humanities not listed above.                                                                                                                                                                                    45
# A program that generally prepares individuals to cut, trim, and style scalp, facial, and body hair; apply cosmetic preparations; perform manicures and pedicures; massage the head and extremities; and prepare for practice as licensed cosmetologists in spec,Private for profit institution"    44
# A program that is a structured combination of the arts, biological and physical sciences, social sciences, and humanities, emphasizing breadth of study.  Includes instruction in independently designed, individualized, or regular programs.                                                     42
# A program that prepares individuals to teach students ranging in age from infancy through eight years (grade three), depending on the school system or state regulations.  Includes preparation to teach all relevant subject matter.                                                              42
#                                                                                                                                                                                                                                                                                                    ..
# A program that prepares individuals to apply mathematical and scientific principles to the design, development and operational evaluation of electrical and electronic systems and their components, including electrical power generation systems; and the ana,Private non-profit institution"     1
# A program that focuses on the characteristics of aging populations and the needs of older individuals in family and institutional settings.  Includes instruction in the biological and psychological stages of aging; the provision of dependent care; serving,Public Institution"                 1
# A program that prepares individuals to apply mathematical and scientific principles to the design, development and operational evaluation of total systems solutions to a wide variety of engineering problems, including the integration of human, physical, e,Private for profit institution"     1
# A program that prepares individuals to manage the specialized business functions of a medical or clinical office.  Includes instruction in business office operations, business and financial record-keeping, personnel supervision, medical and health care po,Private for profit institution"     1
# A program that focuses on the theories and methods for managing the media image of a business, organization, or individual and the communication process with stakeholders, constituencies, audiences, and the general public; and that prepares individuals to,Private non-profit institution"     1
# Name: progdesc, Length: 890, dtype: int64

# %%
dfSchool.isna().sum()
# Out:
# statename        0
# city            85
# areaname         0
# areadesc      1243
# instname1        0
# progtitle        0
# progdesc      5542
# instowndes       0
# insttydesc       0
# latitude         0
# longitude        0
# url              0
# zip           3914
# dtype: int64

# %%
dfSchool.shape
# Out:
# (10304, 13)

# %%
dfSchool.columns
# Out:
# Index(['statename', 'city', 'areaname', 'areadesc', 'instname1', 'progtitle',
#        'progdesc', 'instowndes', 'insttydesc', 'latitude', 'longitude', 'url',
#        'zip'],
#       dtype='object')

# %%
dfSchool['instname1'].value_counts()

# %%
dfSchoolNew.loc[dfSchoolNew['instname1'] == "Western State Colorado University"]

# %%
dfSchool = pd.read_csv("/home/joe/bic_etl/cdle/cdle_education/data_transformed/school_programs.csv",encoding="latin")

# %%
dfSchool.loc[dfSchool['instname1'] == "Western State Colorado University"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/anaconda3/envs/p310/lib/python3.10/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'instname1'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 dfSchool.loc[dfSchool['instname1'] == "Western State Colorado University"]
#
# File ~/anaconda3/envs/p310/lib/python3.10/site-packages/pandas/core/frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File ~/anaconda3/envs/p310/lib/python3.10/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'instname1'

# %%
dfSchoolMan = pd.read_csv("/home/joe/bic_etl/cdle/cdle_education/data_transformed/school_programs_manual.csv")

# %%
dfSchoolMan.columns
# Out:
# Index(['statename', 'city', 'address', 'areaname', 'areadesc', 'instname1',
#        'progtitle', 'progdesc', 'instowndes', 'insttydesc', 'latitude',
#        'longitude', 'url', 'zip'],
#       dtype='object')

# %%
dfSchoolMan['zip'].value_counts()

# %%
dfSchoolMan.isna().sum()
# Out:
# statename        0
# city            85
# address         85
# areaname         0
# areadesc      1243
# instname1        0
# progtitle        0
# progdesc      5542
# instowndes       0
# insttydesc       0
# latitude         0
# longitude        0
# url              0
# zip             85
# dtype: int64

# %%
dfSchoolMan.groupby(["instname1","progtitle",'address']).count()
# Out:
#                                                                                                               statename  \
# instname1                               progtitle                                          address
# Academy of Natural Therapy Inc          Massage Therapy/Therapeutic Massage.               625 8th Ave                2
#                                         Somatic Bodywork.                                  625 8th Ave                1
# Adams State University                  American Government and Politics (United States).  208 Edgemont Blvd          8
#                                         Biology/Biological Sciences, General.              208 Edgemont Blvd          8
#                                         Business Administration and Management, General.   208 Edgemont Blvd          8
# ...                                                                                                                 ...
# Westwood College-Denver North           Web Page, Digital/Multimedia and Information Re... 7350 N Broadway            7
# Xenon International Academy-Denver      Aesthetician/Esthetician and Skin Care Specialist. 2231 S Peoria             10
#                                         Cosmetology/Cosmetologist, General.                2231 S Peoria             10
#                                         Nail Technician/Specialist and Manicurist.         2231 S Peoria              5
# Yeshiva Toras Chaim Talmudical Seminary Talmudic Studies.                                  1555 Stuart St             1
#
#                                                                                                               city  \
# instname1                               progtitle                                          address
# Academy of Natural Therapy Inc          Massage Therapy/Therapeutic Massage.               625 8th Ave           2
#                                         Somatic Bodywork.                                  625 8th Ave           1
# Adams State University                  American Government and Politics (United States).  208 Edgemont Blvd     8
#                                         Biology/Biological Sciences, General.              208 Edgemont Blvd     8
#                                         Business Administration and Management, General.   208 Edgemont Blvd     8
# ...                                                                                                            ...
# Westwood College-Denver North           Web Page, Digital/Multimedia and Information Re... 7350 N Broadway       7
# Xenon International Academy-Denver      Aesthetician/Esthetician and Skin Care Specialist. 2231 S Peoria        10
#                                         Cosmetology/Cosmetologist, General.                2231 S Peoria        10
#                                         Nail Technician/Specialist and Manicurist.         2231 S Peoria         5
# Yeshiva Toras Chaim Talmudical Seminary Talmudic Studies.                                  1555 Stuart St        1
#
#                                                                                                               areaname  \
# instname1                               progtitle                                          address
# Academy of Natural Therapy Inc          Massage Therapy/Therapeutic Massage.               625 8th Ave               2
#                                         Somatic Bodywork.                                  625 8th Ave               1
# Adams State University                  American Government and Politics (United States).  208 Edgemont Blvd         8
#                                         Biology/Biological Sciences, General.              208 Edgemont Blvd         8
#                                         Business Administration and Management, General.   208 Edgemont Blvd         8
# ...                                                                                                                ...
# Westwood College-Denver North           Web Page, Digital/Multimedia and Information Re... 7350 N Broadway           7
# Xenon International Academy-Denver      Aesthetician/Esthetician and Skin Care Specialist. 2231 S Peoria            10
#                                         Cosmetology/Cosmetologist, General.                2231 S Peoria            10
#                                         Nail Technician/Specialist and Manicurist.         2231 S Peoria             5
# Yeshiva Toras Chaim Talmudical Seminary Talmudic Studies.                                  1555 Stuart St            1
#
#                                                                                                               areadesc  \
# instname1                               progtitle                                          address
# Academy of Natural Therapy Inc          Massage Therapy/Therapeutic Massage.               625 8th Ave               2
#                                         Somatic Bodywork.                                  625 8th Ave               1
# Adams State University                  American Government and Politics (United States).  208 Edgemont Blvd         6
#                                         Biology/Biological Sciences, General.              208 Edgemont Blvd         6
#                                         Business Administration and Management, General.   208 Edgemont Blvd         6
# ...                                                                                                                ...
# Westwood College-Denver North           Web Page, Digital/Multimedia and Information Re... 7350 N Broadway           6
# Xenon International Academy-Denver      Aesthetician/Esthetician and Skin Care Specialist. 2231 S Peoria             8
#                                         Cosmetology/Cosmetologist, General.                2231 S Peoria             8
#                                         Nail Technician/Specialist and Manicurist.         2231 S Peoria             4
# Yeshiva Toras Chaim Talmudical Seminary Talmudic Studies.                                  1555 Stuart St            1
#
#                                                                                                               progdesc  \
# instname1                               progtitle                                          address
# Academy of Natural Therapy Inc          Massage Therapy/Therapeutic Massage.               625 8th Ave               1
#                                         Somatic Bodywork.                                  625 8th Ave               0
# Adams State University                  American Government and Politics (United States).  208 Edgemont Blvd         4
#                                         Biology/Biological Sciences, General.              208 Edgemont Blvd         4
#                                         Business Administration and Management, General.   208 Edgemont Blvd         4
# ...                                                                                                                ...
# Westwood College-Denver North           Web Page, Digital/Multimedia and Information Re... 7350 N Broadway           0
# Xenon International Academy-Denver      Aesthetician/Esthetician and Skin Care Specialist. 2231 S Peoria             5
#                                         Cosmetology/Cosmetologist, General.                2231 S Peoria             5
#                                         Nail Technician/Specialist and Manicurist.         2231 S Peoria             0
# Yeshiva Toras Chaim Talmudical Seminary Talmudic Studies.                                  1555 Stuart St            0
#
#                                                                                                               instowndes  \
# instname1                               progtitle                                          address
# Academy of Natural Therapy Inc          Massage Therapy/Therapeutic Massage.               625 8th Ave                 2
#                                         Somatic Bodywork.                                  625 8th Ave                 1
# Adams State University                  American Government and Politics (United States).  208 Edgemont Blvd           8
#                                         Biology/Biological Sciences, General.              208 Edgemont Blvd           8
#                                         Business Administration and Management, General.   208 Edgemont Blvd           8
# ...                                                                                                                  ...
# Westwood College-Denver North           Web Page, Digital/Multimedia and Information Re... 7350 N Broadway             7
# Xenon International Academy-Denver      Aesthetician/Esthetician and Skin Care Specialist. 2231 S Peoria              10
#                                         Cosmetology/Cosmetologist, General.                2231 S Peoria              10
#                                         Nail Technician/Specialist and Manicurist.         2231 S Peoria               5
# Yeshiva Toras Chaim Talmudical Seminary Talmudic Studies.                                  1555 Stuart St              1
#
#                                                                                                               insttydesc  \
# instname1                               progtitle                                          address
# Academy of Natural Therapy Inc          Massage Therapy/Therapeutic Massage.               625 8th Ave                 2
#                                         Somatic Bodywork.                                  625 8th Ave                 1
# Adams State University                  American Government and Politics (United States).  208 Edgemont Blvd           8
#                                         Biology/Biological Sciences, General.              208 Edgemont Blvd           8
#                                         Business Administration and Management, General.   208 Edgemont Blvd           8
# ...                                                                                                                  ...
# Westwood College-Denver North           Web Page, Digital/Multimedia and Information Re... 7350 N Broadway             7
# Xenon International Academy-Denver      Aesthetician/Esthetician and Skin Care Specialist. 2231 S Peoria              10
#                                         Cosmetology/Cosmetologist, General.                2231 S Peoria              10
#                                         Nail Technician/Specialist and Manicurist.         2231 S Peoria               5
# Yeshiva Toras Chaim Talmudical Seminary Talmudic Studies.                                  1555 Stuart St              1
#
#                                                                                                               latitude  \
# instname1                               progtitle                                          address
# Academy of Natural Therapy Inc          Massage Therapy/Therapeutic Massage.               625 8th Ave               2
#                                         Somatic Bodywork.                                  625 8th Ave               1
# Adams State University                  American Government and Politics (United States).  208 Edgemont Blvd         8
#                                         Biology/Biological Sciences, General.              208 Edgemont Blvd         8
#                                         Business Administration and Management, General.   208 Edgemont Blvd         8
# ...                                                                                                                ...
# Westwood College-Denver North           Web Page, Digital/Multimedia and Information Re... 7350 N Broadway           7
# Xenon International Academy-Denver      Aesthetician/Esthetician and Skin Care Specialist. 2231 S Peoria            10
#                                         Cosmetology/Cosmetologist, General.                2231 S Peoria            10
#                                         Nail Technician/Specialist and Manicurist.         2231 S Peoria             5
# Yeshiva Toras Chaim Talmudical Seminary Talmudic Studies.                                  1555 Stuart St            1
#
#                                                                                                               longitude  \
# instname1                               progtitle                                          address
# Academy of Natural Therapy Inc          Massage Therapy/Therapeutic Massage.               625 8th Ave                2
#                                         Somatic Bodywork.                                  625 8th Ave                1
# Adams State University                  American Government and Politics (United States).  208 Edgemont Blvd          8
#                                         Biology/Biological Sciences, General.              208 Edgemont Blvd          8
#                                         Business Administration and Management, General.   208 Edgemont Blvd          8
# ...                                                                                                                 ...
# Westwood College-Denver North           Web Page, Digital/Multimedia and Information Re... 7350 N Broadway            7
# Xenon International Academy-Denver      Aesthetician/Esthetician and Skin Care Specialist. 2231 S Peoria             10
#                                         Cosmetology/Cosmetologist, General.                2231 S Peoria             10
#                                         Nail Technician/Specialist and Manicurist.         2231 S Peoria              5
# Yeshiva Toras Chaim Talmudical Seminary Talmudic Studies.                                  1555 Stuart St             1
#
#                                                                                                               url  \
# instname1                               progtitle                                          address
# Academy of Natural Therapy Inc          Massage Therapy/Therapeutic Massage.               625 8th Ave          2
#                                         Somatic Bodywork.                                  625 8th Ave          1
# Adams State University                  American Government and Politics (United States).  208 Edgemont Blvd    8
#                                         Biology/Biological Sciences, General.              208 Edgemont Blvd    8
#                                         Business Administration and Management, General.   208 Edgemont Blvd    8
# ...                                                                                                           ...
# Westwood College-Denver North           Web Page, Digital/Multimedia and Information Re... 7350 N Broadway      7
# Xenon International Academy-Denver      Aesthetician/Esthetician and Skin Care Specialist. 2231 S Peoria       10
#                                         Cosmetology/Cosmetologist, General.                2231 S Peoria       10
#                                         Nail Technician/Specialist and Manicurist.         2231 S Peoria        5
# Yeshiva Toras Chaim Talmudical Seminary Talmudic Studies.                                  1555 Stuart St       1
#
#                                                                                                               zip
# instname1                               progtitle                                          address
# Academy of Natural Therapy Inc          Massage Therapy/Therapeutic Massage.               625 8th Ave          2
#                                         Somatic Bodywork.                                  625 8th Ave          1
# Adams State University                  American Government and Politics (United States).  208 Edgemont Blvd    8
#                                         Biology/Biological Sciences, General.              208 Edgemont Blvd    8
#                                         Business Administration and Management, General.   208 Edgemont Blvd    8
# ...                                                                                                           ...
# Westwood College-Denver North           Web Page, Digital/Multimedia and Information Re... 7350 N Broadway      7
# Xenon International Academy-Denver      Aesthetician/Esthetician and Skin Care Specialist. 2231 S Peoria       10
#                                         Cosmetology/Cosmetologist, General.                2231 S Peoria       10
#                                         Nail Technician/Specialist and Manicurist.         2231 S Peoria        5
# Yeshiva Toras Chaim Talmudical Seminary Talmudic Studies.                                  1555 Stuart St       1
#
# [2846 rows x 11 columns]

# %%
dfSchoolMan.loc[(dfSchoolMan['instname1'] == "Adams State University")  &
                (dfSchoolMan['progtitle'] == "American Government and Politics (United States).")]
# Out:
#     statename     city            address  \
# 85   Colorado  Alamosa  208 Edgemont Blvd
# 86   Colorado  Alamosa  208 Edgemont Blvd
# 143  Colorado  Alamosa  208 Edgemont Blvd
# 144  Colorado  Alamosa  208 Edgemont Blvd
# 201  Colorado  Alamosa  208 Edgemont Blvd
# 202  Colorado  Alamosa  208 Edgemont Blvd
# 259  Colorado  Alamosa  208 Edgemont Blvd
# 260  Colorado  Alamosa  208 Edgemont Blvd
#
#                                               areaname  \
# 85   Alamosa County                                ...
# 86   Alamosa County                                ...
# 143                      Co Rural Workforce Consortium
# 144                      Co Rural Workforce Consortium
# 201  Edwards MCA                                   ...
# 202  Edwards MCA                                   ...
# 259  Planning Region 3                             ...
# 260  Planning Region 3                             ...
#
#                                               areadesc  \
# 85   Alamosa County is one of the 64 counties of th...
# 86   Alamosa County is one of the 64 counties of th...
# 143                                                NaN
# 144                                                NaN
# 201                              Eagle & Lake counties
# 202                              Eagle & Lake counties
# 259
# 260
#
#                   instname1  \
# 85   Adams State University
# 86   Adams State University
# 143  Adams State University
# 144  Adams State University
# 201  Adams State University
# 202  Adams State University
# 259  Adams State University
# 260  Adams State University
#
#                                              progtitle  \
# 85   American Government and Politics (United States).
# 86   American Government and Politics (United States).
# 143  American Government and Politics (United States).
# 144  American Government and Politics (United States).
# 201  American Government and Politics (United States).
# 202  American Government and Politics (United States).
# 259  American Government and Politics (United States).
# 260  American Government and Politics (United States).
#
#                                               progdesc          instowndes  \
# 85                                                 NaN  Public Institution
# 86   A program that focuses on the systematic study...  Public Institution
# 143                                                NaN  Public Institution
# 144  A program that focuses on the systematic study...  Public Institution
# 201                                                NaN  Public Institution
# 202  A program that focuses on the systematic study...  Public Institution
# 259                                                NaN  Public Institution
# 260  A program that focuses on the systematic study...  Public Institution
#
#                               insttydesc  latitude  longitude  \
# 85   Four-year Colleges and Universities       0.0        0.0
# 86   Four-year Colleges and Universities       0.0        0.0
# 143  Four-year Colleges and Universities       0.0        0.0
# 144  Four-year Colleges and Universities       0.0        0.0
# 201  Four-year Colleges and Universities       0.0        0.0
# 202  Four-year Colleges and Universities       0.0        0.0
# 259  Four-year Colleges and Universities       0.0        0.0
# 260  Four-year Colleges and Universities       0.0        0.0
#
#                       url      zip
# 85   http://www.adams.edu  81101.0
# 86   http://www.adams.edu  81101.0
# 143  http://www.adams.edu  81101.0
# 144  http://www.adams.edu  81101.0
# 201  http://www.adams.edu  81101.0
# 202  http://www.adams.edu  81101.0
# 259  http://www.adams.edu  81101.0
# 260  http://www.adams.edu  81101.0

# %%
for inst in dfSchoolMan['instname1'].unique():
    dftmp = dfSchoolMan.loc[dfSchoolMan['instname1'] == inst]
#    dftmp.sort_values(by=['progtitle','areaname'],inplace=True)
    for

# %% [markdown]
# ### Fix School Data

# %%
dfbad = dfSchoolMan.loc[dfSchoolMan['progdesc'].isna()]
dfgood = dfSchoolMan.loc[~dfSchoolMan['progdesc'].isna()]

# %%
tot=0
histbad = {}
dftmp = pd.DataFrame(columns=dfgood.columns)
dfdel = pd.DataFrame(columns=dfgood.columns)

for index,row in dfbad.iterrows():
    inst = row['instname1']
    prog = row['progtitle']
    area = row['areaname']
    url = row['url']
    ownd = row['instowndes']
    indes = row['insttydesc']
    if inst not in histbad:
        histbad[inst]={}
        histbad[inst]['count']=0
        histbad[inst]['bad']=0
        
    histbad[inst]['count']+=1
    nn = dfgood.loc[(dfgood['instname1'] == inst) & 
                    (dfgood['progtitle'] == prog) & 
                    (dfgood['areaname']==area) & 
                    (dfgood['url'] == url) & 
                    (dfgood['instowndes'] == ownd) & 
                    (dfgood['insttydesc'] == indes)                   
                   ].shape[0]
    if nn == 0: # There are no other records, so we need to keep this record
        tot+=1
        histbad[inst]['bad']+=1
        dftmp = dftmp.append(row)
    elif nn == 1: # There IS another record and the descripiton is NOT missing, so we can delete this record with the missing description
        dfdel=dfdel.append(row)
    else:
        print(inst,prog,area)
        
        
print(dfbad.shape[0],tot)
# Out:
# 5542 1873

# %%
dfdel.shape
# Out:
# (3669, 14)

# %%
for inst,res in histbad.items():
    print(inst,res['count'],res['bad'])

# %%
dfdel.head()
# Out:
#    statename     city            address  \
# 85  Colorado  Alamosa  208 Edgemont Blvd
# 87  Colorado  Alamosa  208 Edgemont Blvd
# 89  Colorado  Alamosa  208 Edgemont Blvd
# 91  Colorado  Alamosa  208 Edgemont Blvd
# 93  Colorado  Alamosa  208 Edgemont Blvd
#
#                                              areaname  \
# 85  Alamosa County                                ...
# 87  Alamosa County                                ...
# 89  Alamosa County                                ...
# 91  Alamosa County                                ...
# 93  Alamosa County                                ...
#
#                                              areadesc               instname1  \
# 85  Alamosa County is one of the 64 counties of th...  Adams State University
# 87  Alamosa County is one of the 64 counties of th...  Adams State University
# 89  Alamosa County is one of the 64 counties of th...  Adams State University
# 91  Alamosa County is one of the 64 counties of th...  Adams State University
# 93  Alamosa County is one of the 64 counties of th...  Adams State University
#
#                                             progtitle  progdesc  \
# 85  American Government and Politics (United States).       NaN
# 87              Biology/Biological Sciences, General.       NaN
# 89   Business Administration and Management, General.       NaN
# 91  Business Administration, Management and Operat...       NaN
# 93                        Business/Commerce, General.       NaN
#
#             instowndes                           insttydesc  latitude  \
# 85  Public Institution  Four-year Colleges and Universities       0.0
# 87  Public Institution  Four-year Colleges and Universities       0.0
# 89  Public Institution  Four-year Colleges and Universities       0.0
# 91  Public Institution  Four-year Colleges and Universities       0.0
# 93  Public Institution  Four-year Colleges and Universities       0.0
#
#     longitude                   url      zip
# 85        0.0  http://www.adams.edu  81101.0
# 87        0.0  http://www.adams.edu  81101.0
# 89        0.0  http://www.adams.edu  81101.0
# 91        0.0  http://www.adams.edu  81101.0
# 93        0.0  http://www.adams.edu  81101.0

# %%
4762+1873
# Out:
# 6635

# %%
5542-1873
# Out:
# 3669

# %%
## Add the records with missing descriptions that do not have a corresponding non-missing description record back for output 
dfgood = pd.concat([dfgood,dftmp])

# %%
for index,row in dfdel.iterrows():
    inst = row['instname1']
    prog = row['progtitle']
    area = row['areaname']
    url = row['url']
    ownd = row['instowndes']
    indes = row['insttydesc']
 
    histbad[inst]['count']+=1
    hld= dfgood.loc[(dfgood['instname1'] == inst) & 
                    (dfgood['progtitle'] == prog) & 
                    (dfgood['areaname']==area) & 
                    (dfgood['url'] == url) & 
                    (dfgood['instowndes'] == ownd) & 
                    (dfgood['insttydesc'] == indes)                   
                   ]
    nn=hld.shape[0]
    
    if nn == 1:
        mm = hld['progdesc'].isna().sum()
        if mm != 0:
            print("ROH ROH")
            print(hld.head())
            print("----")
    else:
        print("BAD BAD BAD",nn)
        print(hld.head())
        print("----")

# %%
longs = dfSchool['longitude'].values.tolist()

# %%
display(dfSchool.iloc[85])
# Out:
# statename                                              Colorado
# city                                                    Alamosa
# areaname      Alamosa County                                ...
# areadesc      Alamosa County is one of the 64 counties of th...
# instname1                                Adams State University
# progtitle     American Government and Politics (United States).
# progdesc                                                    NaN
# instowndes                                   Public Institution
# insttydesc                  Four-year Colleges and Universities
# latitude                                                    0.0
# longitude                                              0.000000
# url                                        http://www.adams.edu
# zip                                                     81101.0
# Name: 85, dtype: object

# %%
dfSchool.iloc[86]
# Out:
# statename                                              Colorado
# city                                                    Alamosa
# areaname      Alamosa County                                ...
# areadesc      Alamosa County is one of the 64 counties of th...
# instname1                                Adams State University
# progtitle     American Government and Politics (United States).
# progdesc      A program that focuses on the systematic study...
# instowndes                  Four-year Colleges and Universities
# insttydesc                                             0.000000
# latitude                                                    0.0
# longitude                                  http://www.adams.edu
# url                                                       81101
# zip                                                         NaN
# Name: 86, dtype: object

# %%
for nn,lng in enumerate(longs):
    print(nn,lng)

# %%
file = "/home/joe/bic_etl/cdle/cdle_education/data_transformed/school_programs.csv"
fin = open(file)
lines = fin.readlines()

# %%
lines[86]
# Out:
# '"Colorado","Alamosa","Alamosa County                                              ","Alamosa County is one of the 64 counties of the state of Colorado of the United States. The county name is the Spanish language word for a ""grove of cottonwood trees."" The county population was 14,966 at U.S. Census 2000. The county seat is Alamosa.","Adams State University","American Government and Politics (United States).",NULL,"Public Institution","Four-year Colleges and Universities","0.000000","0.000000","http://www.adams.edu","81101"\n'

# %%
lines[87]
# Out:
# '"Colorado","Alamosa","Alamosa County                                              ","Alamosa County is one of the 64 counties of the state of Colorado of the United States. The county name is the Spanish language word for a ""grove of cottonwood trees."" The county population was 14,966 at U.S. Census 2000. The county seat is Alamosa.","Adams State University","American Government and Politics (United States).","A program that focuses on the systematic study of United States political institutions and behavior.  Includes instruction in American political theory, political parties and interest groups, state and local governments, Constitutional law, federalism and,"Public Institution","Four-year Colleges and Universities","0.000000","0.000000","http://www.adams.edu","81101"\n'

# %%
schoolNew = pd.read_csv("school_programs.csv")

# %%
schoolNew.loc[schoolNew['instname1'] == "Western State Colorado University"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/anaconda3/envs/p310/lib/python3.10/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'instname1'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 schoolNew.loc[schoolNew['instname1'] == "Western State Colorado University"]
#
# File ~/anaconda3/envs/p310/lib/python3.10/site-packages/pandas/core/frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File ~/anaconda3/envs/p310/lib/python3.10/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'instname1'

# %%
schoolNew.head()
# Out:
#    "Colorado" NULL NULL.1  \
# 0  "Colorado"  NaN    NaN
# 1  "Colorado"  NaN    NaN
# 2  "Colorado"  NaN    NaN
# 3  "Colorado"  NaN    NaN
# 4  "Colorado"  NaN    NaN
#
#   "Douglas County                                              "  \
# 0  "Douglas County                               ...
# 1  "Douglas County                               ...
# 2  "Douglas County                               ...
# 3  "Douglas County                               ...
# 4  "Douglas County                               ...
#
#   "Douglas County is the eighth most populous of the 64 counties of the state of Colorado, in the United States. The county is located midway between Colorado's two largest cities: Denver and Colorado Springs. The United States Census Bureau that the county population was 285,465 in 2010 census, a 62.4% increase since the 2000 census, making Douglas County one of the fastest growing counties in the United States. Douglas County is part of the Denver-Aurora Metropolitan Statistical Area and the Denver-Aurora-Boulder Combined Statistical Area. The county seat is Castle Rock. Douglas County has the highest median household income of any Colorado county or statistical equivalent. It is ranked eighth nationally in that category, and has the highest of any county or equivalent not in the northeastern US."  \
# 0  "Douglas County is the eighth most populous of...
# 1  "Douglas County is the eighth most populous of...
# 2  "Douglas County is the eighth most populous of...
# 3  "Douglas County is the eighth most populous of...
# 4  "Douglas County is the eighth most populous of...
#
#    "University of Phoenix-Colorado Campus"  \
# 0  "University of Phoenix-Colorado Campus"
# 1  "University of Phoenix-Colorado Campus"
# 2  "University of Phoenix-Colorado Campus"
# 3  "University of Phoenix-Colorado Campus"
# 4  "University of Phoenix-Colorado Campus"
#
#                "Accounting and Business/Management." NULL.2  \
# 0                                      "Accounting."    NaN
# 1                             "Behavioral Sciences."    NaN
# 2  "Business Administration and Management, Gener...    NaN
# 3               "Computer and Information Sciences,"    NaN
# 4  "Computer and Information Systems Security/Inf...    NaN
#
#    "Private for profit institution"  "Four-year Colleges and Universities"  \
# 0  "Private for profit institution"  "Four-year Colleges and Universities"
# 1  "Private for profit institution"  "Four-year Colleges and Universities"
# 2  "Private for profit institution"  "Four-year Colleges and Universities"
# 3  "Private for profit institution"  "Four-year Colleges and Universities"
# 4  "Private for profit institution"  "Four-year Colleges and Universities"
#
#    "39.551643"  "-104.873421"  "http://" NULL.3
# 0  "39.551643"  "-104.873421"  "http://"    NaN
# 1  "39.551643"  "-104.873421"  "http://"    NaN
# 2  "39.551643"  "-104.873421"  "http://"    NaN
# 3  "39.551643"  "-104.873421"  "http://"    NaN
# 4  "39.551643"  "-104.873421"  "http://"    NaN

# %%
df = pd.read_csv("school_programs.csv")

# %%
df.head()
# Out:
#   statename city                                           areaname  \
# 0  Colorado  NaN  Douglas County                                ...
# 1  Colorado  NaN  Douglas County                                ...
# 2  Colorado  NaN  Douglas County                                ...
# 3  Colorado  NaN  Douglas County                                ...
# 4  Colorado  NaN  Douglas County                                ...
#
#                                             areadesc  \
# 0  Douglas County is the eighth most populous of ...
# 1  Douglas County is the eighth most populous of ...
# 2  Douglas County is the eighth most populous of ...
# 3  Douglas County is the eighth most populous of ...
# 4  Douglas County is the eighth most populous of ...
#
#                                instname1  \
# 0  University of Phoenix-Colorado Campus
# 1  University of Phoenix-Colorado Campus
# 2  University of Phoenix-Colorado Campus
# 3  University of Phoenix-Colorado Campus
# 4  University of Phoenix-Colorado Campus
#
#                                           progtitle progdesc  \
# 0               Accounting and Business/Management.      NaN
# 1                                       Accounting.      NaN
# 2                              Behavioral Sciences.      NaN
# 3  Business Administration and Management, General.      NaN
# 4                Computer and Information Sciences,      NaN
#
#                        instowndes                           insttydesc  \
# 0  Private for profit institution  Four-year Colleges and Universities
# 1  Private for profit institution  Four-year Colleges and Universities
# 2  Private for profit institution  Four-year Colleges and Universities
# 3  Private for profit institution  Four-year Colleges and Universities
# 4  Private for profit institution  Four-year Colleges and Universities
#
#     latitude   longitude      url  zip
# 0  39.551643 -104.873421  http://  NaN
# 1  39.551643 -104.873421  http://  NaN
# 2  39.551643 -104.873421  http://  NaN
# 3  39.551643 -104.873421  http://  NaN
# 4  39.551643 -104.873421  http://  NaN

# %%
df['longitude'].value_counts()
# Out:
#  0.000000      9714
# -104.986386     196
# -105.000000     154
# -104.822841      66
# -104.873421      60
# -104.820000      30
# -104.980000      28
# -104.875949      20
# -104.821001      13
# -104.780941       7
# -104.787967       5
# -105.053321       4
# -105.200000       3
# -104.967732       1
# -105.043282       1
# -105.080647       1
# -105.065051       1
# Name: longitude, dtype: int64
