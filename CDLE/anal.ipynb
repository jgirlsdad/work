# %%
import pyodbc
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import pyodbc
#       2 import pandas as pd
#
# ModuleNotFoundError: No module named 'pyodbc'

# %%
# Defining the connection string
pw=""
#conn = pyodbc.connect('''DRIVER={SQL Server}; Server=127.0.0.1; 
#                        UID=adminUser; PWD=passWrd@123; DataBase=gocode_0324''')
conn = pyodbc.connect(f"DRIVER={{ODBC Driver 18 for SQL Server}}; Server=192.168.56.1:1433;    \
                        UID=MSI\CoJoe; PWD={pw}; DataBase=gocode_0424")
 
# # Fetching the data from the selected table using SQL query
# RawData= pd.read_sql_query('''select * from &#91;EMP].&#91;Employee_table]''', conn)
# RawData.head()
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# <ipython-input-2-11fa365dabf6> in <module>
#       4 #                        UID=adminUser; PWD=passWrd@123; DataBase=gocode_0324''')
#       5 conn = pyodbc.connect(f"DRIVER={{ODBC Driver 18 for SQL Server}}; Server=192.168.56.1:1433;    \
# ----> 6                         UID=MSI\CoJoe; PWD={pw}; DataBase=gocode_0424")
#       7
#       8 # # Fetching the data from the selected table using SQL query
#
# OperationalError: ('HYT00', '[HYT00] [Microsoft][ODBC Driver 18 for SQL Server]Login timeout expired (0) (SQLDriverConnect)')

# %%
conn = pyodbc.connect(
    "Driver={ODBC Driver 18 for SQL Server};"
    "Server=MSI\MSSQLSERVER01;"
    "Database=gocode_0324;"
    "UID=guest;"
    "PWD="
    ";Trusted_Connection=no"
)

#To execute queries, the “cursor()” object of the connection object is used. The following script stores the cursor object in the “cursor” variable:
cursor = conn.cursor()
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# <ipython-input-26-efb320f95097> in <module>
#       1 conn = pyodbc.connect(
# ----> 2     "Driver={ODBC Driver 18 for SQL Server};"
#       3     "Server=MSI\MSSQLSERVER01;"
#       4     "Database=gocode_0324;"
#       5     "UID=guest;"
#
# OperationalError: ('HYT00', '[HYT00] [Microsoft][ODBC Driver 18 for SQL Server]Login timeout expired (0) (SQLDriverConnect)')
