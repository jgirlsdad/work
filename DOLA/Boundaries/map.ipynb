# %%
import geopandas as gpd,pandas as pd
#import zipfile as zf
import fiona as fi

# %%
dfM = gpd.read_file("/home/joe/bic_etl/dola/special_districts/data_source/dllibrary.shp")

# %%
dfM.crs
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World.
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984 ensemble
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
dfM.columns
# Out:
# Index(['lgid', 'source', 'lastupdate', 'NAME', 'LG_TYPE_ID', 'LG_STATUS_',
#        'ABBREV_NAM', 'MAIL_ADDRE', 'ALT_ADDRES', 'MAIL_CITY', 'MAIL_STATE',
#        'MAIL_ZIP', 'WEBSITE_UR', 'PREV_NAME', 'geometry'],
#       dtype='object')

# %%
dfC = pd.read_csv(" https://data.colorado.gov/resource/7myi-3bh6.csv")

# %%
set(dfC.columns.str.lower()) - set(dfM.columns.str.lower())
# Out:
# {'gid', 'lgstatus_i', 'lgtype_id', 'the_geom', 'url'}

# %%
set(dfM.columns.str.lower()) - set(dfC.columns.str.lower())
# Out:
# {'geometry', 'lg_status_', 'lg_type_id', 'website_ur'}

# %%
print(dfM.shape)
print(dfC.shape)
# Out:
# (56, 15)
# (55, 16)

# %%
dfC.columns
# Out:
# Index(['the_geom', 'gid', 'lgid', 'source', 'lastupdate', 'name', 'lgtype_id',
#        'lgstatus_i', 'abbrev_nam', 'mail_addre', 'alt_addres', 'mail_city',
#        'mail_state', 'mail_zip', 'url', 'prev_name'],
#       dtype='object')

# %%
dfM.columns
# Out:
# Index(['lgid', 'source', 'lastupdate', 'NAME', 'LG_TYPE_ID', 'LG_STATUS_',
#        'ABBREV_NAM', 'MAIL_ADDRE', 'ALT_ADDRES', 'MAIL_CITY', 'MAIL_STATE',
#        'MAIL_ZIP', 'WEBSITE_UR', 'PREV_NAME', 'geometry'],
#       dtype='object')

# %%
dfF = pd.read_csv(" https://data.colorado.gov/resource/9s32-6t85.csv")

# %%
with zf.ZipFile('/home/joe/bic_etl/dola/boundaries/data_source/Annexations.zip', 'r') as zip_ref:
with zf.ZipFile('Annexations.zip', 'r') as zip_ref:
    
    # Get the name of the shapefile within the zip
    shapefile_name = [name for name in zip_ref.namelist() if name.endswith('.shp')][0]
    print("SHAPEFILE ",shapefile_name)
    # Read the shapefile directly from the zip
    with zip_ref.open(f'{shapefile_name}') as f:
        gdf = gpd.read_file(f)

# Now you can work with the geodataframe
print(gdf.head())
# Out:
#   Cell In[4], line 2
#     with zf.ZipFile('Annexations.zip', 'r') as zip_ref:
#     ^
# IndentationError: expected an indented block after 'with' statement on line 1

# %%
    
# Get the name of the shapefile within the zip

with fi.open(f'Annexations/Annexations.shp', 'r') as shapefile:
    # Get the coordinate reference system (CRS)
    crs = shapefile.crs
    for feature in shapefile:
        # Access the feature's geometry
        geometry = feature['geometry']

        # Access the feature's attributes
        attributes = feature['properties']

        # Do something with the geometry and attributes
        print(geometry, attributes)

# %%
gdf = gpd.read_file('Annexations/Annexations.shp')
print(gdf.head())
# Out:
#    gid        rec_num county   city cl_re_date                     descr  \
# 0  898         912897    087  27810 2018-07-02        Bath Annexation II
# 1  899       D8075948    005  12815 2018-08-03      Ting Annexation 1-10
# 2    1        3378913    013  41835 2014-05-07  Swinburg Annexation No 1
# 3    2        3377570    013  45970 2014-04-29   Quail Commercial Center
# 4    3  2014000022046    001  08675 2014-04-11            Case Farms PUD
#
#           ord_num type                                            notes  \
# 0        No. 1212    A                                             None
# 1   No. 2018-O-06    A                                             None
# 2       O10 S2014    A                                             None
# 3       O-2013-28    A                                             None
# 4  No. 2163, 2013    A  Maybe Delete - A zoning rather than annexation.
#
#       cityname                                           geometry
# ...
