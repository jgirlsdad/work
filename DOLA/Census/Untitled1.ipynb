# %%
import pandas as pd  
import numpy as np  
import geopandas as gpd  
import matplotlib.pyplot as plt # plot our data and manipulate the plot

# %%
df = gpd.read_file("/home/joe/bic_etl/dola/census/data_transformed/raw/zip_codes_2021/zip_codes_2021.shp")

# %%
df.head()
# Out:
#   zip_code    pop hispanic white_nh black_nh ntvam_nh asian_nh hawpi_nh  \
# 0    80737   1699      277     1361       15        1        8        0
# 1    80457    414       30      384        0        0        0        0
# 2    80501  43615    13662    26727      550      200      775       53
# 3    80104  33991     2920    28301      166      124      526      111
# 4    80743   1194       83     1069       31        0        0        1
#
#   other_nh twoplus_nh  ... disabled pop16_pls laborforce civ_lf    emp unemp  \
# 0        4         33  ...      356      1284        719    719    686    33
# 1        0          0  ...       27       341        314    314    314     0
# 2      128       1520  ...     5100     35307      25305  25289  24083  1206
# 3      158       1685  ...     3074     26997      20004  19938  19057   881
# 4        0         10  ...      137       904        561    561    531    30
#
# ...

# %%
df.plot()
# Out:
# <AxesSubplot:>

# %%
counties21.head()
# Out:
#                                             the_geom    geoname  geonum  \
# 0  MULTIPOLYGON (((-105.053289 39.856764, -105.05...      Adams  108001
# 1  MULTIPOLYGON (((-106.039348 37.458741, -106.03...    Alamosa  108003
# 2  MULTIPOLYGON (((-104.902671 39.685712, -104.89...   Arapahoe  108005
# 3  MULTIPOLYGON (((-107.482304 37.328714, -107.48...  Archuleta  108007
# 4  MULTIPOLYGON (((-103.08632 37.143426, -103.086...       Baca  108009
#
#       pop  hispanic  white_nh  black_nh  ntvam_nh  asian_nh  hawpi_nh  ...  \
# 0  514969    210869    248507     16630      2006     20103       685  ...
# 1   16377      7793      7610       277        49       161         9  ...
# 2  651621    129630    381106     69431      1912     40237      1421  ...
# 3   13267      2467     10050        21       267       125        19  ...
# 4    3519       414      2926        22        34        50         9  ...
#
#    civ_ni_pop  disabled  pop16_pls  laborforce  civ_lf     emp  unemp  \
# ...
